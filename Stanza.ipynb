# %% [markdown]
# <a href="https://colab.research.google.com/github/Viny2030/UNED/blob/main/Stanza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installing Stanza

# %%
# !pip install stanza

import stanza
# Out:
# Requirement already satisfied: stanza in /usr/local/lib/python3.7/dist-packages (1.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.7.1+cu101)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.19.5)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (3.7.4.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (53.0.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (1.15.0)

# %% [markdown]
# ## Downloading Models

# %%
# Download an English model into the default directory
print("Downloading English model...")
stanza.download('en')

# Note that you can use verbose=False to turn off all printed messages
print("Downloading Chinese model...")
stanza.download('zh', verbose=False)
# Out:
# Downloading English model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 20.9MB/s]
# 2021-03-01 06:05:13 INFO: Downloading default packages for language: en (English)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/default.zip: 100%|██████████| 411M/411M [00:46<00:00, 8.76MB/s]
# 2021-03-01 06:06:07 INFO: Finished downloading models and saved to /root/stanza_resources.
# Downloading Chinese model...

# %% [markdown]
# ### Processing Text

# %% [markdown]
# ### Constructing Pipeline

# %%
# Build an English pipeline, with all processors by default
print("Building an English pipeline...")
en_nlp = stanza.Pipeline('en')

# Build a Chinese pipeline, with customized processor list and no logging, and force it to use CPU
print("Building a Chinese pipeline...")
zh_nlp = stanza.Pipeline('zh', processors='tokenize,lemma,pos,depparse', verbose=False, use_gpu=False)
# Out:
# Building an English pipeline...
# Building a Chinese pipeline...

# %% [markdown]
# ### Annotating Text
#
# After a pipeline is successfully constructed, you can get annotations of a piece of text simply by passing the string into the pipeline object. The pipeline will return a `Document` object, which can be used to access detailed annotations from. For example:

# %%
# Processing English text
en_doc = en_nlp("Barack Obama was born in Hawaii.  He was elected president in 2008.")
print(type(en_doc))

# Processing Chinese text
zh_doc = zh_nlp("达沃斯世界经济论坛是每年全球政商界领袖聚在一起的年度盛事。")
print(type(zh_doc))
# Out:
# <class 'stanza.models.common.doc.Document'>
# <class 'stanza.models.common.doc.Document'>

# %% [markdown]
# ## Accessing Annotations
#
# Annotations can be accessed from the returned `Document` object.

# %%
for i, sent in enumerate(en_doc.sentences):
    print("[Sentence {}]".format(i+1))
    for word in sent.words:
        print("{:12s}\t{:12s}\t{:6s}\t{:d}\t{:12s}".format(\
              word.text, word.lemma, word.pos, word.head, word.deprel))
    print("")
# Out:
# [Sentence 1]
# Barack      	Barack      	PROPN 	4	nsubj:pass
# Obama       	Obama       	PROPN 	1	flat
# was         	be          	AUX   	4	aux:pass
# born        	bear        	VERB  	0	root
# in          	in          	ADP   	6	case
# Hawaii      	Hawaii      	PROPN 	4	obl
# .           	.           	PUNCT 	4	punct
#
# [Sentence 2]
# He          	he          	PRON  	3	nsubj:pass
# was         	be          	AUX   	3	aux:pass
# elected     	elect       	VERB  	0	root
# president   	president   	NOUN  	3	xcomp
# in          	in          	ADP   	6	case
# 2008        	2008        	NUM   	3	obl
# .           	.           	PUNCT 	3	punct

# %% [markdown]
# The following example iterate over all extracted named entity mentions and print out their character spans and types.

# %%
print("Mention text\tType\tStart-End")
for ent in en_doc.ents:
    print("{}\t{}\t{}-{}".format(ent.text, ent.type, ent.start_char, ent.end_char))
# Out:
# Mention text	Type	Start-End
# Barack Obama	PERSON	0-12
# Hawaii	GPE	25-31
# 2008	DATE	62-66

# %% [markdown]
# And similarly for the Chinese text:

# %%
for i, sent in enumerate(zh_doc.sentences):
    print("[Sentence {}]".format(i+1))
    for word in sent.words:
        print("{:12s}\t{:12s}\t{:6s}\t{:d}\t{:12s}".format(\
              word.text, word.lemma, word.pos, word.head, word.deprel))
    print("")
# Out:
# [Sentence 1]
# 达沃斯         	达沃斯         	PROPN 	4	nmod
# 世界          	世界          	NOUN  	4	nmod
# 经济          	经济          	NOUN  	4	nmod
# 论坛          	论坛          	NOUN  	16	nsubj
# 是           	是           	AUX   	16	cop
# 每年          	每年          	DET   	10	det
# 全           	全           	DET   	8	det
# 球政          	球政          	NOUN  	10	nmod
# 商界          	商界          	NOUN  	10	nmod
# 领袖          	领袖          	NOUN  	11	nsubj
# 聚           	聚           	VERB  	16	acl:relcl
# 在           	在           	VERB  	11	mark
# 一起          	一起          	NOUN  	11	obj
# 的           	的           	PART  	11	mark:relcl
# 年度          	年度          	NOUN  	16	nmod
# 盛事          	盛事          	NOUN  	0	root
# 。           	。           	PUNCT 	16	punct

# %% [markdown]
# Alternatively, you can directly print a `Word` object to view all its annotations as a Python dict:

# %%
word = en_doc.sentences[0].words[0]
print(word)
# Out:
# {
#   "id": 1,
#   "text": "Barack",
#   "lemma": "Barack",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 4,
#   "deprel": "nsubj:pass",
#   "misc": "start_char=0|end_char=6"
# }

# %%
stanza.download(lang="en")
nlp = stanza.Pipeline(lang="en")
doc = nlp("Question answering is a task where a sentence or sample of text is provided from which questions are asked and must be answered.")
for sentence in doc.sentences:
    print(sentence.ents)
    print(sentence.dependencies)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 20.7MB/s]
# 2021-03-01 12:01:08 INFO: Downloading default packages for language: en (English)...
# 2021-03-01 12:01:09 INFO: File exists: /root/stanza_resources/en/default.zip.
# 2021-03-01 12:01:14 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-03-01 12:01:14 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | lemma     | combined  |
# | depparse  | combined  |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2021-03-01 12:01:14 INFO: Use device: cpu
# 2021-03-01 12:01:14 INFO: Loading: tokenize
# 2021-03-01 12:01:14 INFO: Loading: pos
# 2021-03-01 12:01:15 INFO: Loading: lemma
# 2021-03-01 12:01:15 INFO: Loading: depparse
# 2021-03-01 12:01:15 INFO: Loading: sentiment
# 2021-03-01 12:01:16 INFO: Loading: ner
# 2021-03-01 12:01:17 INFO: Done loading processors!
# []
# [({
#   "id": 2,
#   "text": "answering",
#   "lemma": "answer",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 5,
#   "deprel": "nsubj",
#   "misc": "start_char=9|end_char=18"
# }, 'compound', {
#   "id": 1,
#   "text": "Question",
#   "lemma": "question",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 2,
#   "deprel": "compound",
#   "misc": "start_char=0|end_char=8"
# }), ({
#   "id": 5,
#   "text": "task",
#   "lemma": "task",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 0,
#   "deprel": "root",
#   "misc": "start_char=24|end_char=28"
# }, 'nsubj', {
#   "id": 2,
#   "text": "answering",
#   "lemma": "answer",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 5,
#   "deprel": "nsubj",
#   "misc": "start_char=9|end_char=18"
# }), ({
#   "id": 5,
#   "text": "task",
#   "lemma": "task",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 0,
#   "deprel": "root",
#   "misc": "start_char=24|end_char=28"
# }, 'cop', {
#   "id": 3,
#   "text": "is",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBZ",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#   "head": 5,
#   "deprel": "cop",
#   "misc": "start_char=19|end_char=21"
# }), ({
#   "id": 5,
#   "text": "task",
#   "lemma": "task",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 0,
#   "deprel": "root",
#   "misc": "start_char=24|end_char=28"
# }, 'det', {
#   "id": 4,
#   "text": "a",
#   "lemma": "a",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Ind|PronType=Art",
#   "head": 5,
#   "deprel": "det",
#   "misc": "start_char=22|end_char=23"
# }), ({
#   "id": 0,
#   "text": "ROOT"
# }, 'root', {
#   "id": 5,
#   "text": "task",
#   "lemma": "task",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 0,
#   "deprel": "root",
#   "misc": "start_char=24|end_char=28"
# }), ({
#   "id": 14,
#   "text": "provided",
#   "lemma": "provide",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 5,
#   "deprel": "acl:relcl",
#   "misc": "start_char=67|end_char=75"
# }, 'mark', {
#   "id": 6,
#   "text": "where",
#   "lemma": "where",
#   "upos": "SCONJ",
#   "xpos": "WRB",
#   "feats": "PronType=Rel",
#   "head": 14,
#   "deprel": "mark",
#   "misc": "start_char=29|end_char=34"
# }), ({
#   "id": 8,
#   "text": "sentence",
#   "lemma": "sentence",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 14,
#   "deprel": "nsubj:pass",
#   "misc": "start_char=37|end_char=45"
# }, 'det', {
#   "id": 7,
#   "text": "a",
#   "lemma": "a",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Ind|PronType=Art",
#   "head": 8,
#   "deprel": "det",
#   "misc": "start_char=35|end_char=36"
# }), ({
#   "id": 14,
#   "text": "provided",
#   "lemma": "provide",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 5,
#   "deprel": "acl:relcl",
#   "misc": "start_char=67|end_char=75"
# }, 'nsubj:pass', {
#   "id": 8,
#   "text": "sentence",
#   "lemma": "sentence",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 14,
#   "deprel": "nsubj:pass",
#   "misc": "start_char=37|end_char=45"
# }), ({
#   "id": 10,
#   "text": "sample",
#   "lemma": "sample",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 8,
#   "deprel": "conj",
#   "misc": "start_char=49|end_char=55"
# }, 'cc', {
#   "id": 9,
#   "text": "or",
#   "lemma": "or",
#   "upos": "CCONJ",
#   "xpos": "CC",
#   "head": 10,
#   "deprel": "cc",
#   "misc": "start_char=46|end_char=48"
# }), ({
#   "id": 8,
#   "text": "sentence",
#   "lemma": "sentence",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 14,
#   "deprel": "nsubj:pass",
#   "misc": "start_char=37|end_char=45"
# }, 'conj', {
#   "id": 10,
#   "text": "sample",
#   "lemma": "sample",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 8,
#   "deprel": "conj",
#   "misc": "start_char=49|end_char=55"
# }), ({
#   "id": 12,
#   "text": "text",
#   "lemma": "text",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 8,
#   "deprel": "nmod",
#   "misc": "start_char=59|end_char=63"
# }, 'case', {
#   "id": 11,
#   "text": "of",
#   "lemma": "of",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 12,
#   "deprel": "case",
#   "misc": "start_char=56|end_char=58"
# }), ({
#   "id": 8,
#   "text": "sentence",
#   "lemma": "sentence",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 14,
#   "deprel": "nsubj:pass",
#   "misc": "start_char=37|end_char=45"
# }, 'nmod', {
#   "id": 12,
#   "text": "text",
#   "lemma": "text",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 8,
#   "deprel": "nmod",
#   "misc": "start_char=59|end_char=63"
# }), ({
#   "id": 14,
#   "text": "provided",
#   "lemma": "provide",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 5,
#   "deprel": "acl:relcl",
#   "misc": "start_char=67|end_char=75"
# }, 'aux:pass', {
#   "id": 13,
#   "text": "is",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBZ",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#   "head": 14,
#   "deprel": "aux:pass",
#   "misc": "start_char=64|end_char=66"
# }), ({
#   "id": 5,
#   "text": "task",
#   "lemma": "task",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 0,
#   "deprel": "root",
#   "misc": "start_char=24|end_char=28"
# }, 'acl:relcl', {
#   "id": 14,
#   "text": "provided",
#   "lemma": "provide",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 5,
#   "deprel": "acl:relcl",
#   "misc": "start_char=67|end_char=75"
# }), ({
#   "id": 19,
#   "text": "asked",
#   "lemma": "ask",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 14,
#   "deprel": "advcl",
#   "misc": "start_char=101|end_char=106"
# }, 'mark', {
#   "id": 15,
#   "text": "from",
#   "lemma": "from",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 19,
#   "deprel": "mark",
#   "misc": "start_char=76|end_char=80"
# }), ({
#   "id": 17,
#   "text": "questions",
#   "lemma": "question",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 19,
#   "deprel": "nsubj:pass",
#   "misc": "start_char=87|end_char=96"
# }, 'det', {
#   "id": 16,
#   "text": "which",
#   "lemma": "which",
#   "upos": "DET",
#   "xpos": "WDT",
#   "feats": "PronType=Int",
#   "head": 17,
#   "deprel": "det",
#   "misc": "start_char=81|end_char=86"
# }), ({
#   "id": 19,
#   "text": "asked",
#   "lemma": "ask",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 14,
#   "deprel": "advcl",
#   "misc": "start_char=101|end_char=106"
# }, 'nsubj:pass', {
#   "id": 17,
#   "text": "questions",
#   "lemma": "question",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 19,
#   "deprel": "nsubj:pass",
#   "misc": "start_char=87|end_char=96"
# }), ({
#   "id": 19,
#   "text": "asked",
#   "lemma": "ask",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 14,
#   "deprel": "advcl",
#   "misc": "start_char=101|end_char=106"
# }, 'aux:pass', {
#   "id": 18,
#   "text": "are",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBP",
#   "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#   "head": 19,
#   "deprel": "aux:pass",
#   "misc": "start_char=97|end_char=100"
# }), ({
#   "id": 14,
#   "text": "provided",
#   "lemma": "provide",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 5,
#   "deprel": "acl:relcl",
#   "misc": "start_char=67|end_char=75"
# }, 'advcl', {
#   "id": 19,
#   "text": "asked",
#   "lemma": "ask",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 14,
#   "deprel": "advcl",
#   "misc": "start_char=101|end_char=106"
# }), ({
#   "id": 23,
#   "text": "answered",
#   "lemma": "answer",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 19,
#   "deprel": "conj",
#   "misc": "start_char=119|end_char=127"
# }, 'cc', {
#   "id": 20,
#   "text": "and",
#   "lemma": "and",
#   "upos": "CCONJ",
#   "xpos": "CC",
#   "head": 23,
#   "deprel": "cc",
#   "misc": "start_char=107|end_char=110"
# }), ({
#   "id": 23,
#   "text": "answered",
#   "lemma": "answer",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 19,
#   "deprel": "conj",
#   "misc": "start_char=119|end_char=127"
# }, 'aux', {
#   "id": 21,
#   "text": "must",
#   "lemma": "must",
#   "upos": "AUX",
#   "xpos": "MD",
#   "feats": "VerbForm=Fin",
#   "head": 23,
#   "deprel": "aux",
#   "misc": "start_char=111|end_char=115"
# }), ({
#   "id": 23,
#   "text": "answered",
#   "lemma": "answer",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 19,
#   "deprel": "conj",
#   "misc": "start_char=119|end_char=127"
# }, 'aux:pass', {
#   "id": 22,
#   "text": "be",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": 23,
#   "deprel": "aux:pass",
#   "misc": "start_char=116|end_char=118"
# }), ({
#   "id": 19,
#   "text": "asked",
#   "lemma": "ask",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 14,
#   "deprel": "advcl",
#   "misc": "start_char=101|end_char=106"
# }, 'conj', {
#   "id": 23,
#   "text": "answered",
#   "lemma": "answer",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 19,
#   "deprel": "conj",
#   "misc": "start_char=119|end_char=127"
# }), ({
#   "id": 5,
#   "text": "task",
#   "lemma": "task",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 0,
#   "deprel": "root",
#   "misc": "start_char=24|end_char=28"
# }, 'punct', {
#   "id": 24,
#   "text": ".",
#   "lemma": ".",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 5,
#   "deprel": "punct",
#   "misc": "start_char=127|end_char=128"
# })]

# %%
for sentence in doc.sentences:
    for word in sentence.words:
        print("{:12s}\t{:12s}\t{:6s}".format(word.text, word.lemma, word.pos))
# Out:
# Question    	question    	NOUN
# answering   	answer      	NOUN
# is          	be          	AUX
# a           	a           	DET
# task        	task        	NOUN
# where       	where       	SCONJ
# a           	a           	DET
# sentence    	sentence    	NOUN
# or          	or          	CCONJ
# sample      	sample      	NOUN
# of          	of          	ADP
# text        	text        	NOUN
# is          	be          	AUX
# provided    	provide     	VERB
# from        	from        	ADP
# which       	which       	DET
# questions   	question    	NOUN
# are         	be          	AUX
# asked       	ask         	VERB
# and         	and         	CCONJ
# must        	must        	AUX
# be          	be          	AUX
# answered    	answer      	VERB
# .           	.           	PUNCT

# %%
stanza.download('hi')
hi_nlp = stanza.Pipeline('hi')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 27.7MB/s]
# 2021-03-01 10:14:20 INFO: Downloading default packages for language: hi (Hindi)...
# 2021-03-01 10:14:21 INFO: File exists: /root/stanza_resources/hi/default.zip.
# 2021-03-01 10:14:23 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-03-01 10:14:23 INFO: Loading these models for language: hi (Hindi):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | hdtb    |
# | pos       | hdtb    |
# | lemma     | hdtb    |
# | depparse  | hdtb    |
# =======================
#
# 2021-03-01 10:14:23 INFO: Use device: cpu
# 2021-03-01 10:14:23 INFO: Loading: tokenize
# 2021-03-01 10:14:23 INFO: Loading: pos
# 2021-03-01 10:14:23 INFO: Loading: lemma
# 2021-03-01 10:14:23 INFO: Loading: depparse
# 2021-03-01 10:14:24 INFO: Done loading processors!

# %%
hindi_doc = hi_nlp("प्रश्न का उत्तर देना एक ऐसा कार्य है जहाँ एक वाक्य या पाठ का नमूना प्रदान किया जाता है जहाँ से प्रश्न पूछे जाते हैं और उसका उत्तर दिया जाना चाहिए।")

# %%
for sentence in hindi_doc.sentences:
    for word in sentence.words:
        print("{:12s}\t{:12s}\t{:6s}".format(word.text, word.lemma, word.pos))
# Out:
# प्रश्न      	प्रश्न      	NOUN
# का          	का          	ADP
# उत्तर       	उत्तर       	NOUN
# देना        	दे          	VERB
# एक          	एक          	NUM
# ऐसा         	ऐसा         	DET
# कार्य       	कार्य       	NOUN
# है          	है          	VERB
# जहाँ        	जहाँ        	PRON
# एक          	एक          	NUM
# वाक्य       	वाक्य       	NOUN
# या          	या          	CCONJ
# पाठ         	पाठ         	NOUN
# का          	का          	ADP
# नमूना       	नमूना       	NOUN
# प्रदान      	प्रदान      	NOUN
# किया        	कर          	VERB
# जाता        	जा          	AUX
# है          	है          	AUX
# जहाँ        	जहाँ        	PRON
# से          	से          	ADP
# प्रश्न      	प्रश्न      	NOUN
# पूछे        	पूछ         	VERB
# जाते        	जा          	AUX
# हैं         	है          	AUX
# और          	और          	CCONJ
# उसका        	वह          	PRON
# उत्तर       	उत्तर       	NOUN
# दिया        	दे          	VERB
# जाना        	जा          	AUX
# चाहिए       	चाहिए       	AUX
# ।           	।           	PUNCT

# %%
for sentence in hindi_doc.sentences:
    print(sentence.ents)
    print(sentence.dependencies)
# Out:
# []
# [({
#   "id": 3,
#   "text": "उत्तर",
#   "lemma": "उत्तर",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#   "head": 4,
#   "deprel": "obj",
#   "misc": "start_char=10|end_char=15"
# }, 'nmod', {
#   "id": 1,
#   "text": "प्रश्न",
#   "lemma": "प्रश्न",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#   "head": 3,
#   "deprel": "nmod",
#   "misc": "start_char=0|end_char=6"
# }), ({
#   "id": 1,
#   "text": "प्रश्न",
#   "lemma": "प्रश्न",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#   "head": 3,
#   "deprel": "nmod",
#   "misc": "start_char=0|end_char=6"
# }, 'case', {
#   "id": 2,
#   "text": "का",
#   "lemma": "का",
#   "upos": "ADP",
#   "xpos": "PSP",
#   "feats": "AdpType=Post|Case=Nom|Gender=Masc|Number=Sing",
#   "head": 1,
#   "deprel": "case",
#   "misc": "start_char=7|end_char=9"
# }), ({
#   "id": 4,
#   "text": "देना",
#   "lemma": "दे",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Case=Nom|VerbForm=Inf",
#   "head": 8,
#   "deprel": "nsubj",
#   "misc": "start_char=16|end_char=20"
# }, 'obj', {
#   "id": 3,
#   "text": "उत्तर",
#   "lemma": "उत्तर",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#   "head": 4,
#   "deprel": "obj",
#   "misc": "start_char=10|end_char=15"
# }), ({
#   "id": 8,
#   "text": "है",
#   "lemma": "है",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#   "head": 0,
#   "deprel": "root",
#   "misc": "start_char=34|end_char=36"
# }, 'nsubj', {
#   "id": 4,
#   "text": "देना",
#   "lemma": "दे",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Case=Nom|VerbForm=Inf",
#   "head": 8,
#   "deprel": "nsubj",
#   "misc": "start_char=16|end_char=20"
# }), ({
#   "id": 7,
#   "text": "कार्य",
#   "lemma": "कार्य",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#   "head": 8,
#   "deprel": "obj",
#   "misc": "start_char=28|end_char=33"
# }, 'nummod', {
#   "id": 5,
#   "text": "एक",
#   "lemma": "एक",
#   "upos": "NUM",
#   "xpos": "QC",
#   "feats": "NumType=Card",
#   "head": 7,
#   "deprel": "nummod",
#   "misc": "start_char=21|end_char=23"
# }), ({
#   "id": 7,
#   "text": "कार्य",
#   "lemma": "कार्य",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#   "head": 8,
#   "deprel": "obj",
#   "misc": "start_char=28|end_char=33"
# }, 'det', {
#   "id": 6,
#   "text": "ऐसा",
#   "lemma": "ऐसा",
#   "upos": "DET",
#   "xpos": "DEM",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|PronType=Dem",
#   "head": 7,
#   "deprel": "det",
#   "misc": "start_char=24|end_char=27"
# }), ({
#   "id": 8,
#   "text": "है",
#   "lemma": "है",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#   "head": 0,
#   "deprel": "root",
#   "misc": "start_char=34|end_char=36"
# }, 'obj', {
#   "id": 7,
#   "text": "कार्य",
#   "lemma": "कार्य",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#   "head": 8,
#   "deprel": "obj",
#   "misc": "start_char=28|end_char=33"
# }), ({
#   "id": 0,
#   "text": "ROOT"
# }, 'root', {
#   "id": 8,
#   "text": "है",
#   "lemma": "है",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#   "head": 0,
#   "deprel": "root",
#   "misc": "start_char=34|end_char=36"
# }), ({
#   "id": 17,
#   "text": "किया",
#   "lemma": "कर",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|Number=Sing|Person=3|VerbForm=Part|Voice=Pass",
#   "head": 7,
#   "deprel": "acl:relcl",
#   "misc": "start_char=74|end_char=78"
# }, 'obl', {
#   "id": 9,
#   "text": "जहाँ",
#   "lemma": "जहाँ",
#   "upos": "PRON",
#   "xpos": "PRP",
#   "feats": "Case=Nom|PronType=Prs",
#   "head": 17,
#   "deprel": "obl",
#   "misc": "start_char=37|end_char=41"
# }), ({
#   "id": 11,
#   "text": "वाक्य",
#   "lemma": "वाक्य",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#   "head": 15,
#   "deprel": "nmod",
#   "misc": "start_char=45|end_char=50"
# }, 'nummod', {
#   "id": 10,
#   "text": "एक",
#   "lemma": "एक",
#   "upos": "NUM",
#   "xpos": "QC",
#   "feats": "NumType=Card",
#   "head": 11,
#   "deprel": "nummod",
#   "misc": "start_char=42|end_char=44"
# }), ({
#   "id": 15,
#   "text": "नमूना",
#   "lemma": "नमूना",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#   "head": 17,
#   "deprel": "obj",
#   "misc": "start_char=61|end_char=66"
# }, 'nmod', {
#   "id": 11,
#   "text": "वाक्य",
#   "lemma": "वाक्य",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#   "head": 15,
#   "deprel": "nmod",
#   "misc": "start_char=45|end_char=50"
# }), ({
#   "id": 13,
#   "text": "पाठ",
#   "lemma": "पाठ",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#   "head": 11,
#   "deprel": "conj",
#   "misc": "start_char=54|end_char=57"
# }, 'cc', {
#   "id": 12,
#   "text": "या",
#   "lemma": "या",
#   "upos": "CCONJ",
#   "xpos": "CC",
#   "head": 13,
#   "deprel": "cc",
#   "misc": "start_char=51|end_char=53"
# }), ({
#   "id": 11,
#   "text": "वाक्य",
#   "lemma": "वाक्य",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#   "head": 15,
#   "deprel": "nmod",
#   "misc": "start_char=45|end_char=50"
# }, 'conj', {
#   "id": 13,
#   "text": "पाठ",
#   "lemma": "पाठ",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#   "head": 11,
#   "deprel": "conj",
#   "misc": "start_char=54|end_char=57"
# }), ({
#   "id": 11,
#   "text": "वाक्य",
#   "lemma": "वाक्य",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#   "head": 15,
#   "deprel": "nmod",
#   "misc": "start_char=45|end_char=50"
# }, 'case', {
#   "id": 14,
#   "text": "का",
#   "lemma": "का",
#   "upos": "ADP",
#   "xpos": "PSP",
#   "feats": "AdpType=Post|Case=Nom|Gender=Masc|Number=Sing",
#   "head": 11,
#   "deprel": "case",
#   "misc": "start_char=58|end_char=60"
# }), ({
#   "id": 17,
#   "text": "किया",
#   "lemma": "कर",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|Number=Sing|Person=3|VerbForm=Part|Voice=Pass",
#   "head": 7,
#   "deprel": "acl:relcl",
#   "misc": "start_char=74|end_char=78"
# }, 'obj', {
#   "id": 15,
#   "text": "नमूना",
#   "lemma": "नमूना",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#   "head": 17,
#   "deprel": "obj",
#   "misc": "start_char=61|end_char=66"
# }), ({
#   "id": 17,
#   "text": "किया",
#   "lemma": "कर",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|Number=Sing|Person=3|VerbForm=Part|Voice=Pass",
#   "head": 7,
#   "deprel": "acl:relcl",
#   "misc": "start_char=74|end_char=78"
# }, 'compound', {
#   "id": 16,
#   "text": "प्रदान",
#   "lemma": "प्रदान",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#   "head": 17,
#   "deprel": "compound",
#   "misc": "start_char=67|end_char=73"
# }), ({
#   "id": 7,
#   "text": "कार्य",
#   "lemma": "कार्य",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#   "head": 8,
#   "deprel": "obj",
#   "misc": "start_char=28|end_char=33"
# }, 'acl:relcl', {
#   "id": 17,
#   "text": "किया",
#   "lemma": "कर",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|Number=Sing|Person=3|VerbForm=Part|Voice=Pass",
#   "head": 7,
#   "deprel": "acl:relcl",
#   "misc": "start_char=74|end_char=78"
# }), ({
#   "id": 17,
#   "text": "किया",
#   "lemma": "कर",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|Number=Sing|Person=3|VerbForm=Part|Voice=Pass",
#   "head": 7,
#   "deprel": "acl:relcl",
#   "misc": "start_char=74|end_char=78"
# }, 'aux:pass', {
#   "id": 18,
#   "text": "जाता",
#   "lemma": "जा",
#   "upos": "AUX",
#   "xpos": "VAUX",
#   "feats": "Aspect=Imp|Gender=Masc|Number=Sing|VerbForm=Part",
#   "head": 17,
#   "deprel": "aux:pass",
#   "misc": "start_char=79|end_char=83"
# }), ({
#   "id": 17,
#   "text": "किया",
#   "lemma": "कर",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|Number=Sing|Person=3|VerbForm=Part|Voice=Pass",
#   "head": 7,
#   "deprel": "acl:relcl",
#   "misc": "start_char=74|end_char=78"
# }, 'aux:pass', {
#   "id": 19,
#   "text": "है",
#   "lemma": "है",
#   "upos": "AUX",
#   "xpos": "VAUX",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#   "head": 17,
#   "deprel": "aux:pass",
#   "misc": "start_char=84|end_char=86"
# }), ({
#   "id": 23,
#   "text": "पूछे",
#   "lemma": "पूछ",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|Number=Plur|Person=3|VerbForm=Part|Voice=Act",
#   "head": 15,
#   "deprel": "acl:relcl",
#   "misc": "start_char=102|end_char=106"
# }, 'obl', {
#   "id": 20,
#   "text": "जहाँ",
#   "lemma": "जहाँ",
#   "upos": "PRON",
#   "xpos": "PRP",
#   "feats": "Case=Acc|PronType=Prs",
#   "head": 23,
#   "deprel": "obl",
#   "misc": "start_char=87|end_char=91"
# }), ({
#   "id": 20,
#   "text": "जहाँ",
#   "lemma": "जहाँ",
#   "upos": "PRON",
#   "xpos": "PRP",
#   "feats": "Case=Acc|PronType=Prs",
#   "head": 23,
#   "deprel": "obl",
#   "misc": "start_char=87|end_char=91"
# }, 'case', {
#   "id": 21,
#   "text": "से",
#   "lemma": "से",
#   "upos": "ADP",
#   "xpos": "PSP",
#   "feats": "AdpType=Post",
#   "head": 20,
#   "deprel": "case",
#   "misc": "start_char=92|end_char=94"
# }), ({
#   "id": 23,
#   "text": "पूछे",
#   "lemma": "पूछ",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|Number=Plur|Person=3|VerbForm=Part|Voice=Act",
#   "head": 15,
#   "deprel": "acl:relcl",
#   "misc": "start_char=102|end_char=106"
# }, 'obj', {
#   "id": 22,
#   "text": "प्रश्न",
#   "lemma": "प्रश्न",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Plur|Person=3",
#   "head": 23,
#   "deprel": "obj",
#   "misc": "start_char=95|end_char=101"
# }), ({
#   "id": 15,
#   "text": "नमूना",
#   "lemma": "नमूना",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#   "head": 17,
#   "deprel": "obj",
#   "misc": "start_char=61|end_char=66"
# }, 'acl:relcl', {
#   "id": 23,
#   "text": "पूछे",
#   "lemma": "पूछ",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|Number=Plur|Person=3|VerbForm=Part|Voice=Act",
#   "head": 15,
#   "deprel": "acl:relcl",
#   "misc": "start_char=102|end_char=106"
# }), ({
#   "id": 23,
#   "text": "पूछे",
#   "lemma": "पूछ",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|Number=Plur|Person=3|VerbForm=Part|Voice=Act",
#   "head": 15,
#   "deprel": "acl:relcl",
#   "misc": "start_char=102|end_char=106"
# }, 'aux:pass', {
#   "id": 24,
#   "text": "जाते",
#   "lemma": "जा",
#   "upos": "AUX",
#   "xpos": "VAUX",
#   "feats": "Aspect=Imp|Gender=Masc|Number=Plur|VerbForm=Part",
#   "head": 23,
#   "deprel": "aux:pass",
#   "misc": "start_char=107|end_char=111"
# }), ({
#   "id": 23,
#   "text": "पूछे",
#   "lemma": "पूछ",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|Number=Plur|Person=3|VerbForm=Part|Voice=Act",
#   "head": 15,
#   "deprel": "acl:relcl",
#   "misc": "start_char=102|end_char=106"
# }, 'aux:pass', {
#   "id": 25,
#   "text": "हैं",
#   "lemma": "है",
#   "upos": "AUX",
#   "xpos": "VAUX",
#   "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#   "head": 23,
#   "deprel": "aux:pass",
#   "misc": "start_char=112|end_char=115"
# }), ({
#   "id": 29,
#   "text": "दिया",
#   "lemma": "दे",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|VerbForm=Part|Voice=Pass",
#   "head": 23,
#   "deprel": "conj",
#   "misc": "start_char=130|end_char=134"
# }, 'cc', {
#   "id": 26,
#   "text": "और",
#   "lemma": "और",
#   "upos": "CCONJ",
#   "xpos": "CC",
#   "head": 29,
#   "deprel": "cc",
#   "misc": "start_char=116|end_char=118"
# }), ({
#   "id": 28,
#   "text": "उत्तर",
#   "lemma": "उत्तर",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#   "head": 29,
#   "deprel": "obj",
#   "misc": "start_char=124|end_char=129"
# }, 'nmod', {
#   "id": 27,
#   "text": "उसका",
#   "lemma": "वह",
#   "upos": "PRON",
#   "xpos": "PRP",
#   "feats": "Case=Acc,Gen|Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs",
#   "head": 28,
#   "deprel": "nmod",
#   "misc": "start_char=119|end_char=123"
# }), ({
#   "id": 29,
#   "text": "दिया",
#   "lemma": "दे",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|VerbForm=Part|Voice=Pass",
#   "head": 23,
#   "deprel": "conj",
#   "misc": "start_char=130|end_char=134"
# }, 'obj', {
#   "id": 28,
#   "text": "उत्तर",
#   "lemma": "उत्तर",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#   "head": 29,
#   "deprel": "obj",
#   "misc": "start_char=124|end_char=129"
# }), ({
#   "id": 23,
#   "text": "पूछे",
#   "lemma": "पूछ",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|Number=Plur|Person=3|VerbForm=Part|Voice=Act",
#   "head": 15,
#   "deprel": "acl:relcl",
#   "misc": "start_char=102|end_char=106"
# }, 'conj', {
#   "id": 29,
#   "text": "दिया",
#   "lemma": "दे",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|VerbForm=Part|Voice=Pass",
#   "head": 23,
#   "deprel": "conj",
#   "misc": "start_char=130|end_char=134"
# }), ({
#   "id": 29,
#   "text": "दिया",
#   "lemma": "दे",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|VerbForm=Part|Voice=Pass",
#   "head": 23,
#   "deprel": "conj",
#   "misc": "start_char=130|end_char=134"
# }, 'aux:pass', {
#   "id": 30,
#   "text": "जाना",
#   "lemma": "जा",
#   "upos": "AUX",
#   "xpos": "VAUX",
#   "feats": "Gender=Masc|Number=Sing|VerbForm=Inf",
#   "head": 29,
#   "deprel": "aux:pass",
#   "misc": "start_char=135|end_char=139"
# }), ({
#   "id": 29,
#   "text": "दिया",
#   "lemma": "दे",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Aspect=Perf|Gender=Masc|VerbForm=Part|Voice=Pass",
#   "head": 23,
#   "deprel": "conj",
#   "misc": "start_char=130|end_char=134"
# }, 'aux:pass', {
#   "id": 31,
#   "text": "चाहिए",
#   "lemma": "चाहिए",
#   "upos": "AUX",
#   "xpos": "VAUX",
#   "head": 29,
#   "deprel": "aux:pass",
#   "misc": "start_char=140|end_char=145"
# }), ({
#   "id": 8,
#   "text": "है",
#   "lemma": "है",
#   "upos": "VERB",
#   "xpos": "VM",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#   "head": 0,
#   "deprel": "root",
#   "misc": "start_char=34|end_char=36"
# }, 'punct', {
#   "id": 32,
#   "text": "।",
#   "lemma": "।",
#   "upos": "PUNCT",
#   "xpos": "SYM",
#   "head": 8,
#   "deprel": "punct",
#   "misc": "start_char=145|end_char=146"
# })]

# %%
for i, sent in enumerate(hindi_doc.sentences):
    print("[Sentence {}]".format(i+1))
    for word in sent.words:
        print("{:12s}\t{:12s}\t{:6s}\t{:d}\t{:12s}".format(\
              word.text, word.lemma, word.pos, word.head, word.deprel))
    print("")
# Out:
# [Sentence 1]
# प्रश्न      	प्रश्न      	NOUN  	3	nmod
# का          	का          	ADP   	1	case
# उत्तर       	उत्तर       	NOUN  	4	obj
# देना        	दे          	VERB  	8	nsubj
# एक          	एक          	NUM   	7	nummod
# ऐसा         	ऐसा         	DET   	7	det
# कार्य       	कार्य       	NOUN  	8	obj
# है          	है          	VERB  	0	root
# जहाँ        	जहाँ        	PRON  	17	obl
# एक          	एक          	NUM   	11	nummod
# वाक्य       	वाक्य       	NOUN  	15	nmod
# या          	या          	CCONJ 	13	cc
# पाठ         	पाठ         	NOUN  	11	conj
# का          	का          	ADP   	11	case
# नमूना       	नमूना       	NOUN  	17	obj
# प्रदान      	प्रदान      	NOUN  	17	compound
# किया        	कर          	VERB  	7	acl:relcl
# जाता        	जा          	AUX   	17	aux:pass
# है          	है          	AUX   	17	aux:pass
# जहाँ        	जहाँ        	PRON  	23	obl
# से          	से          	ADP   	20	case
# प्रश्न      	प्रश्न      	NOUN  	23	obj
# पूछे        	पूछ         	VERB  	15	acl:relcl
# जाते        	जा          	AUX   	23	aux:pass
# हैं         	है          	AUX   	23	aux:pass
# और          	और          	CCONJ 	29	cc
# उसका        	वह          	PRON  	28	nmod
# उत्तर       	उत्तर       	NOUN  	29	obj
# दिया        	दे          	VERB  	23	conj
# जाना        	जा          	AUX   	29	aux:pass
# चाहिए       	चाहिए       	AUX   	29	aux:pass
# ।           	।           	PUNCT 	8	punct

# %%
stanza.download('en', package = 'partut',verbose=True)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 21.8MB/s]
# 2021-03-01 09:21:03 INFO: Downloading these customized packages for language: en (English)...
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | partut  |
# | mwt       | partut  |
# | pos       | partut  |
# | lemma     | partut  |
# | depparse  | partut  |
# | pretrain  | partut  |
# =======================
#
# 2021-03-01 09:21:03 INFO: File exists: /root/stanza_resources/en/tokenize/partut.pt.
# 2021-03-01 09:21:03 INFO: File exists: /root/stanza_resources/en/mwt/partut.pt.
# 2021-03-01 09:21:03 INFO: File exists: /root/stanza_resources/en/pos/partut.pt.
# 2021-03-01 09:21:03 INFO: File exists: /root/stanza_resources/en/lemma/partut.pt.
# Downloading English model...
# 2021-03-01 09:21:03 INFO: File exists: /root/stanza_resources/en/depparse/partut.pt.
# 2021-03-01 09:21:04 INFO: File exists: /root/stanza_resources/en/pretrain/partut.pt.
# 2021-03-01 09:21:04 INFO: Finished downloading models and saved to /root/stanza_resources.

# %%
stanza.download('en', package = 'lines', processors='tokenize,pos', verbose=True)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 28.5MB/s]
# 2021-03-01 09:27:12 INFO: Downloading these customized packages for language: en (English)...
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | lines   |
# | pos       | lines   |
# | pretrain  | lines   |
# =======================
# Downloading English model...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/tokenize/lines.pt: 100%|██████████| 626k/626k [00:00<00:00, 3.12MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/pos/lines.pt: 100%|██████████| 18.3M/18.3M [00:00<00:00, 20.8MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/pretrain/lines.pt: 100%|██████████| 107M/107M [00:24<00:00, 4.36MB/s]
# 2021-03-01 09:27:38 INFO: Finished downloading models and saved to /root/stanza_resources.

# %%
stanza.download('en', package = 'partut' , verbose=True)
nlp = stanza.Pipeline('en', package = 'partut')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 29.8MB/s]
# 2021-03-01 09:33:34 INFO: Downloading these customized packages for language: en (English)...
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | partut  |
# | mwt       | partut  |
# | pos       | partut  |
# | lemma     | partut  |
# | depparse  | partut  |
# | pretrain  | partut  |
# =======================
#
# 2021-03-01 09:33:35 INFO: File exists: /root/stanza_resources/en/tokenize/partut.pt.
# 2021-03-01 09:33:35 INFO: File exists: /root/stanza_resources/en/mwt/partut.pt.
# 2021-03-01 09:33:35 INFO: File exists: /root/stanza_resources/en/pos/partut.pt.
# 2021-03-01 09:33:35 INFO: File exists: /root/stanza_resources/en/lemma/partut.pt.
# 2021-03-01 09:33:35 INFO: File exists: /root/stanza_resources/en/depparse/partut.pt.
# 2021-03-01 09:33:35 INFO: File exists: /root/stanza_resources/en/pretrain/partut.pt.
# 2021-03-01 09:33:35 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-03-01 09:33:35 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | partut  |
# | mwt       | partut  |
# | pos       | partut  |
# | lemma     | partut  |
# | depparse  | partut  |
# =======================
#
# 2021-03-01 09:33:35 INFO: Use device: cpu
# 2021-03-01 09:33:35 INFO: Loading: tokenize
# 2021-03-01 09:33:35 INFO: Loading: mwt
# 2021-03-01 09:33:35 INFO: Loading: pos
# 2021-03-01 09:33:35 INFO: Loading: lemma
# 2021-03-01 09:33:36 INFO: Loading: depparse
# 2021-03-01 09:33:36 INFO: Done loading processors!

# %%
type(nlp)
# Out:
# stanza.pipeline.core.Pipeline

# %%
stanza.download('hi', processors='tokenize,pos')
nlp = stanza.Pipeline('hi', processors='tokenize,pos', verbose = True)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 26.3MB/s]
# 2021-03-01 10:08:13 INFO: Downloading these customized packages for language: hi (Hindi)...
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | hdtb    |
# | pos       | hdtb    |
# | pretrain  | hdtb    |
# =======================
#
# 2021-03-01 10:08:13 INFO: File exists: /root/stanza_resources/hi/tokenize/hdtb.pt.
# 2021-03-01 10:08:13 INFO: File exists: /root/stanza_resources/hi/pos/hdtb.pt.
# 2021-03-01 10:08:13 INFO: File exists: /root/stanza_resources/hi/pretrain/hdtb.pt.
# 2021-03-01 10:08:13 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-03-01 10:08:13 INFO: Loading these models for language: hi (Hindi):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | hdtb    |
# | pos       | hdtb    |
# =======================
#
# 2021-03-01 10:08:13 INFO: Use device: cpu
# 2021-03-01 10:08:13 INFO: Loading: tokenize
# 2021-03-01 10:08:13 INFO: Loading: pos
# 2021-03-01 10:08:13 INFO: Done loading processors!

# %%
stanza.download('it', processors='tokenize,mwt', package='twittiro')
nlp = stanza.Pipeline('it', processors='tokenize,mwt', package='twittiro')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 25.9MB/s]
# 2021-03-01 09:50:23 INFO: Downloading these customized packages for language: it (Italian)...
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | twittiro |
# | mwt       | twittiro |
# ========================
#
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/it/tokenize/twittiro.pt: 100%|██████████| 632k/632k [00:00<00:00, 2.94MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/it/mwt/twittiro.pt: 100%|██████████| 564k/564k [00:00<00:00, 1.16MB/s]
# 2021-03-01 09:50:24 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-03-01 09:50:24 INFO: Loading these models for language: it (Italian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | twittiro |
# | mwt       | twittiro |
# ========================
#
# 2021-03-01 09:50:24 INFO: Use device: cpu
# 2021-03-01 09:50:24 INFO: Loading: tokenize
# 2021-03-01 09:50:24 INFO: Loading: mwt
# 2021-03-01 09:50:24 INFO: Done loading processors!

# %%
stanza.download('nl', processors={'ner': 'conll02'})
nlp = stanza.Pipeline('nl', processors={'ner': 'conll02'})
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 37.7MB/s]
# 2021-03-01 09:58:39 INFO: Downloading these customized packages for language: nl (Dutch)...
# =============================
# | Processor       | Package |
# -----------------------------
# | tokenize        | alpino  |
# | pos             | alpino  |
# | lemma           | alpino  |
# | depparse        | alpino  |
# | ner             | conll02 |
# | forward_charlm  | ccwiki  |
# | pretrain        | alpino  |
# | backward_charlm | ccwiki  |
# =============================
#
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/nl/tokenize/alpino.pt: 100%|██████████| 628k/628k [00:00<00:00, 1.27MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/nl/pos/alpino.pt: 100%|██████████| 20.4M/20.4M [00:04<00:00, 4.17MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/nl/lemma/alpino.pt: 100%|██████████| 3.80M/3.80M [00:00<00:00, 9.85MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/nl/depparse/alpino.pt: 100%|██████████| 98.2M/98.2M [00:16<00:00, 6.05MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/nl/ner/conll02.pt: 100%|██████████| 351M/351M [01:26<00:00, 4.05MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/nl/forward_charlm/ccwiki.pt: 100%|██████████| 20.4M/20.4M [00:01<00:00, 16.8MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/nl/pretrain/alpino.pt: 100%|██████████| 107M/107M [00:23<00:00, 4.52MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/nl/backward_charlm/ccwiki.pt: 100%|██████████| 20.4M/20.4M [00:03<00:00, 6.22MB/s]
# 2021-03-01 10:01:00 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-03-01 10:01:00 INFO: Loading these models for language: nl (Dutch):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | alpino  |
# | pos       | alpino  |
# | lemma     | alpino  |
# | depparse  | alpino  |
# | ner       | conll02 |
# =======================
#
# 2021-03-01 10:01:00 INFO: Use device: cpu
# 2021-03-01 10:01:00 INFO: Loading: tokenize
# 2021-03-01 10:01:00 INFO: Loading: pos
# 2021-03-01 10:01:00 INFO: Loading: lemma
# 2021-03-01 10:01:00 INFO: Loading: depparse
# 2021-03-01 10:01:01 INFO: Loading: ner
# 2021-03-01 10:01:03 INFO: Done loading processors!

# %%
processor_dict = {
    'tokenize': 'gsd',
    'pos': 'hdt',
    'ner': 'conll03',
    'lemma': 'default'
}
stanza.download('de', processors=processor_dict, package=None)
nlp = stanza.Pipeline('de', processors=processor_dict, package=None)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 28.0MB/s]
# 2021-03-01 10:08:16 WARNING: Language de package gsd expects mwt, which has been added
# 2021-03-01 10:08:16 INFO: Downloading these customized packages for language: de (German)...
# ==============================
# | Processor       | Package  |
# ------------------------------
# | tokenize        | gsd      |
# | mwt             | gsd      |
# | pos             | hdt      |
# | lemma           | gsd      |
# | ner             | conll03  |
# | backward_charlm | newswiki |
# | pretrain        | hdt      |
# | forward_charlm  | newswiki |
# ==============================
#
# 2021-03-01 10:08:16 INFO: File exists: /root/stanza_resources/de/tokenize/gsd.pt.
# 2021-03-01 10:08:16 INFO: File exists: /root/stanza_resources/de/mwt/gsd.pt.
# 2021-03-01 10:08:16 INFO: File exists: /root/stanza_resources/de/pos/hdt.pt.
# 2021-03-01 10:08:16 INFO: File exists: /root/stanza_resources/de/lemma/gsd.pt.
# 2021-03-01 10:08:17 INFO: File exists: /root/stanza_resources/de/ner/conll03.pt.
# 2021-03-01 10:08:17 INFO: File exists: /root/stanza_resources/de/backward_charlm/newswiki.pt.
# 2021-03-01 10:08:18 INFO: File exists: /root/stanza_resources/de/pretrain/hdt.pt.
# 2021-03-01 10:08:18 INFO: File exists: /root/stanza_resources/de/forward_charlm/newswiki.pt.
# 2021-03-01 10:08:18 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-03-01 10:08:18 WARNING: Language de package gsd expects mwt, which has been added
# 2021-03-01 10:08:18 INFO: Loading these models for language: de (German):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | gsd     |
# | mwt       | gsd     |
# | pos       | hdt     |
# | lemma     | gsd     |
# | ner       | conll03 |
# =======================
#
# 2021-03-01 10:08:18 INFO: Use device: cpu
# 2021-03-01 10:08:18 INFO: Loading: tokenize
# 2021-03-01 10:08:18 INFO: Loading: mwt
# 2021-03-01 10:08:18 INFO: Loading: pos
# 2021-03-01 10:08:18 INFO: Loading: lemma
# 2021-03-01 10:08:18 INFO: Loading: ner
# 2021-03-01 10:08:20 INFO: Done loading processors!

# %%
from stanza.pipeline.processor import Processor, register_processor, register_processor_variant

@register_processor("lowercase")
class LowercaseProcessor(Processor):
    ''' Processor that lowercases all text '''
    _requires = set(['tokenize'])
    _provides = set(['lowercase'])

    def __init__(self, config, pipeline, use_gpu):
        pass

    def _set_up_model(self, *args):
        pass

    def process(self, doc):
        doc.text = doc.text.lower()
        for sent in doc.sentences:
            for tok in sent.tokens:
                tok.text = tok.text.lower()

            for word in sent.words:
                word.text = word.text.lower()

        return doc

# %%
nlp = stanza.Pipeline(lang='en', processors='tokenize,lowercase')

doc = nlp("Question answering is a task where a sentence or sample of text is provided from which questions are asked and must be answered.")
# Out:
# 2021-03-01 12:01:21 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | lowercase | default  |
# ========================
#
# 2021-03-01 12:01:21 INFO: Use device: cpu
# 2021-03-01 12:01:21 INFO: Loading: tokenize
# 2021-03-01 12:01:21 INFO: Loading: lowercase
# 2021-03-01 12:01:21 INFO: Done loading processors!

# %%
s =[]
for sentence in doc.sentences:
    for word in sentence.words:
        s.append(word.text)
print(" ".join(s))
# Out:
# question answering is a task where a sentence or sample of text is provided from which questions are asked and must be answered .

# %%
import stanza
stanza.download('en', package='craft')
nlp = stanza.Pipeline('en', package='craft')
doc = nlp('A single-cell transcriptomic atlas characterizes ageing tissues in the mouse.')
doc.sentences[0].print_dependencies()
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 23.9MB/s]
# 2021-03-01 11:24:29 INFO: Downloading these customized packages for language: en (English)...
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | craft   |
# | pos       | craft   |
# | lemma     | craft   |
# | depparse  | craft   |
# | pretrain  | craft   |
# =======================
#
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/tokenize/craft.pt: 100%|██████████| 637k/637k [00:00<00:00, 2.97MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/pos/craft.pt: 100%|██████████| 21.6M/21.6M [00:01<00:00, 19.3MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/lemma/craft.pt: 100%|██████████| 4.55M/4.55M [00:00<00:00, 9.79MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/depparse/craft.pt: 100%|██████████| 110M/110M [00:08<00:00, 12.7MB/s]
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/pretrain/craft.pt: 100%|██████████| 82.6M/82.6M [00:07<00:00, 11.5MB/s]
# 2021-03-01 11:24:49 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-03-01 11:24:49 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | craft   |
# | pos       | craft   |
# | lemma     | craft   |
# | depparse  | craft   |
# =======================
#
# 2021-03-01 11:24:49 INFO: Use device: cpu
# 2021-03-01 11:24:49 INFO: Loading: tokenize
# 2021-03-01 11:24:49 INFO: Loading: pos
# 2021-03-01 11:24:50 INFO: Loading: lemma
# 2021-03-01 11:24:50 INFO: Loading: depparse
# 2021-03-01 11:24:50 INFO: Done loading processors!
# ('A', 6, 'det')
# ('single', 4, 'amod')
# ('-', 4, 'punct')
# ('cell', 6, 'compound')
# ('transcriptomic', 6, 'amod')
# ('atlas', 7, 'nsubj')
# ('characterizes', 0, 'root')
# ('ageing', 9, 'compound')
# ('tissues', 7, 'obj')
# ('in', 12, 'case')
# ('the', 12, 'det')
# ('mouse', 7, 'obl')
# ('.', 7, 'punct')

# %%
# mimic pipeline with an i2b2 NER model
stanza.download('en', package='mimic', processors={'ner': 'i2b2'})
nlp = stanza.Pipeline('en', package='mimic', processors={'ner': 'i2b2'})
# annotate clinical text
doc = nlp('The patient had a dry cough and fever, they were treated with Paracetamol.')
# print out the entities
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 25.0MB/s]
# 2021-03-01 11:36:58 INFO: Downloading these customized packages for language: en (English)...
# =============================
# | Processor       | Package |
# -----------------------------
# | tokenize        | mimic   |
# | pos             | mimic   |
# | lemma           | mimic   |
# | depparse        | mimic   |
# | ner             | i2b2    |
# | forward_charlm  | mimic   |
# | pretrain        | mimic   |
# | backward_charlm | mimic   |
# =============================
#
# 2021-03-01 11:36:58 INFO: File exists: /root/stanza_resources/en/tokenize/mimic.pt.
# 2021-03-01 11:36:58 INFO: File exists: /root/stanza_resources/en/pos/mimic.pt.
# 2021-03-01 11:36:58 INFO: File exists: /root/stanza_resources/en/lemma/mimic.pt.
# 2021-03-01 11:36:58 INFO: File exists: /root/stanza_resources/en/depparse/mimic.pt.
# 2021-03-01 11:36:58 INFO: File exists: /root/stanza_resources/en/ner/i2b2.pt.
# 2021-03-01 11:36:58 INFO: File exists: /root/stanza_resources/en/forward_charlm/mimic.pt.
# 2021-03-01 11:36:59 INFO: File exists: /root/stanza_resources/en/pretrain/mimic.pt.
# 2021-03-01 11:36:59 INFO: File exists: /root/stanza_resources/en/backward_charlm/mimic.pt.
# 2021-03-01 11:36:59 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-03-01 11:36:59 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | mimic   |
# | pos       | mimic   |
# | lemma     | mimic   |
# | depparse  | mimic   |
# | ner       | i2b2    |
# =======================
#
# 2021-03-01 11:36:59 INFO: Use device: cpu
# 2021-03-01 11:36:59 INFO: Loading: tokenize
# 2021-03-01 11:36:59 INFO: Loading: pos
# 2021-03-01 11:36:59 INFO: Loading: lemma
# 2021-03-01 11:36:59 INFO: Loading: depparse
# 2021-03-01 11:37:00 INFO: Loading: ner
# 2021-03-01 11:37:00 INFO: Done loading processors!
# a dry cough	PROBLEM
# fever	PROBLEM
# Paracetamol	TREATMENT
