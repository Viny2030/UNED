# %% [markdown]
# <a href="https://colab.research.google.com/github/Viny2030/UNED/blob/main/2_NLPII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***MASTERCLASS NLP***

# %% [markdown]
# # ***Tema 1: Introducción***
# # ¿Qué es un Lenguaje?
# Un Lenguajes es un conjunto potencialmente infinito de oraciones y sentencias de palabras construidas mediante reglas gramaticales, foneticas y de significación que rigen el propio lenguaje.
# Nos encontramos con 3 tipos de lenguajes:
#
# ## ***Lenguaje Natural***: Lengua o idioma que nace espontáneamente de un grupo de hablantes por la necesidad de establecer comunicación verbal. Ejm: Ingles, Castellano, Frances, Italiano, etc.
#
# #***Lenguaje Formal***: Lenguajes diseñados para un ámbito de aplicación concreto, que se definen de manera precisa y libre de ambigüedad. Ejm: Matemático, Lógico, Musical, Programación (C, Java, Python, R, Scala, etc.)
#
# #***Lenguaje Artificial***: Lenguajes diseñados antes de ser usados por sus parlantes. Es una mezcla entre los lenguajes naturales y formales. Ejm: Klingon.

# %% [markdown]
# # ***¿Qué es el Procesamiento del Lenjuaje Natural?***
# El Procesamiento del Lenguaje Natural (NLP) es un campo que combina la Informática, la Inteligencia Artificial y la Lingüística; que tiene como objetivo, tratar la interacción entre los lenguajes humanos (lenguajes naturales) y los dispositivos informáticos.
# El NLP abarca los siguientes campos:
# #**Recuperación** de información
# #**Extracción** y categorización de información
# #**Análisis** automático de texto subjetivo (Análisis de **sentimientos**)
# #**Traducción** automática
# #**Generación** del lenguaje
# #**Questions** & Answering (Chatbots)

# %% [markdown]
# ###En NLP no es suficiente con comprender meras palabras, se deberá comprender al conjunto de palabras que conforman una oración, y al conjunto de lineas que comprenden un párrafo. Dando un sentido global al análisis del texto/discurso para poder sacar buenas conclusiones.
#
# ###Nuestro lenguaje está lleno de ambigüedades, de palabras con distintas acepciones, giros y diversos significados según el contexto. Esto hace que el NLP sea una de las tareas más difíciles de dominar.

# %% [markdown]
# # ***Aplicaciones***

# %% [markdown]
# La lista es inmensa en cuanto a aplicaciones prácticas de las técnicas de NLP a la vida cotidiana. Pero me gustaría remarcar el potencial que tienen para ayudar al diagnóstico clínico y a la mejora de la calidad asistencial de los hospitales y centros de salud.

# %% [markdown]
# La historia clínica electrónica (HCE) es el registro que almacena toda la información de la relación paciente-sistema hospitalario, incluye todos los datos de pruebas clínicas a lo largo de la vida, citas, diagnósticos previos, enfermedades y tratamientos anteriores, intervenciones quirúrgicas etc.

# %% [markdown]
# # ***Otras Aplicaciones:***
# # **Resumen de textos: El algoritmo deberá encontrar la idea central de un artículo e ignorar lo que no sea relevante.**
# # ***ChatBots: deberán ser capaces de mantener una charla fluida con el usuario y responder a sus preguntas de manera automática.***
# # ***Generación automática de keywords y generación de textos siguiendo un estilo particular***
# # ***Reconocimiento de Entidades: encontrar Personas, Entidades comerciales o gubernamentales ó Países, Ciudades, marcas…***
# # ***Análisis de Sentimientos: deberá comprender si un tweet, una review o comentario es positivo ó negativo y en qué magnitud (ó neutro). Muy utilizado en Redes Sociales, en política, opiniones de productos y en motores de recomendación.***
# # ***Traducción automática de Idiomas***
# # ***Clasificación automática de textos en categorías pre-existentes ó a partir de textos completos, detectar los temas recurrentes y crear las categorías.***

# %% [markdown]
# ***De la Lingüística al Procesamiento del Lenguaje Natural***
# ###- Lingüística
# La lingüística es el estudio científico del lenguaje, incluyendo su gramática, semántica y fonética.
# En términos generales, un lingüista es cualquier persona que estudia un idioma.
# ##- Lingüística computacional
# La lingüística computacional es el estudio de la lingüística utilizando las herramientas de la informática.
# ##- Procesamiento estadístico del lenguaje natural
# La lingüística computacional también se conoce con el nombre de Procesamiento del Lenguaje Natural, para reflejar el enfoque más ingenieril o empírico de los métodos estadísticos aplicados a la Lingüistica.
# El dominio estadístico del campo, lleva a menudo a que el NLP sea descrito como Procesamiento Estadístico del Lenguaje Natural, para distanciarse (en la definición) de los métodos clásicos de la lingüística computacional.
# ###- Procesamiento del Lenguaje natural
# Campo que combina la Informática, la Inteligencia Artificial y la Lingüística; que tiene como objetivo, tratar la interacción entre los lenguajes humanos (lenguajes naturales) y los dispositivos informáticos.

# %% [markdown]
# # Natural Language Processing (NLP)
# Gracias al absoluto éxito de ChatGPT en sus inicios (noviembre 2022) y sus sucesores (Bard o Bing Chat) se ha popularizado el término de Procesamiento de Lenguaje Natural (PLN) o Natural Language Processing (NLP).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***Herramientas en Python para el NLP***
# Aunque existen bastante librería en Python destinadas al Procesamiento del Lenguaje Natural o a resolver determinadas partes del NLP, mostramos a continuación una serie de librería que vamos a utilizar en este curso:
#
# ##NLTK (https://www.nltk.org/): Es una librería desarrollada por Steven Bird y Edward Loper para el NLP (principalmente en Inglés) que incorpora muchas funcionalidades como, corpus, recursos léxicos, algoritmos de aprendizaje para el NLP, etc.
#
# ###SpaCy (https://spacy.io/): Es una librería para el NLP incorpora funcionalidades como Tokenización, Lematización, PoS, NER, etc. en varios idiomas. A diferencia de NLTK que tienen fines de caracter didáctico, SpaCy esta pensado para explotarlo en entornos productivos.
#
# ###Gensim (https://radimrehurek.com/gensim): Es una librería desarrollada por el Checo Radim Řehůřek, Ph.D, que tiene implementadas; entre otras cosas, algoritmos como el LSI y el LDA para la detección de tópicos (Topic Modeling)
#
# ##Scikit (https://scikit-learn.org/): Es una librería que tiene implementada multitud de algoritmos de aprendizaje (regresión, clasificación, cluterización, reducción de la dimensionalidad) y funcionalidades para trabajar con estos algoritmos.
#
# ##TensorFlow-Keras (https://www.tensorflow.org/): Es una librería desarrollada por Google para trabajar con Redes Neuronales (MLP, CNN, RNN). La versión 2 de TensorFlow hace uso del API de Keras para un desarrollo más sencillo.

# %% [markdown]
# # ***Conceptos***

# %% [markdown]
# La ambigüedad de lenguaje humano es claramente un desafío para los modelos de NLP, puesto que el significado de muchas frases o expresiones dependen en gran medida del contexto en el que se digan. Por tanto, aprender a tener el contexto de la conversación en cuenta es otro de los desafíos que estos modelos deben resolver.

# %% [markdown]
# El análisis sintáctico y gramatical también es una tarea que deben aprender. Tiene una complejidad añadida puesto que para cada lenguaje, las reglas gramaticales son diferentes por lo que dificulta entender el contexto de las frases.

# %% [markdown]
# Entre estas reglas, también es importante tener en cuenta que el problema de las correferencias. Según la RAE, es la relación entre dos o más elementos lingüísticos cuyo referente es común. Por ejemplo, la que se da entre le y a tu padre en Le doy la carta a tu padre. Ambas referencias son a la misma persona. Para nosotros no supone ningún problema ya que lo hemos aprendido durante nuestra vida, sin embargo para los grandes modelos de lenguaje es un desafío poder identificar y resolver estas correferencias, de nuevo para poder entender el contexto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dado que son modelos basados en machine learning, tienen todos los problemas inherentes a este tipo de inteligencia artificial. Primero, los datos de entrenamiento y la posible escasez de los mismos etiquetados es otro de los problemas a los que se enfrentan, y poder así transformar datos no estructurados como son los de lenguaje humano a datos estructurados donde los modelos puedan extraer patrones.

# %% [markdown]
# En la actualidad el mayor problema de que los modelos comprendan y generen lenguaje humano está en el contexto. Ya que, en general, en todos los idiomas el lenguaje está en constante evolución para ser muy eficiente. Esto conlleva a que se creen contracciones o reutilizaciones de las mismas palabras para significados diferentes dependiendo de la situación en la que se utilicen. Aspectos como por ejemplo, la ironía, el sarcasmo, las metáforas o el humor son un claro desafío.

# %% [markdown]
# # ***Estructura del lenguaje***

# %% [markdown]
# Ver el lenguaje desde un punto de vista linguistico:
# Las características intrínsecas al lenguaje hacen que se agrupen de diferentes formas. Como la morfología que se refiere a la forma y estructura interna de las palabras. En cambio, el léxico se encarga de la segmentación del texto y las palabras en grupos significativos como palabras, veremos más adelante la importancia del léxico en la aplicación del NLP.

# %% [markdown]
# La sintaxis al conjunto de reglas para formar oraciones. En el de la semántica, se refiere a las relaciones existentes entra las oraciones para construir un significado superior. Y también muy importante en este aspecto, la pragmática, una rama de la lingüística que se enfoca en el estudio del uso del lenguaje en el contexto de la comunicación.

# %% [markdown]
# # ***-Arquitectura de analisis  simple para un sistema de diálogo hablado***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***-Análisis léxico***

# %% [markdown]
# # ***En el contexto de la algoritmia, se conoce como «divide y vencerás» a la técnica de resolución de problemas que consiste en descomponer un problema grande y complejo en subproblemas más pequeños, resolver cada subproblema de forma independiente y luego combinar las soluciones para obtener la solución del problema original. En este caso sería aplicable al NLP y al léxico.***

# %% [markdown]
# Como en todo previo entrenamiento de modelo, los datos de entrada se deben pre-procesar. En este caso el primer enfoque a llevar a cabo en la aplicación o en el entrenamiento de modelos de NLP, suele ser este, dividir el texto en unidades básicas que más tarde puedan ser analizadas morfológicamente

# %% [markdown]
# Este proceso de división o segmentación puede ser por frases, separar las distintas frases de un texto. Por ejemplo, las separadas por algún signo de puntuación. Pero también puede hacerse dividiendo las frases de un texto por palabras, tomando como separador un espacio en blanco, algún signo de puntuación o un salto de línea o retorno de carro.

# %% [markdown]
# # ***Tokenización***

# %% [markdown]
# Estas unidades básicas se conocen como tokens. Sin embargo, se debe decidir qué se considera como token a través de un proceso de tokenización. Básicamente se centra en separar el texto o las frases en unidades de procesamiento semántico, es decir con significado.

# %% [markdown]
# En resumen, se puede definir la tokenización como el proceso de división de un texto en unidades más pequeñas llamadas «tokens», que pueden ser palabras, subpalabras o caracteres. Esta división ayuda a estructurar el texto y facilita su procesamiento posterior por modelos y algoritmos de NLP. Es un primer paso de transformación de datos no estructurados a estructurados.

# %% [markdown]
# Puesto que no todo en todo en un texto tiene significado:
#
# ###-Lastvistasrdesdelamontaññanossonbruenas
# ###-Las vistas desde la montaña no son buenas
# ###-Hola, este es tu regalo, es nuevo ¿Te gusta?

# %% [markdown]
# La primera frase no tiene ningún significado, la segunda si, por lo que podrá tokenizarse sin problema. Y la tercera también es correcta, pero tiene muchos signos de puntación que no tienen en el mismo significado que una palabra. Estos tokens tendrán que ser identificados y descartados. Por lo tanto, este proceso es crucial para facilitar y liberar de carga computacional a los modelos. Gracias a bibliotecas y lenguajes como Python y NLTK podemos realizar este proceso de forma fácil y sencilla.

# %% [markdown]
# ##Instalacion biblioteca nltk

# %%
# !pip install nltk

# %%
# !pip show nltk
# Out:
# Name: nltk
# Version: 3.9.1
# Summary: Natural Language Toolkit
# Home-page: https://www.nltk.org/
# Author: NLTK Team
# Author-email: nltk.team@gmail.com
# License: Apache License, Version 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: click, joblib, regex, tqdm
# Required-by: textblob

# %% [markdown]
# ##Tratamiento de palabras y texto

# %% [markdown]
# emojis: https://emojikeyboard.top/es/

# %% [markdown]
# # ***-Carga de palabras y analisis de posicion***

# %%
s = 'prodctivo'
s = s[:4] + 'u' + s[4:]
s
# Out:
# 'productivo'

# %%
'dishes'[:-2]
# Out:
# 'dish'

# %%
'running'[:-4]
# Out:
# 'run'

# %%
###'in'[-5] # fuera del rango

# %%
monty = 'Monty Python'
monty[6:11:2]
# Out:
# 'Pto'

# %%
monty[::-1]
# Out:
# 'nohtyP ytnoM'

# %% [markdown]
# # ***-Proceso de asignacion variable = expresion***

# %%
phrase = ['My', 'very', 'unimaginative', 'phrase','phrase', '.','👍','😉']## proceso de asignacion de variable

# %%
phrase # variable
# Out:
# ['My', 'very', 'unimaginative', 'phrase', 'phrase', '.', '👍', '😉']

# %%
phrase.sort()## ordenamiento de la variable
phrase
# Out:
# ['.', 'My', 'phrase', 'phrase', 'unimaginative', 'very', '👍', '😉']

# %% [markdown]
# _Calculamos la frecuencia de las palabras  de la frase-metodo word_tokenize y calculo de frecuencia

# %%
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist  ## proceso de frecuencia de palabras

# %%
fdist1 = FreqDist(phrase) # se expresa la frecuencia de las palabras en forma de diccionario
fdist1
# Out:
# FreqDist({'phrase': 2, '.': 1, 'My': 1, 'unimaginative': 1, 'very': 1, '👍': 1, '😉': 1})

# %% [markdown]
# # ***-Gráfico acumulativo de la distribución de frecuencia***

# %%
fdist1.plot(50, cumulative=True) # grafico de distribucion acumulada de las palabras es util?
# Out:
# <Axes: xlabel='Samples', ylabel='Cumulative Counts'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fdist1.plot() # grafico de la frecuencia simple es util?
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# -Palabras unicas

# %%
fdist1.items() # palabras unicas
# Out:
# dict_items([('.', 1), ('My', 1), ('phrase', 2), ('unimaginative', 1), ('very', 1), ('👍', 1), ('😉', 1)])

# %%
fdist1.N()# cantidad de palabras con repetidas
# Out:
# 8

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # ***-Ejemplo Trabalenguas***

# %%
frase = 'Tres tristes tigres comen trigo en un trigal.'
frase.split('t') ## divide en letras la variable sin la letra que detallo en el script
# Out:
# ['Tres ', 'ris', 'es ', 'igres comen ', 'rigo en un ', 'rigal.']

# %%
fdisto = FreqDist(frase) # frecuencia de las letras en el texto
fdisto
# Out:
# FreqDist({' ': 7, 'r': 5, 'e': 5, 't': 5, 's': 4, 'i': 4, 'g': 3, 'n': 3, 'o': 2, 'T': 1, ...})

# %%
fdisto.hapaxes() # letras unicas al azar
# Out:
# ['T', 'c', 'm', 'u', 'a', 'l', '.']

# %%
fdisto.N() # cantidad de letras sin espacios ni puntos
# Out:
# 45

# %%
fdisto.plot(50, cumulative=True) ##grafico acumulativo de letras
# Out:
# <Axes: xlabel='Samples', ylabel='Cumulative Counts'>

# %%
fdisto.items()# diccionario de letras y su fecuencia de aparicion acumulada
# Out:
# dict_items([('T', 1), ('r', 5), ('e', 5), ('s', 4), (' ', 7), ('t', 5), ('i', 4), ('g', 3), ('c', 1), ('o', 2), ('m', 1), ('n', 3), ('u', 1), ('a', 1), ('l', 1), ('.', 1)])

# %%
for char in frase[:13]: # recorremos las primeras 13 letras de la frase e imprimimos cada una
    print (char)
# Out:
# T
# r
# e
# s
#
# t
# r
# i
# s
# t
# e
# s

# %%
frase.split()# imprimo la frase completa sin excluir letras
# Out:
# ['Tres', 'tristes', 'tigres', 'comen', 'trigo', 'en', 'un', 'trigal.']

# %%
frase.split(' ')
# Out:
# ['Tres', 'tristes', 'tigres', 'comen', 'trigo', 'en', 'un', 'trigal.']

# %%
frase1 = 'Tres\ttristes\ttigres\tcomen\ttrigo\ten\tun\ttrigal.'
frase1.split()
# Out:
# ['Tres', 'tristes', 'tigres', 'comen', 'trigo', 'en', 'un', 'trigal.']

# %%
frase1.split(' ')
# Out:
# ['Tres\ttristes\ttigres\tcomen\ttrigo\ten\tun\ttrigal.']

# %%
frase2 = 'Tres \ttristes\t\t\ttigres\t\t comen\t \t trigo en un trigal.'
frase2.split()
# Out:
# ['Tres', 'tristes', 'tigres', 'comen', 'trigo', 'en', 'un', 'trigal.']

# %%
frase2.split(' ')
# Out:
# ['Tres',
#  '\ttristes\t\t\ttigres\t\t',
#  'comen\t',
#  '\t',
#  'trigo',
#  'en',
#  'un',
#  'trigal.']

# %%
palabras = frase.split()
print (palabras) # imprimo variable original
palabras.sort() # ordeno las palabras de la variable original en orden reverso
print( palabras)
# Out:
# ['Tres', 'tristes', 'tigres', 'comen', 'trigo', 'en', 'un', 'trigal.']
# ['Tres', 'comen', 'en', 'tigres', 'trigal.', 'trigo', 'tristes', 'un']

# %%
palabras = frase.split()
sorted(palabras)
# Out:
# ['Tres', 'comen', 'en', 'tigres', 'trigal.', 'trigo', 'tristes', 'un']

# %%
palabras
# Out:
# ['Tres', 'tristes', 'tigres', 'comen', 'trigo', 'en', 'un', 'trigal.']

# %% [markdown]
# # ***-Otro ejemplo***

# %%
words = ['is', 'NLP', 'fun', '?']
tmp = words[0] # detallo palabras en posiciones y agrego
words[0] = words[1]
words[1] = tmp
words[3] = '!'
words
# Out:
# ['NLP', 'is', 'fun', '!']

# %%
words = ['is', 'NLP', 'fun', '?']
words[0], words[1], words[3] = words[1], words[0], '!'
words # posiciones
# Out:
# ['NLP', 'is', 'fun', '!']

# %% [markdown]
# # ***Punkt***

# %% [markdown]
# Es el tokenizador de NLTK, el algoritmo que lleva a cabo la tokenización de las palabras que pases por parámetro. Divide el texto en frases a través de un modelo no supervisado, esto es que no necesita datos etiquetados para su entrenamiento, obtendrá patrones de los propios datos. Es entrenable para reconocer abreviaturas o frases que comiencen con las mismas palabras.

# %% [markdown]
# Ahora ya podemos importarlo y descargar los componentes, entre ellos punkt.

# %%
import nltk
nltk.download("punkt")
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Probemos sent_tokenize (sentences_tokenize), nos permite tokenizar algunas frases que ha generado Gemini:

# %%
text = '''En las clases de programacion el alumno comprende todas las instrucciones y ordenes de programacion que el profesor
le sugiere. Muchas veces el profesor no es capaz de comprender las instrucciones y ordenes de programacion que el alumno
escribe. Por lo tanto el alumno debe comprender las instrucciones y ordenes de programacion que el profesor le sugiere.
En las clases de programacion el alumno comprende todas las instrucciones y ordenes de programacion que el profesor le sugiere 😊💪👍'''
print(text)
# Out:
# En las clases de programacion el alumno comprende todas las instrucciones y ordenes de programacion que el profesor
# le sugiere. Muchas veces el profesor no es capaz de comprender las instrucciones y ordenes de programacion que el alumno
# escribe. Por lo tanto el alumno debe comprender las instrucciones y ordenes de programacion que el profesor le sugiere.
# En las clases de programacion el alumno comprende todas las instrucciones y ordenes de programacion que el profesor le sugiere 😊💪👍

# %% [markdown]
# ####_Una cosa es detectar automáticamente que una palabra en particular ocurre en un texto y mostrar algunas palabras que aparecen en el mismo contexto
# ####_Sin embargo, también podemos determinar la ubicación de una palabra en el texto: cuántas palabras del principio aparece.
# ###-Esta información posicional se puede mostrar utilizando una gráfica de dispersión-dispersion_plot, para ello debemos tokenizar el texto primero.

# %%
text
# Out:
# 'En las clases de programacion el alumno comprende todas las instrucciones y ordenes de programacion que el profesor\nle sugiere. Muchas veces el profesor no es capaz de comprender las instrucciones y ordenes de programacion que el alumno\nescribe. Por lo tanto el alumno debe comprender las instrucciones y ordenes de programacion que el profesor le sugiere.\nEn las clases de programacion el alumno comprende todas las instrucciones y ordenes de programacion que el profesor le sugiere 😊💪👍'

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Tokenize the text and create an NLTK Text object
tokens = word_tokenize(text)
text_nltk = nltk.Text(tokens)

# %%
text_nltk.dispersion_plot(["En", "profesor", "instrucciones", "ordenes", "😊"]) # grafico de dispersion donde aparecen algunas  unidades propuestas como token

# %%
sorted(set(text_nltk))# listado por orden alfabetico, primero mayusculas, luego minusculas
# Out:
# ['.',
#  'En',
#  'Muchas',
#  'Por',
#  'alumno',
#  'capaz',
#  'clases',
#  'comprende',
#  'comprender',
#  'de',
#  'debe',
#  'el',
#  'es',
#  'escribe',
#  'instrucciones',
#  'las',
#  'le',
#  'lo',
#  'no',
#  'ordenes',
#  'profesor',
#  'programacion',
#  'que',
#  'sugiere',
#  'tanto',
#  'todas',
#  'veces',
#  'y',
#  '😊💪👍']

# %% [markdown]
# -Cuantas palabras tiene el text?

# %%
len(text)
# Out:
# 487

# %% [markdown]
# -Cuantas veces se repite la palabra Por en el texto?

# %%
text.count('Por')
# Out:
# 1

# %%
text.count('alumno')
# Out:
# 4

# %% [markdown]
# -Que porcentaje representa la palabra alumno en el texto?

# %%
text.count('alumno')/len(text)
# Out:
# 0.008213552361396304

# %% [markdown]
# # ***Tokenización***
# Estas unidades básicas se conocen como tokens. Sin embargo, se debe decidir qué se considera como token a través de un proceso de tokenización. Básicamente se centra en separar el texto o las frases en unidades de procesamiento semántico, es decir con significado.

# %% [markdown]
# ###Divide las cadenas de texto del documento en piezas más pequeñas o tokens.

# %%
print(sent_tokenize(text)) ##El método devuelve una lista de oraciones. Cada oración es a su vez una lista de palabras.
# Out:
# ['En las clases de programacion el alumno comprende todas las instrucciones y ordenes de programacion que el profesor\nle sugiere.', 'Muchas veces el profesor no es capaz de comprender las instrucciones y ordenes de programacion que el alumno\nescribe.', 'Por lo tanto el alumno debe comprender las instrucciones y ordenes de programacion que el profesor le sugiere.', 'En las clases de programacion el alumno comprende todas las instrucciones y ordenes de programacion que el profesor le sugiere 😊💪👍']

# %% [markdown]
# Como vemos le introducimos un texto y la función nos devuelve una lista con las 3 frases que componen el texto y además los emojis como una parte distinta.

# %% [markdown]
# Ahora probemos a tokenizar palabras con word_tokenize:

# %%
print(word_tokenize(text))
# Out:
# ['En', 'las', 'clases', 'de', 'programacion', 'el', 'alumno', 'comprende', 'todas', 'las', 'instrucciones', 'y', 'ordenes', 'de', 'programacion', 'que', 'el', 'profesor', 'le', 'sugiere', '.', 'Muchas', 'veces', 'el', 'profesor', 'no', 'es', 'capaz', 'de', 'comprender', 'las', 'instrucciones', 'y', 'ordenes', 'de', 'programacion', 'que', 'el', 'alumno', 'escribe', '.', 'Por', 'lo', 'tanto', 'el', 'alumno', 'debe', 'comprender', 'las', 'instrucciones', 'y', 'ordenes', 'de', 'programacion', 'que', 'el', 'profesor', 'le', 'sugiere', '.', 'En', 'las', 'clases', 'de', 'programacion', 'el', 'alumno', 'comprende', 'todas', 'las', 'instrucciones', 'y', 'ordenes', 'de', 'programacion', 'que', 'el', 'profesor', 'le', 'sugiere', '😊💪👍']

# %% [markdown]
# # ***-Ejemplo de frases en ingles***

# %%
english = '''Hello, Mr. Smith! How are you today? The weather is great,it's sunny and city is awesome.
The sky is pinkish-blue. You shouldn't eat cardboard. I am going to learn Python.
Yes 😉, I prefer eat sweets.🥳'''
print(english)
# Out:
# Hello, Mr. Smith! How are you today? The weather is great,it's sunny and city is awesome.
# The sky is pinkish-blue. You shouldn't eat cardboard. I am going to learn Python.
# Yes 😉, I prefer eat sweets.🥳

# %%
english
# Out:
# "Hello, Mr. Smith! How are you today? The weather is great,it's sunny and city is awesome.\nThe sky is pinkish-blue. You shouldn't eat cardboard. I am going to learn Python.\nYes 😉, I prefer eat sweets.🥳"

# %%
print(word_tokenize(english))
# Out:
# ['Hello', ',', 'Mr.', 'Smith', '!', 'How', 'are', 'you', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'it', "'s", 'sunny', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard', '.', 'I', 'am', 'going', 'to', 'learn', 'Python', '.', 'Yes', '😉', ',', 'I', 'prefer', 'eat', 'sweets.🥳']

# %% [markdown]
# Vemos dos ejemplos en los que se separan las palabras, en el caso del texto en inglés, nltk entiende que «it´s» es una contracción y lo separa en it y `s.

# %% [markdown]
# Sin embargo, en los lenguajes en general hay muchas palabras que no tienen ningún significado y que simplemente sirven para conectar y no aportan mucho contexto, por lo que los algoritmos las deben obviar para así obtener un mejor rendimiento y mejor entendimiento del lenguaje.

# %% [markdown]
# # ***_Stopwords***

# %% [markdown]
# Cómo eliminar las palabras vacías (Stopwords)
# Son palabras sin significado semántico: artículos, preposiciones, conjunciones, y algunos adverbios. También palabras muy comunes como los verbos modales o verbos frecuentes en el idioma ('to be', 'to have', etc).
#
# Es útil identificar estas palabras en los textos para poder ignorarlas durante la representación de los textos, ya que no añaden información semántica y pueden añadir ruido.
#
# Es necesario descargar el paquete stopwords

# %% [markdown]
# Sin embargo, en los lenguajes en general hay muchas palabras que no tienen ningún significado y que simplemente sirven para conectar y no aportan mucho contexto, por lo que los algoritmos las deben obviar para así obtener un mejor rendimiento y mejor entendimiento del lenguaje.

# %% [markdown]
# NLTK veremos la lista que ofrece para español y para inglés:

# %%
  import nltk
  nltk.download('stopwords')# modulo stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # ***--Stopwords en ingles***

# %%
from nltk.corpus import stopwords

english_sw = set(stopwords.words('english'))

print(english_sw)
# Out:
# {'so', 'themselves', 'hadn', 'because', 'himself', 'been', 'and', 'my', 'being', "you'd", 'against', 'his', 'again', 't', "you've", 'd', 'for', 'than', 'are', 'but', 'from', 'herself', 'be', "shan't", 'above', 'have', 'same', 'whom', "shouldn't", 'as', 'these', 'hasn', 'the', 'm', 'theirs', 'until', 'this', "mustn't", 'few', 'can', 'now', 'which', 'by', 'why', 'on', "wouldn't", 'while', 'nor', 'ma', 'y', 'further', 'shan', 'who', 'our', 'into', 'there', 'should', 'only', 'her', 'ourselves', "should've", 'no', 'both', 'aren', 'those', 'i', 'isn', 'before', 'needn', 'over', 'your', 'through', 'ain', 'or', 'up', 'here', 'ours', 'a', 'were', 'how', 'yours', "you'll", 'at', 'haven', 'not', "hadn't", 'then', 'in', 'any', 'mightn', "she's", 'if', 'don', 'yourself', 've', 'them', 're', "that'll", 'after', "mightn't", 'an', 'between', 'some', "couldn't", 'they', 'having', 'shouldn', 'she', 'about', 'out', 'once', 'down', "don't", 'won', 'me', 'too', 's', 'is', 'myself', 'all', "hasn't", 'will
# ...

# %% [markdown]
# # ***--Stopwords en aleman***

# %%
from nltk.corpus import stopwords

german_sw = set(stopwords.words('german'))

print(german_sw)
# Out:
# {'jener', 'mich', 'anderem', 'ob', 'soll', 'so', 'solchem', 'derselben', 'seines', 'welchem', 'könnte', 'ihres', 'einem', 'können', 'nicht', 'gewesen', 'andern', 'ich', 'derer', 'denselben', 'machen', 'ihm', 'dann', 'denn', 'dieser', 'solche', 'seinem', 'dasselbe', 'aller', 'manches', 'deines', 'deiner', 'dir', 'ohne', 'seiner', 'für', 'wie', 'daß', 'sehr', 'wollte', 'würden', 'viel', 'euch', 'welchen', 'jenen', 'einmal', 'oder', 'die', 'es', 'waren', 'ander', 'deinem', 'dieses', 'manchem', 'sind', 'von', 'solchen', 'vor', 'das', 'jeder', 'diese', 'jetzt', 'anderm', 'hin', 'werde', 'diesem', 'deine', 'anderes', 'nach', 'jedem', 'allem', 'jenes', 'anderr', 'mit', 'war', 'sollte', 'jene', 'einigen', 'weil', 'einiges', 'deinen', 'jenem', 'welche', 'also', 'welches', 'nun', 'du', 'aber', 'den', 'einiger', 'ihr', 'anderen', 'warst', 'habe', 'keines', 'bei', 'dein', 'dessen', 'hier', 'wollen', 'manche', 'wo', 'musste', 'in', 'dieselben', 'ihrem', 'manchen', 'aus', 'eines', 'unsere', 'indem
# ...

# %% [markdown]
# # ***--Stopwords en ruso***

# %%
from nltk.corpus import stopwords

russian_sw = set(stopwords.words('russian'))

print(russian_sw)
# Out:
# {'потому', 'да', 'уж', 'быть', 'до', 'у', 'ему', 'в', 'какой', 'чем', 'все', 'мы', 'того', 'этой', 'себя', 'ее', 'если', 'чтобы', 'будто', 'разве', 'уже', 'перед', 'есть', 'нет', 'тогда', 'здесь', 'теперь', 'чтоб', 'тем', 'куда', 'им', 'ли', 'нибудь', 'о', 'когда', 'два', 'вдруг', 'как', 'над', 'один', 'этом', 'по', 'надо', 'со', 'раз', 'всю', 'или', 'без', 'на', 'будет', 'был', 'этого', 'эти', 'при', 'из', 'к', 'может', 'были', 'наконец', 'него', 'впрочем', 'даже', 'опять', 'он', 'почти', 'так', 'моя', 'была', 'нас', 'ней', 'нельзя', 'всегда', 'во', 'бы', 'тот', 'всего', 'такой', 'тоже', 'мой', 'мне', 'вот', 'себе', 'чуть', 'совсем', 'ну', 'вам', 'ведь', 'не', 'для', 'за', 'ни', 'вас', 'я', 'через', 'а', 'и', 'много', 'ей', 'конечно', 'но', 'них', 'ты', 'всех', 'от', 'тут', 'тебя', 'сейчас', 'между', 'эту', 'их', 'хорошо', 'свою', 'нее', 'они', 'сам', 'еще', 'кто', 'под', 'только', 'то', 'там', 'больше', 'три', 'об', 'ним', 'другой', 'зачем', 'чего', 'иногда', 'хоть', 'ж', 'можно', 
# ...

# %% [markdown]
# # ***--Stopwords en Hebreo***

# %%
from nltk.corpus import stopwords

hebrew_sw = set(stopwords.words('hebrew'))

print(hebrew_sw)
# Out:
# {'איתם', 'איתה', 'כולן', 'מאד', 'אותם', 'מדוע', 'ואילו', 'אחר', 'יותר', 'כך', 'מנין', 'שלך', 'מאיזו סיבה', 'הסיבה שבגללה', 'איתכם', 'מעט', 'ככה', 'זות', 'עם', 'עליהן', 'היה', 'אחרות', 'אחרי', 'מן', 'אף', 'עצמי', 'יכולים', 'אלה', 'מאין', 'לאו', 'מאיפה', 'לבין', 'שלה', 'יוכל', 'למעלה', 'אל', 'לכם', 'באיזו מידה', 'נגד', 'ברם', 'עליך', 'יש', 'או', 'רק', 'היכן', 'אנחנו', 'לה', 'מתחת', 'יכולות', 'אס', 'אותה', 'יוכלו', 'אך', 'אצל', 'להם', 'כש', 'שלכן', 'שלהם', 'אז', 'מכיוון', 'בין', 'ואת', 'מכאן', 'יכלו', 'כאן', 'אותי', 'כי', 'לאן', 'לפני', 'איפה', 'כלל', 'עליו', 'לעבר', 'מאחורי', 'עצמן', 'למקום שבו', 'אתם', 'יכול', 'עליכם', 'למטה', 'אם', 'את', 'איזה', 'אתכן', 'בלי', 'למרות', 'איתן', 'אין', 'בתוך', 'יכל', 'מי', 'מצד', 'לפיכך', 'היתה', 'עצמם', 'יכלה', 'של', 'כזה', 'על', 'אתכם', 'איך', 'להן', 'כפי', 'שלי', 'עלי', 'להיות', 'עצמו', 'אבל', 'מלבד', 'עליה', 'נו', 'שוב', 'אני', 'אותך', 'הרי', 'כאשר', 'גם', 'כיצד', 'לנו', 'היתי', 'לאיזו תכלית', 'אתן', 'במקום שבו', 'איתך', 'עד', 'מבלי', 'מתי', 'מסוגל
# ...

# %% [markdown]
# # ***--Stopwords en Frances***

# %%
from nltk.corpus import stopwords

French_sw = set(stopwords.words('french'))

print(French_sw)
# Out:
# {'soyons', 'eusses', 'sera', 'ta', 'eussent', 'avec', 'mais', 'eut', 'ces', 'soyez', 'eusse', 'son', 'd', 't', 'êtes', 'ayantes', 'eux', 'ayez', 'se', 'étiez', 'fûmes', 'suis', 'fût', 'aura', 'fussiez', 'as', 'vos', 'était', 'eussiez', 'notre', 'et', 'm', 'aies', 'ses', 'étées', 'seraient', 'avions', 'aurai', 'en', 'avait', 'mes', 'étants', 'la', 'es', 'ait', 'étions', 'fusse', 'on', 'fus', 'eu', 'ma', 'y', 'fussent', 'eues', 'étant', 'est', 'de', 'sa', 'nous', 'sur', 'avais', 'seront', 'seriez', 'ont', 'eue', 'serai', 'une', 'pour', 'fussions', 'ou', 'du', 'étaient', 'par', 'été', 'auraient', 'soient', 'auriez', 'seras', 'aurait', 'ayons', 'les', 'serions', 'auront', 'aurez', 'eus', 'dans', 'leur', 'elle', 'avez', 'étés', 'eût', 'toi', 'l', 'étante', 'serons', 'tu', 'ne', 'me', 's', 'aurions', 'il', 'qui', 'ils', 'étantes', 'j', 'lui', 'serez', 'soit', 'ai', 'à', 'auras', 'étée', 'fûtes', 'mon', 'même', 'avaient', 'serait', 'aient', 'ayant', 'nos', 'pas', 'tes', 'étais', 'aviez', 'a
# ...

# %% [markdown]
# # ***--Stopwords en español***

# %%
from nltk.corpus import stopwords

spanish_sw = set(stopwords.words('spanish'))

print(spanish_sw)
# Out:
# {'unos', 'tenida', 'tened', 'tuviésemos', 'vuestros', 'habíamos', 'hubiera', 'ya', 'sentido', 'estada', 'quienes', 'nuestras', 'estaréis', 'habría', 'para', 'estabais', 'estaríamos', 'hay', 'vuestro', 'fueron', 'teníamos', 'estos', 'estuvieseis', 'hemos', 'hube', 'lo', 'habréis', 'seríamos', 'tuvisteis', 'cual', 'tus', 'esté', 'todos', 'su', 'algo', 'estuviera', 'hayamos', 'estarán', 'seáis', 'fuimos', 'nuestra', 'estuvo', 'tenías', 'tendrías', 'sería', 'tuvierais', 'pero', 'estuviese', 'más', 'estaba', 'tuviesen', 'tanto', 'tenidas', 'mis', 'hubo', 'me', 'esa', 'eras', 'habremos', 'tenían', 'estuviéramos', 'tiene', 'has', 'tenemos', 'será', 'tienes', 'tuvieras', 'estado', 'han', 'él', 'ante', 'habiendo', 'esta', 'hubisteis', 'entre', 'tuviera', 'habíais', 'he', 'también', 'o', 'otra', 'hubimos', 'yo', 'estuviésemos', 'nuestros', 'fuerais', 'ese', 'estuve', 'estando', 'otro', 'fuese', 'seré', 'del', 'estuvieses', 'estas', 'ha', 'algunos', 'fuiste', 'hayan', 'estés', 'fuisteis', 'haya
# ...

# %% [markdown]
# Todas estas palabras se pueden usar para filtrar textos y obtener información relevante. Primero le pedimos a Gemini un texto de ejemplo, luego tokenizamos y filtramos

# %%
filtered_text = []

text_with_sw = '''
vosotras, las protagonistas, seréis las líderes del equipo mágico.
Habríamos tenido éxito si no fuera por aquel poderoso hechizo que tenía el villano.
Muchos estaban preocupados, pero confío en que habré encontrado la solución a tiempo.
Sentido tiene que haberles guiado hacia esta misión crucial.
Si estéis listas para enfrentar los desafíos, seríais capaces de superar cualquier obstáculo.
Tendrías que recordar que no se puede subestimar el poder que se oculta dentro de cada uno.
'''

words = word_tokenize(text_with_sw)

for word in words:
    if word not in spanish_sw:
        filtered_text.append(word)

print(filtered_text)
# Out:
# [',', 'protagonistas', ',', 'líderes', 'equipo', 'mágico', '.', 'Habríamos', 'éxito', 'si', 'aquel', 'poderoso', 'hechizo', 'villano', '.', 'Muchos', 'preocupados', ',', 'confío', 'encontrado', 'solución', 'tiempo', '.', 'Sentido', 'haberles', 'guiado', 'hacia', 'misión', 'crucial', '.', 'Si', 'listas', 'enfrentar', 'desafíos', ',', 'capaces', 'superar', 'cualquier', 'obstáculo', '.', 'Tendrías', 'recordar', 'puede', 'subestimar', 'poder', 'oculta', 'dentro', 'cada', '.']

# %%
len(words)
# Out:
# 85

# %%
len(filtered_text)
# Out:
# 49

# %% [markdown]
# A traves del filtro aparecen los signos de puntuacion y palabras filtradas en el texto, ejemplo:
# ','   ...'protagonistas'...

# %% [markdown]
# # ***Tag	Meaning***
# ##ADJ	-adjective
# ##ADP	-adposition
# ##ADV	-adverb
# ##CONJ	-conjunction
# ##DET	-determiner
# ##NOUN	-noun
# ##NUM	-numeral
# ##PRT	-particle
# ##PRON	-pronoun
# ##VERB	-verb
# ##.	-punctuation
# ##X	-other

# %% [markdown]
# # **###Etiquetas**

# %%
# !python -m spacy download es_core_news_sm # Download the Spanish language model 'es_core_news_sm'
import spacy

nlp = spacy.load("es_core_news_sm")  # Load the Spanish model.
import nltk
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 35.7 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk import word_tokenize, pos_tag

## etiquetas del texto
words = word_tokenize(text_with_sw)
# Get the POS tags for the words
tagged_words = pos_tag(words)

# Now, you can access the tag for each word
for word, pos in tagged_words:
    print(f"{word}: {pos}")
# Out:
# vosotras: NNS
# ,: ,
# las: NNS
# protagonistas: NNS
# ,: ,
# seréis: JJ
# las: NN
# líderes: VBZ
# del: JJ
# equipo: NN
# mágico: NN
# .: .
# Habríamos: NNP
# tenido: NN
# éxito: NNP
# si: VBZ
# no: DT
# fuera: NN
# por: NN
# aquel: NN
# poderoso: NN
# hechizo: NN
# que: NN
# tenía: NN
# el: JJ
# villano: NN
# .: .
# Muchos: NNP
# estaban: JJ
# preocupados: NN
# ,: ,
# pero: NN
# confío: NN
# en: IN
# que: NN
# habré: NN
# encontrado: NN
# la: NN
# solución: VBD
# a: DT
# tiempo: NN
# .: .
# Sentido: NNP
# tiene: NN
# que: NN
# haberles: NNS
# guiado: VBP
# hacia: JJ
# esta: NN
# misión: NN
# crucial: JJ
# .: .
# Si: NNP
# estéis: JJ
# listas: NNS
# para: VBP
# enfrentar: JJ
# los: NN
# desafíos: NN
# ,: ,
# seríais: JJ
# capaces: NNS
# de: FW
# superar: FW
# cualquier: JJR
# obstáculo: NN
# .: .
# Tendrías: NNP
# que: NN
# recordar: NN
# que: NN
# no: DT
# se: NN
# puede: NN
# subestimar: NN
# el: NN
# poder: NN
# que: NN
# se: NN
# oculta: JJ
# dentro: NN
# de: IN
# cada: FW
# ...

# %% [markdown]
# Etiquetas : https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %% [markdown]
# # ***Lematización***

# %% [markdown]
# ###Proceso lingüístico que sustituye una palabra con forma flexionada (plurales, femeninos, verbos conjugados, etc.) por su lema; es decir, por una palabra válida en el idioma.
# ###La Lematización que hace NLTK solo es buena para la lengua inglesa.

# %% [markdown]
# Una vez hemos visto el análisis léxico, el siguiente paso es el análisis morfológico. Esto es el estudio de la estructura interna de las palabras, en este contexto vamos a ver como llevar a cabo la lematización.
#
# Es el proceso lingüístico y de procesamiento de lenguaje natural que consiste en reducir las palabras a su forma base o raíz, conocida como «lema». El lema es la forma más básica y genérica de una palabra como el infinitivo en el caso de los verbos. Por ejemplo, «corriendo», «corre», «corrió» y «correrá» se reducirían todas a su lema «correr». Este proceso es muy importante en las técnicas de NLP.

# %%
import nltk

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer


##Inicializamos el lematizador
Lemmatizer = WordNetLemmatizer()

print(Lemmatizer.lemmatize(word="bats"))
print(Lemmatizer.lemmatize(word="feet"))
# Out:
# bat
# foot

# %% [markdown]
# Importamos WordNetLemmatize, que será el lematizador que se encargue de tranformar las palabras a su forma más básica, a través de la función lemmatize. También tendremos que descargar Wordnet, la mayor base de datos léxica en inglés de la Universidad de Princeton. Esto es necesario porque la función lemmatize hace uso de ella. Por ello, únicamente podremos usar palabras en inglés.

# %% [markdown]
# Vemos que ha lematizado bats y feet a sus formas básicas bat y foot. La función lemmatize por defecto espera sustantivos, en el caso de querer pasar verbos u otros debemos indicarlo, en el segundo parámetro pos (Part Of Speech):

# %%
print(Lemmatizer.lemmatize("running", pos="v"))
# Out:
# run

# %% [markdown]
# En el caso de que queramos lematizar frases o textos, primero debemos tokenizarlos y etiquetar cada palabra según las categorías que define Wordnet: ADJ, VERB, NOUN y ADVERB principalmente. Aquí están todas las opciones. Y después procesar cada palabra con el lematizador. Antes que nada, descargamos nltk.download(‘universal_tagset’) en el entorno de Python, creamos una sencilla función para saber clasificar según las categorías de Wordnet y creamos un texto que queramos lematizar.

# %% [markdown]
# # ***Part of Speech (PoS)***

# %% [markdown]
# Consiste en asignar una etiqueta de categoría a las partes tokenizadas de una oración: sustantivos, verbos, adjetivos, etc.
# El PoS de NLTK solo esta disponible para el ingles y tiene las siguientes categorias:

# %% [markdown]
# Tag Meaning
# #ADJ -adjective
# #ADP -adposition:elementos relacionales que expresan una amplia variedad de valores semánticos entre ellos, causa, fuente, tiempo, instrumento, finalidad o locación;
# #ADV -adverb
# #CONJ -conjunction
# #DET -determiner: determinador
# #NOUN -noun
# #NUM -numeral
# #PRT -particle
# #PRON -pronoun
# #VERB -verb
# #. -punctuation
# #X -other

# %%
from nltk.corpus import wordnet
nltk.download('universal_tagset') # descargo la base de etiquetas

def get_wordnet_pos(word): # describo a traves de un def las etiquetas y las adjudico con su correspondiente etiqueta
    if word.startswith('ADJ'):
        return wordnet.ADJ
    elif word.startswith('V'):
        return wordnet.VERB
    elif word.startswith('N'):
        return wordnet.NOUN
    elif word.startswith('ADV'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

texto = "Luis´s dogs aren´t sitting calmly on the white mats" # cargo un texto
texto_tokenizado = nltk.word_tokenize(texto)##tokenizo

texto_tokenizado
# Out:
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# ['Luis´s', 'dogs', 'aren´t', 'sitting', 'calmly', 'on', 'the', 'white', 'mats']

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# Una vez hecho esto ya podemos etiquetar las palabras, con la función pos_tag de nltk. Necesita dos parámetros, el texto y el tagset, esto es el conjunto de etiquetas que se utilizará al etiquetar las partes del discurso, universal es la más común, con las categorías mencionadas antes:

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
palabras_etiquetadas = nltk.pos_tag(texto_tokenizado, tagset="universal") # la frase se lematizo

palabras_etiquetadas
# Out:
# [('Luis´s', 'NOUN'),
#  ('dogs', 'NOUN'),
#  ('aren´t', 'VERB'),
#  ('sitting', 'VERB'),
#  ('calmly', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('white', 'ADJ'),
#  ('mats', 'NOUN')]

# %% [markdown]
# Usando el lematizador de WordNetLemmatizer como en ocasiones anteriores, podemos obtener los lemas del texto inicial. Haciendo uso de la posibilidad que ofrece de list comprehension, para crear nuevas listas en base a listas que ya existen.

# %% [markdown]
# Se recorre la lista de palabras_etiquetadas por cada dupla en cada posición, obtenemos el token y la POS (Part Of Speech) de cada palabra del texto inicial. Estos parámetros se le proporcionan a lemmatize para poder llevar a cabo la lematización de cada palabra. Cada resultado se va almacenando en la lista lemas mediante list comprehension, como he mencionado antes.

# %%
lematizador = WordNetLemmatizer()

lemas = [lematizador.lemmatize(palabra, get_wordnet_pos(etiqueta)) for palabra, etiqueta in palabras_etiquetadas]

lemas # guardar la lemmatizacion en un archivo de lemas
# Out:
# ['Luis´s', 'dog', 'aren´t', 'sit', 'calmly', 'on', 'the', 'white', 'mat']

# %% [markdown]
# A partir de este texto inicial, obtenemos los lemas de cada palabra:

# %% [markdown]
# # ***Tratamiento de archivos de texto en nltk***

# %% [markdown]
# # ***Podemos a traves de un archivo de texto cargarlos con pandas y trabajarlo luego con nltk***

# %% [markdown]
# # ***-Texto anterior ***

# %%
text
# Out:
# 'En las clases de programacion el alumno comprende todas las instrucciones y ordenes de programacion que el profesor\nle sugiere. Muchas veces el profesor no es capaz de comprender las instrucciones y ordenes de programacion que el alumno\nescribe. Por lo tanto el alumno debe comprender las instrucciones y ordenes de programacion que el profesor le sugiere.\nEn las clases de programacion el alumno comprende todas las instrucciones y ordenes de programacion que el profesor le sugiere 😊💪👍'

# %% [markdown]
# -Cargamos el texto en archivo txt a traves de pandas.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/Viny2030/datasets/refs/heads/main/texto.txt"
texto01 = pd.read_fwf(url)  ### lector de texto de pandas

# %%
texto01 # observen que el dataFrame del archivo de texto no reconoce los emojis,,,,,dividen en 9 lineas
# Out:
#   '''En las clases de programacion el alumno comprende todas las instrucciones y ordenes de
# 0  programacion que el profesor le sugiere. Mucha...
# 1  las instrucciones y ordenes de programacion qu...
# 2  Por lo tanto el alumno debe comprender las ins...
# 3  profesor le sugiere. En las clases de programa...
# 4  instrucciones y ordenes de programacion que el...

# %% [markdown]
# -Biblioteca adicional :https://pypi.org/project/skimpy/0.0.4/

# %%
# !pip install skimpy

# %%
from skimpy import skim

# %%
skim(texto01)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 5      │ │ string      │ 1     │                                                          │
# │ │ Number of columns │ 1      │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# ...

# %% [markdown]
# # ***_Cargar archivo PDF***

# %%
# !pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 6.2 MB/s eta 0:00:00
# ...

# %%
import PyPDF2

# %%
from PyPDF2 import PdfReader

# %% [markdown]
# # ***-Es necesario abrir con mode='rb'.***

# %%
# !pip install PyPDF2

# %%
import io
import requests
from PyPDF2 import PdfReader

# %%
url = "https://raw.githubusercontent.com/Viny2030/datasets/refs/heads/main/texto01.pdf"

# Fetch the PDF content from the URL
response = requests.get(url)
response.raise_for_status()  # Raise an exception for bad status codes

# Create a file-like object from the response content
pdf_file = io.BytesIO(response.content)

# Now you can use PdfReader with the pdf_file object
reader = PdfReader(pdf_file)

# %%
# Fetch the PDF content from the URL
response = requests.get(url)
response.raise_for_status()  # Raise an exception for bad status codes

# Create a file-like object from the response content
pdf_file = io.BytesIO(response.content)

# Now you can use PdfReader with the pdf_file object
#You are already using PdfReader, no need to use PyPDF2.PdfReader
lectura_pdf = PdfReader(pdf_file)

# %%
lectura_pdf

# %%
len(lectura_pdf.pages)
# Out:
# 1

# %%
pagina_pdf = lectura_pdf.pages[0]

# %% [markdown]
# # ***-Impresion del pdf observen como toma los emojis...!!***

# %%
print(pagina_pdf.extract_text())
# Out:
# '''En las clases de programacion el alumno comprende todas las
# instrucciones y ordenes de
# programacion que el profesor le sugiere. Muchas veces el profesor no es
# capaz de comprender
# las instrucciones y ordenes de programacion que el alumno escribe.
# Por lo tanto el alumno debe comprender las instrucciones y ordenes de
# programacion que el
# profesor le sugiere. En las clases de programacion el alumno comprende
# todas las
# instrucciones y ordenes de programacion que el profesor le sugiere
# ??????'''

# %% [markdown]
# # ***-Cierre del archivo***

# %%
pdf_file.close()

# %% [markdown]
# La biblioteca de nltk tiene un conjunto de archivos denominados Corpora  en : https://www.nltk.org/nltk_data/
# donde se puede descargar a traves de nltk.downLoad()

# %% [markdown]
# # ***- Corpus***
# Un Corpus (en Latín "Cuerpo") dentro del contexto del NLP se refiere a una colección de textos como puede ser un conjunto de artítulo periodísticos, libros, críticas, tweets, etc.
# NLTK dispone de una serie de Corpus con los que poder trabajar y realizar pruebas.

# %% [markdown]
# # -Manejo de Corpus (funcionalidades)
#
# Dentro de NLTK podemos encontrarnos diferentes tipos de Corpus que podrían clasificarse en:
#
# * Textos planos: como el corpus de *Gutenberg*
# * Textos categorizados: como el corpus de *Bronwn* (15 generos)
# * Textos multicategóricos: como el corpus de *Reuters* (1 documentos, varias categorias)
# * Textos temporales: como el corpus *Inaugural Address Corpus*, discursos presidenciales a lo largo de la historia

# %% [markdown]
# # ***--LAS BIBLIOTECAS TIENE DATASET PROPIOS, EJEMPLO SKLEARN, SPACY Y NLTK TIENE CORPUS DE TEXTOS..DE DIFERENTES TEMAS***

# %% [markdown]
# # ***Ejemplo con el corpus de Gutenberg***
#  ¿Que ficheros componen el corpus?

# %%
import nltk
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
from nltk.corpus import gutenberg
gutenberg.fileids()  # el corpus de gutenberg tiene archivos de texto
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
len(gutenberg.raw(['austen-emma.txt'])) # caracteres de el archivo
# Out:
# 887071

# %% [markdown]
# # **-Graficamos los fileaids de gutemberg donde en el grafico aparecen los fileaids ordenados alfabeticamente por cantidad de palabras en un rango, dentro del rango del primer fileaids 'austen-emma.txt'..

# %%
names = nltk.corpus.names
cfd = nltk.ConditionalFreqDist(
    (fileid, gutenberg.fileids()[0])
    for fileid in gutenberg.fileids()
    for name in gutenberg.words(fileid))
cfd.plot()  # es util el grafico ???? a opinion de ustedes
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # ***-Cuento los caracteres, las palabras y las frases  de cada archivo.txt***

# %%
len(gutenberg.raw(['austen-emma.txt']))# caracteres
# Out:
# 887071

# %%
len(gutenberg.words(['austen-emma.txt']))#palabras
# Out:
# 192427

# %%
len(gutenberg.sents(['austen-emma.txt']))#frases
# Out:
# 7752

# %%
len(gutenberg.raw(['austen-persuasion.txt']))
# Out:
# 466292

# %%
len(gutenberg.raw(['bible-kjv.txt']))
# Out:
# 4332554

# %%
len(gutenberg.raw(['blake-poems.txt']))
# Out:
# 38153

# %%
len(gutenberg.raw(['chesterton-ball.txt']))
# Out:
# 457450

# %%
len(gutenberg.raw(['shakespeare-macbeth.txt']))
# Out:
# 100351

# %%
len(gutenberg.words(['shakespeare-macbeth.txt']))
# Out:
# 23140

# %% [markdown]
# # ***Como descargo un fichero ?***

# %%
print('bible-kjv.txt')
print(gutenberg.raw('bible-kjv.txt')[:700])
# Out:
# bible-kjv.txt
# [The King James Bible]
#
# The Old Testament of the King James Bible
#
# The First Book of Moses:  Called Genesis
#
#
# 1:1 In the beginning God created the heaven and the earth.
#
# 1:2 And the earth was without form, and void; and darkness was upon
# the face of the deep. And the Spirit of God moved upon the face of the
# waters.
#
# 1:3 And God said, Let there be light: and there was light.
#
# 1:4 And God saw the light, that it was good: and God divided the light
# from the darkness.
#
# 1:5 And God called the light Day, and the darkness he called Night.
# And the evening and the morning were the first day.
#
# 1:6 And God said, Let there be a firmament in the midst of the waters,
# and let it divide the waters from the w

# %% [markdown]
# ###-Cantidad de caracteres  del fichero

# %%
len(gutenberg.raw(['bible-kjv.txt']))
# Out:
# 4332554

# %% [markdown]
# # ¿Cual es el contenido del fichero "blake-poems.txt"?

# %%
contenido = gutenberg.raw("blake-poems.txt")
contenido[:]
# Out:
# '[Poems by William Blake 1789]\n\n \nSONGS OF INNOCENCE AND OF EXPERIENCE\nand THE BOOK of THEL\n\n\n SONGS OF INNOCENCE\n \n \n INTRODUCTION\n \n Piping down the valleys wild,\n   Piping songs of pleasant glee,\n On a cloud I saw a child,\n   And he laughing said to me:\n \n "Pipe a song about a Lamb!"\n   So I piped with merry cheer.\n "Piper, pipe that song again;"\n   So I piped: he wept to hear.\n \n "Drop thy pipe, thy happy pipe;\n   Sing thy songs of happy cheer:!"\n So I sang the same again,\n   While he wept with joy to hear.\n \n "Piper, sit thee down and write\n   In a book, that all may read."\n So he vanish\'d from my sight;\n   And I pluck\'d a hollow reed,\n \n And I made a rural pen,\n   And I stain\'d the water clear,\n And I wrote my happy songs\n   Every child may joy to hear.\n \n \n THE SHEPHERD\n \n How sweet is the Shepherd\'s sweet lot!\n From the morn to the evening he stays;\n He shall follow his sheep all the day,\n And his tongue shall be filled with prai
# ...

# %% [markdown]
# -Graficamos los datos?

# %% [markdown]
# # ***De cada uno de los ficheros mostramos: ***
# ##- Número de caracteres
# ##- Número de palabras
# ##- Número de frases
# ##- Número de palabras distintas que aparecen en el texto (primero las pasamos a minúsculas)
# ##- Número de medio de caracteres por palabra
# ##- Número medio de palabras por frase
# ##- Diversidad léxica (número de palabras / palabras distintas del texto)

# %%
import nltk
nltk.download('punkt')

# %%
for file in gutenberg.fileids():
    num_chars = len(gutenberg.raw(file))
    num_words = len(gutenberg.words(file))
    num_sents = len(gutenberg.sents(file))
    num_words_distinct = len(set([w.lower() for w in gutenberg.words(file)]))
    avg_chars_words = int(num_chars/num_words)
    avg_words_sents = int(num_words/num_sents)
    lexical_diversity = int(num_words/num_words_distinct)
    print("{num_chars:<10} {num_words:<10} {num_sents:<10} {num_words_distinct:<10} {avg_chars_words:<10} {avg_words_sents:<10} {lexical_diversity:<10} {file:<10}"
          .format(num_chars=num_chars, num_words=num_words, num_sents=num_sents,
                  num_words_distinct=num_words_distinct, avg_chars_words=avg_chars_words,
                  avg_words_sents = avg_words_sents, lexical_diversity=lexical_diversity, file=file))

# %% [markdown]
# # ***- Vale la pena graficar el fileaids de texto ?***

# %%
# !pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
nltk.download('gutenberg')
from nltk.corpus import gutenberg

# %%
plt.hist(gutenberg.words('austen-sense.txt'))
plt.show()

# %% [markdown]
# # Ejemplo de Tokenización de una frase
# Divide las cadenas de texto del documento en piezas más pequeñas o tokens.

# %%
import nltk
from nltk import word_tokenize
doc = "Una multa de transito es muy onerosa en la Ciudad de Buenos Aires"
words = nltk.word_tokenize(doc)
print (words)

# %% [markdown]
# # ***Stop words aplicada a una frase***
# Son las palabras que no aportan nada al significado de la frase.
# NLTK tiene para una serie de idiomas un listado de Stop Words.
# Para el Español dispone de un listado de stop words:

# %%
import nltk
nltk.download('stopwords')

# %%
from nltk.corpus import stopwords
print(set(stopwords.words('spanish')))

# %% [markdown]
# ###Este listado de palabras se utiliza para eliminarlas de los textos.
# ###Veamos  como filtra las stop words de una frase tras su tokenización.

# %%
doc = "Las multas en la Ciudad de Buenos Aires son onerosas"
words = nltk.word_tokenize(doc)
for word in words:
        if word not in stopwords.words('spanish'):
            print (word)

# %% [markdown]
# # ***Comentarios Adicionales***

# %% [markdown]
# # ***Embeddings***

# %% [markdown]
# En el campo del Deep Learning y las redes neuronales sólo se puede trabajar con números que es lo único que entienden los modelos y en definitiva los ordenadores. Por lo que tenemos un problema si queremos que aprendan texto. Ya que si intentamos introducer palabras o letras en una red neuronal para que aprenda las relaciones entre ellas, las va a escupir como si de algo envenenado se tratase.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Por ello tenemos que buscar una forma de codificar las palabras a números que son el tipo de dato que acepta la red neuronal. Aquí es donde entran los embeddings.

# %% [markdown]
# Es una técnica de representación de palabras en vectores matemáticos. Cada palabra del lenguaje está representada por un vector, lo que permite hacer operaciones con ellos. Así podemos obtener la cercanía conceptual de las palabras en base a sus cercanía matemática en base de vector.

# %% [markdown]
# No buscan asignar un valor matemático a cada palabra, sino una representación contextual. Para que así la distancia entre cat y car sea muy grande, a pesar de ser palabras muy parecidas y que la distancia entre cat y dog sea pequeña puesto que pertenecen al campo semántico de los animales, a pesar de ser palabras muy distintas.

# %% [markdown]
# Pero son imprescindibles para que los modelos puedan entender las palabras y poder aprender las relaciones sobre ellas. A través de como se ubicarían en un espacio vectorial y la distancia relativa entre los vectores permitiría agruparlas.

# %% [markdown]
# # ***One-hot encoding***

# %% [markdown]
# Es la representación más común de palabras como vectores. Tomando como vocabulario un conjunto de 3 palabras (perro, gato, periquito), para cada palabra, su forma vectorial se vería reflejada como todo ceros salvo una posición con un 1. Asumiendo que las posiciones pertenecen a una única palabra, es decir, en la primera posición solo puede representarse un 1 como perro y así sucesivamente.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Esta técnica tiene el inconveniente de que crece proporcionalmente al tamaño del vocabulario. Para un vocabulario de n palabras habrá n posiciones en el vector.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Esta técnica tiene el problema de que se manejan dimensiones muy grandes, por tanto una forma de reducir la dimensionalidad es usar los vectores como entrada de una red neuronal con un número de neuronas significativamente inferior al número de vectores de entrada.
#
# Como siempre en el mundo del deep learning y el entrenamiento de modelos partir de cero es muy costoso y largo. Por ello, en la práctica, se usa la técnica de transfer learning para aprovechar el entrenamiento de un embedding para otra tarea parecida pero relacionada.

# %% [markdown]
# # ***`muchas gracias`***
#
# ⏰

# %% [markdown]
# Bibliografia on line:
# https://www.nltk.org/book/

# %% [markdown]
# "Natural Language Processing"- copia PDF

# %% [markdown]
# # ***-Modelos***

# %% [markdown]
# https://huggingface.co/
