# %% [markdown]
# <a href="https://colab.research.google.com/github/Viny2030/UNED/blob/main/1_GoogleNews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***MASTERCLASS NLP***

# %% [markdown]
# # ***_En este colab se trata de extraer noticias de algun tipo de sitios de news y buscar palabras, formar datasets e investigar a traves del tratamiento de lenguaje natural***

# %% [markdown]
# # ***-Como puedo extraer datos de un sitio: a traves de las API***
# -###-API significa “interfaz de programación de aplicaciones”. En el contexto de las API, la palabra aplicación se refiere a cualquier software con una función distinta. La interfaz puede considerarse como un contrato de servicio entre dos aplicaciones

# %% [markdown]
# -API DE X = https://developer.x.com/en/docs

# %% [markdown]
# -API DE FACEBOOK E INSTAGRAM: https://developers.facebook.com/products/instagram/apis/

# %% [markdown]
# -### SITIO CON APIS: https://apilayer.com/

# %% [markdown]
# ###-API de Twitter: (https://developer.twitter.com/)
# ### O utilizar la librería tweepy que nos facilitamo mucho la labor a la hora de obtener datos de Twitter:https://www.tweepy.org/

# %% [markdown]
# # ***Por lo tanto, para el análisis de datos, se debería tener respuesta a los siguientes interrogantes:***
# ###●	¿Se puede utilizar un conjunto de datos determinado para análisis?
# ###●	¿Los datos tienen el formato requerido?
# ###●	¿Los datos están alcanzados por algún tipo de licencia?
# ###●	¿Los datos están sujetos a las normas de protección de datos?
# ###●	¿Los datos presentan algún tipo de sesgo?
# ###●	¿Cuáles son las fuentes de datos?
# ###●	¿Las fuentes de datos son confiables?
# ###●	¿Cómo se recopilan los datos?

# %% [markdown]
# # ***Carga de librerias necesarias para el proceso***

# %% [markdown]
# -En este caso existe una biblioteca de python especifica para el acceso a GoogleNews

# %% [markdown]
# ###-Bibliotecas de Python de ejemplo:
# ###-yahoofinance:https://pypi.org/project/yfinance installation
# ##-facebook: https://pypi.org/project/python-facebook-api/
# ##-linkedin: https://pypi.org/project/python3-linkedin/

# %% [markdown]
# # ***_Cual es la diferencia entre usar un API y una biblioteca especifica de acceso?***

# %% [markdown]
# Se carga la biblioteca que se aplica el sitio de GoogleNews:
# https://pypi.org/project/GoogleNews/

# %%
# !pip install GoogleNews
# Out:
# Requirement already satisfied: GoogleNews in /usr/local/lib/python3.10/dist-packages (1.6.15)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from GoogleNews) (4.12.3)
# Requirement already satisfied: dateparser in /usr/local/lib/python3.10/dist-packages (from GoogleNews) (1.2.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from GoogleNews) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->GoogleNews) (2.6)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser->GoogleNews) (2024.2)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser->GoogleNews) (2024.9.11)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser->GoogleNews) (5.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->GoogleNews) (1.16.0)

# %% [markdown]
# # ***sys— Parámetros y funciones específicos del sistema ***
# Este módulo proporciona acceso a algunas variables utilizadas o mantenidas por el intérprete y a funciones que interactúan fuertemente con el intérprete. Siempre está disponible:
# https://docs.python.org/3/library/sys.html

# %%
 import sys

# %% [markdown]
# # ***##Se carga pandas profiling para la creacion de la Nube de palabras***

# %% [markdown]
# ###Proceso EDA  a traves de pandas profiling:
# El análisis exploratorio de datos (EDA por sus siglas en inglés) implica el uso de gráficos y visualizaciones para explorar y analizar un conjunto de datos. El objetivo es explorar, investigar y aprender, no confirmar hipótesis estadísticas.

# %% [markdown]
# https://pypi.org/project/pandas-profiling/

# %%
 # !pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in /usr/local/lib/python3.10/dist-packages (4.12.0)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (3.8.0)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.9.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (3.1.4)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (0.7.6)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.66.6)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.2.1)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling) (1.7.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba<1,>=0.56.0->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.2)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.8.30)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (24.2.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<3.10,>=3.5->ydata-profiling) (1.16.0)

# %% [markdown]
# ###pathlib— Rutas del sistema de archivos orientado a objetos
#
#
# ###Este módulo ofrece clases que representan rutas de sistemas de archivos con semántica apropiada para diferentes sistemas operativos:
# https://docs.python.org/3/library/pathlib.html

# %% [markdown]
# ##¿Qué son los widgets?
# ###Los widgets son objetos de Python llenos de acontecimientos que tienen una representación en el navegador, a menudo como un control como un control deslizante, un cuadro de texto:
# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20Basics.html

# %%
# Standard Library Imports
from pathlib import Path

# Installed packages
import pandas as pd
from ipywidgets import widgets

# Our package
from ydata_profiling import ProfileReport
from ydata_profiling.utils.cache import cache_file

# %% [markdown]
# Bibliotecas de graficos:
# https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html
# https://seaborn.pydata.org/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import warnings
warnings.filterwarnings('ignore')###El módulo warnings suprime los mensajes repetidos de la misma fuente para reducir la molestia de ver la misma advertencia una y otra vez.

# %% [markdown]
# Inicializamos en GoogleNews

# %%
from GoogleNews import GoogleNews
googlenews = GoogleNews()
googlenews.clear()

# %%
googlenews = GoogleNews(lang='en')
googlenews.get_news('Corruption')
googlenews.search('Corruption')

# %% [markdown]
# ##1-Aqui se elije el idioma de las noticias-ingles-
# ##2-el tipo de noticias y la palabra de referencia sobre ##las noticias: Corrupcion
# ##3-la instruccion de busqueda

# %% [markdown]
# Obtener mensajes me  devolverá la lista de títulos de noticias

# %%
googlenews.get_texts()
# Out:
# ['China suspends military official Miao Hua in anti-corruption purge, denies Dong Jun probe',
#  'China defence minister placed under investigation for corruption, FT reports',
#  'China Defence Minister Dong Jun’s fate unclear as corruption probe sparks differing account',
#  'China dismisses report of corruption probe into Defence Minister Dong Jun',
#  'China’s defence minister placed under investigation for corruption',
#  'China Defense Minister Investigated for Corruption, FT Says',
#  'China investigates defence minister for corruption: Report',
#  'China launches corruption probe against Defence Minister Dong Jun: Report',
#  'China Investigates Defense Minister for Corruption: Report',
#  'Can technology end corruption?',
#  'China probes top military official Miao Hua for corruption',
#  'DSI summary on PTT-OR corruption case is fake news, agency says',
#  'Ex-Taipei city councilor found guilty of corruption',
#  'China investigates defense minister for corruption — report',
#  'Former Taipei councilor and aide sentenced for corruption',
#  'The corruption scandal gripping Xi Jinping’s army',
#  'Kedah sees rise in civil servants arrested for corruption',
#  'Former Bank of China chairman sentenced to death on corruption charges',
#  'China announces top military official is under investigation',
#  "China's defence minister Dong Jun under investigation for corruption: Report",
#  'Sabah corruption scandal ahead of 2025 state polls poses fresh challenge for Anwar',
#  'China says top military official suspended, placed under investigation',
#  'China investigates head of Shanghai’s free-trade zone for corruption',
#  'Slovakia’s central bank governor given reprieve in corruption case',
#  'High-level Corruption Probe Leads to Insults and Death Threats in the Philippines',
#  'Corruption is like cancer cells eroding the nation - Sultan Nazrin',
#  'China’s Third Defense Minister Under Probe For Corruption? Is Xi Jinping’s “Personal Ambitions” Hurting PLA?',
#  'Chinese Defence Minister Dong Jun under investigation for corruption – report',
#  'Former Taipei councilor found guilty of corruption',
#  'Singapore gears up for biggest corruption trial in decades',
#  "'Is the ICC Anti-Corruption Unit... ?' Ex-Pakistan batter expresses disgust",
#  'A Top Military Official in China Is Suspended Under Suspicion of Corruption',
#  'China investigating defense minister for corruption, FT reports',
#  'How the expansion of U.S. anti-corruption law affects Brazil',
#  'Imran Khans wife Bushra Bibi dodges arrest in 190 million pound corruption case',
#  'Corruption Casebook 2: Hidden Victims of Corruption',
#  'Total Energies pauses investments into Adani Group on bribery charges',
#  'FT: China defence minister placed under investigation for corruption',
#  'Constant Vigilance Vital To The Fight Against Corruption',
#  'A Corruption Case That Spilled Across Latin America Is Coming Undone',
#  'KPK, TNI Commander to Discuss Corruption Handling in the Military',
#  'Chinese defense minister under investigation for alleged corruption',
#  'STOLEN FUTURES: The impact of corruption on children in Africa.',
#  'Corruption in Chinese army continues to haunt Xi Jinping; PLA purge expands',
#  'Benjamin Bestgen: Corruption, I presume? A useful lesson from Singapore',
#  'China suspends top military official Miao Hua amid corruption probe',
#  "Iswaran corruption charges amended as ex-minister, Ong Beng Seng would have 'interest in denying' corruption: AGC",
#  'First cryptocurrency corruption case in China is former central bank official',
#  'Escaping Trump’s tariffs has required navigating a ‘broken’ system vulnerable to corruption, businesses and academics say',
#  'China defense minister being investigated for corruption, report says',
#  'Sri Lanka votes for change',
#  'Understanding corruption and its relationship with AML',
#  '2024/42 "Corruption Eradication in Indonesia: One Step Forward, Two Steps Back" by Astrid Meilasari-Sugiana, Gunardi Endro, Siwage Dharma Negara',
#  'Singapore ex-Transport Minister Iswaran pleads guilty in graft trial',
#  "Explainer: 'The Corrupt Solar Project': Adani embroiled in US findings of bribery scheme",
#  'Horizontal Review of Gatekeepers’ Technical Compliance Related to Corruption',
#  'Chinese defence minister placed under investigation for corruption.',
#  'Lost nearly $55 billion since U.S. corruption charges: Adani Group',
#  'Sarawak Metro invites MACC, ombudsman to audit as part of zero-tolerance policy on corruption',
#  'Dossier no. 82: How Neoliberalism Has Wielded ‘Corruption’ to Privatise Life in Africa',
#  'Singapore’s ex-transport minister jailed for 12 months in landmark ruling',
#  'Singapore’s ex-transport minister hit with 8 new charges in corruption case',
#  '2024/44 "Anti-Corruption Politics and Shifts in Central-Local Relations in Vietnam" by Nguyen Khac Giang',
#  'Indian Billionaire Gautam Adani’s Company Says He Hasn’t Been Charged For Violating U.S. Corruption Law',
#  'Why China is purging its senior military officials',
#  'Explainer: How corruption facilitates organized crime',
#  "Turmoil In Ranks: China's PLA Grapples With Corruption Scandals As Senior Officers Face Scrutiny",
#  'Iran determined to actively contribute to anti-corruption efforts: Official',
#  "Corruption, leakages and abuse of power are akin to cancerous cells in nation's anatomy, says Sultan Nazrin",
#  'Practical Law: Note for the Board on Anti-Corruption - Singapore',
#  "Chinese military official Miao Hua under investigation amid ongoing corruption crackdown in China's army ranks",
#  'Tsotsobe, Tsolekile and Mbhalati arrested and charged with corruption',
#  'China probes top military official for corruption',
#  'Special House Committee formed to probe corruption in Visakha Dairy, says Andhra Pradesh Assembly Speaker',
#  'What makes China’s Guangdong and its ‘sin city’ magnets for corruption probes?',
#  'Disgraced ex-minister gets jail time in rare corruption case for squeaky clean Singapore',
#  'Karnataka cabinet orders reopening of corruption and money laundering cases against BS Yediyurappa and Family',
#  'SC stays revival of corruption case against former TN CM Panneerselvam',
#  'Four innovative ways the World Bank is fighting corruption',
#  'Curaçao gambling regulator refutes licensing reform corruption allegations',
#  'CBI books 2 senior SEEPZ officers in corruption case',
#  'Unbroken Chains: The Continuity of Systemic Corruption in Afghanistan',
#  'Combatting High-level Corruption in Eastern Europe',
#  'Ecuador judge convicts 20 in judiciary corruption case',
#  'RG Kar corruption case: CBI files chargesheet, not accepted by court',
#  'Saudi citizen wanted for corruption crimes extradited from Russia',
#  'Sabah PKR gathering evidence to dispel corruption allegations against PM',
#  'RG Kar Corruption Case: CBI Files Chargesheet, Not Accepted By Court',
#  'South Korean PM offers to Resign in his own Fight Against Corruption',
#  'How to strengthen anti-corruption frameworks: 4 actionable insights',
#  'Defence firm Thales faces bribery and corruption investigation',
#  'Anti-Corruption Network for Eastern Europe and Central Asia',
#  'Civic body chief, JE, contractor booked on corruption charges',
#  'Corruption in the Extractive Value Chain',
#  'Tom Lembong Sugar Corruption Case, AGO Examines Former Ministry Of SOEs Officials',
#  "South Africa's Tsotsobe, Tsolekile and Mbhalati arrested, charged with corruption",
#  "Xi Jinping can't seem to find the right man to be the face of China's military",
#  'Gautam Adani not charged with FCPA, only securities violations involving penalties: Adani Green',
#  "China's Defense Minister Under Investigation as Corruption Crisis Deepens",
#  'CM Chandrababu Ensures Corruption-Free Pension Distribution in Andhra Pradesh',
#  'ANAMBRA GOVT IN COLLABORATION WITH EUROLAC REVIEWS ANTI- CORRUPTION PRACTICES IN THE STATE',
#  'Mahama defends proposal to restructure Free SHS Secretariat over corruption',
#  'The corruption scandal gripping Xi Jinping’s army',
#  'Iran determined to actively contribute to anti-corruption efforts: Official',
#  'License examiner held for bribing anti-corruption investigators',
#  "South Africa's Tsotsobe, Tsolekile And Mbhalati Arrested, Charged With Corruption",
#  'Kedah sees rise in civil servants arrested for corruption',
#  'KPK, TNI Commander to Discuss Corruption Handling in the Military',
#  'DSI summary on PTT-OR corruption case is fake news, agency says']

# %% [markdown]
# Obtener enlaces Devuelve la lista de enlaces de noticias

# %%
googlenews.get_links()
# Out:
# ['https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMicEFVX3lxTE5qYWpZMlllWS1nNVF6LUVHaWJpcmhBLTZfYV9KclotckJuOXo2YmJzM2o3NUR6MDdNNTR4X29KcG1kaEh1ZG9fNlNNel8zZUlORHdIVy1fd0xzRlF0a1pyX2tQMk9HMUdGalpScnYyTXU?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMirwFBVV95cUxPaGlQVXcxQWxQcDNMbHNodlhHcFFxSEpkczhWeHp3bWNUMlpidm9FOFRpSm5lamZIRFlEQm5kZVh4WlZqTXhIdzZPa1hNWm9YQVY5elNfRXNqWmNPQTZrbnFWMC1tcENNNG55WmxFLXE3UEpEOXF3RTFpRUlYTWE5RzlOYi1ZMnpJUHZUTjlTbmt5Z3hDcXExTEpaRWx0VmZjVGppTlo3b2pLQkhvMDA0?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMinwFBVV95cUxQWmtEVEZQTUhkM08zcS1JclB1c3o1X2tsOERNZDlCSU44dlJCSjBjWDBsa2tMSXNKUklMRDYwemRQcF9BMjZ1cndwSl9NZ04yVXp6bE9iQkJqdDRpWFZ1MEhMcU50NTdlV0VRbVhVQW9iakxCb2hTOUd3RXhPMXdJNUFtWHl2VHVhVi1ja0k1N1c4cDJXaHBzTVlwWUcxVFE?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiigFBVV95cUxNcURiTTFIbENNM1ZLUUVlTG5GdS1xc1ZEazdWWU9vZENRTXdBMjNySmdPRG9yWTZpRDd6M3lIOWpPS2o0dG5IR3p6RTdpMVBIX0w0ZFpoMnhVSXJqU0VvMEgwcHNwRE9wUFpTa1ljcV9uU3pvMkZDeW1MV2RiUFR2aEszQjg0LURyZWc?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMirwFBVV95cUxPQmVMbHJrWFkyaGgwUktPTjNLTjZLOThmQjkxck4tMnRZZEVDQmtySkRXZUkyQ1l0dkc3dDhRRXpWSmJsSVVHb21jcTZnWGhlZ2hHLVg5eGVYV1NGOEF2RTQ4TVhNN0xsZUk4M28xZ3l2R3l3NFRoeW5iSmdxLXRVODNOQ1ZkLUM3RXNXdGdUQ0FBVjA4dzc4YzA1aEFFWVd3WDgyR3Q2ajJDQzk4Qmo0?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiYkFVX3lxTFA4RkMtWmlhdERITm5iS0pyUFhBM05XNGtndDZ2Tm90emFiVzNUV05xUTVhR2FrbmRaS3RMV2tFVVVSNjREMU5iZG51Zjdxck52NjAtWEI4TkZEMXdyeHB5UW13?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiVkFVX3lxTE15dWc5em9hLU1LYjNMbk9sTkJvcS0tZlFFdXFsN1JpMC1BbGQwSmg1dURoajdOcGQ1d1VjZnlSY0hyRU0wYjdnRnh1aUo2X3VIekgzdFFB?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiekFVX3lxTE5sWUVxM3VsUng0aFpFM3N5djJfWnBhMEJRTkpKZktkUFBYR3dXQkhDOEZ5VWZKNVlKWmJKQ3VmZjRwYnl3UXNlQTZjQ2hZN29wNEhZNnpSMVhrRDlZNDB1QjA4UG9VaDBScGhrSVNBOVVTUkRvVGhZLUdB?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMijgFBVV95cUxOdHBiWFk2RDhYaWs0WTFWNThGZzVhbFJSUkVNNWgzaDBKeThWaVEzZVBNMEh3WUtwTFRJdkFtZDN1RzBlQkp1aWtSak1BYjFqNUxIWW9NcVN1Tk9yN19MUE1qZ3VfZ19ETE5Tb1lXaEZhb0ZFa2tGTTNVOHZtcVFaYkdPSV9kWjlXSjlrZmF3?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiowFBVV95cUxNeWFHVy1EbVptVXlsYWZtLXRCVFFKSEVXdU9ZUTVTY3BpNjlELWFucUlVek9kSnRySGY2aGZOQXBtazlOdThNWHB6LWtDOFdmRXJraEUtUkoyMFZaZ3hYel9OU3BRMjR1eGhkc19TRWFPaWJXVTdoOXZWTHpRSlNYYUdZeG1tbmpXTGZMVWdhNENBXzU4NENDZ3RqU2xWMkVKbEFZ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMingFBVV95cUxPeGpEVm5oajZrYklRYzMyLWM3WjdEQlpZX3RNSGhJM0tfbzlyeE5GYURvczUxUFZpbXhJS0hnZmVhdGx2YXRnb2o2X0xGMnFHcmh6VGx5ODZvNnBKakhQUWJvNXNxaXQ3UHM2bDRreFRGWXlPWC11VDlOUWpySTNXaE5xR0t4SzR2WFBDS3JILTBqeVM1bm84R3VlVzdCdw?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiqgFBVV95cUxOanZHd1l1bmtoY1QxMVUwdUVKck1DRlZ3S1U1TmpaY1hCbllSZkk3dEtsWTNHc0daaGRTVG5GM2tfa0FCNFdlM2xLdnpmNTkzQkVzUWtvNGRZbXJvM1pxdEZOaGFVd1pSVGdhSDRvWm5QVzJ6b2JnbmdfSHZmWFl3eE5tVE5GbUItQ1JZeHN6VU92Vk9WLVhJQ3pwMHQwYzl4SzRTa2NVYUVCZw?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMicEFVX3lxTE9Cb043bFpXOC1YcXBKbW5xWlRqWmRkYk1yeE1OTDJoeTl5ZmdmajBvRUxXVlVGcXc3S2ZsdjBrUXpVcS1JVllLTUowTl82YmxrZkdkLWx6ODJwWlhFaFIzSDlxamRhZjFfcEJoS1pSYkQ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiUkFVX3lxTE12QzZ6ZHVwSVpMQnZJTEcybEw4TlhNOVoxWldWM1RLY2ZKS3UyTS1FSXVVbHdxWFVYZFZHdko1S2FGdnhGYjJvVngtOW5pS3VaWmc?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMirwFBVV95cUxPVzZqTXI4N0V6VkdsTGJibUdaZHM4SUNuLXl1cl8xOTRITV9DVVZvUG5UUmZXTEdkbnNxM2RrM1FCYnhSaXZoNGhPdVVwZ3VHOC1hNVVzanQyUEZRSWpVSV9RWktuN1BaMXRHdi1YZlF0X0V6UDV0SHJDUzB0UHhHVWo0VG4tWG5vZXA2MjRSOHFpWmlEd2dXemYtdXRsdURwUjhRZVNoelF6SDc1OUNv?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiWEFVX3lxTFBmX1FXaWdPTk51aER4RkEwdkRfYmtLeWllYUJLdzNNMmtGNlR6NUkwajlnTzcwUWlhLU14ODkteHRLN1pDOGhab2pXRTNmMnpVdmhYLTlwcl8?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMingFBVV95cUxNNzhBMWZ2V01ZZzctSC1ReXZ0Tm1TVjJVdk5XM1dfQnRIcU1uUUZJblRobjVfMHMtY2FCVDRBVkV6dGREVm50WHl3WnlUMmNkR0NrM21fR3NjNHp0UTdmaV95bFZWYWpraU9JMXNZdkJjbWlBLUNFcUZsNjNsM0xYajdMYWl6d1pKTUJJUDRzWmJ6NXFEY2NDRUlVYWRQZw?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMimwFBVV95cUxNYkU1VG10cnlPWmMyU1ZudmdVZ0hEc3hGNnRCdUlkbTRsQ2hqcHlYZV9RYVN1OGJUT19EWnJhNGtPd3FPM1dkTGVIT04zR3lOSnl2VFZzMm1SV0FlRjJ4enMxS2JxQml6U1JtOVVZT3hwMDVBbjJaTUowbjJCQXhnellLVlRpRkJUYUZGNnd0dWd4a1JmMlFEODMwUQ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMifkFVX3lxTFAwNkVGSXVxUUs3VmtVbVlsZWNXRmdhUl9ESHpsTDZOMnUxQWx0QnhGaVUxbHdUejZZN0JLSTBHeF9IRmtzSjlpdjdqRlZVV250WEhGXzQ0NDZzY0EzeF83TkJrLUpiRHFEakZxZWFsZVdIdVBFWDEyMEkwcHJSZw?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMitAFBVV95cUxPeXlZNVNhZC1sV3VjMVAwZjJRT2hoZVZ2cmltLUFzc3ZuLXJQWU5HS2RFQXlqUGx1UGVyNEpYb3ZkLWNvY3pGOG0yQjAzbDdKdTl0VkZCaHFIbGVmdVh3alFLRnRBNVhHVlIydTE4NlhzdjFoQjRZU0I4ODlTejFmRzhISlRHdlB1MDh5RXhHdjdUSGZXQVNSQk1jRE92djBVNmUyOFRHal94Y3ktMDFZXzloMl_SAboBQVVfeXFMUGZaNE5zNjlTY0psN0YxdHRkbFlLemw3NThydTRyWER3VFY2dlZaM0UwTHZvVThVbmVKTE50YWdFemJyT21HSFVNWnhEcVVfSFdicEJlUWktNUVjcC1QWUs2ek4tSU9XX0VtQjl3YVNQODJ4dDFUQ1EzT1l3d1BzVFlxWEpFX0VlSHRuT04zYUFwWDJ0U1N4MmVsRno1eGE5RW4tbS1CdHVhZHBDVXUyRHlUMnV1V3JVRWRR?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiqwFBVV95cUxQY2pzLVE2UHZQSkpzZ0x3TFE1MzRXUG12Wkt2VldYT1JOQmVjcWFzQWp6Vnl1N3E3aE44Wm1kazJQS01rTnpMQm90Qk03a2w4Y1pHNU9iSVNYNHAwRDlEdFN0d2lQOWwtS0FVRFp6bVBNYVRtSmpxdWtxenViUTl5cHVRSEEzQm10OTN0cDBsTGFYaWpXb0RIWmRvQk5DOUk2TjlNVGw3TlpRWkU?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMipgFBVV95cUxQSDZwd2NqTTlPX1FUa1pDV1RPdkloNmV6NHFmWnlPeGk2aDRoQ25aSFk0RzZ5UnQ0MU9zdzI0enJieExMX2s0T1JKMW9rUGFUV1JCZEpzc1ljSWU1dklNaHZrNGhmRms4NENteHNWNHNYRDVKbFdfQWY4TVJDall5U3doMG53bXZ4X2ZCMEpZc2xMaC04N2lMbU9xTzRmSXVjMnBrXzJn?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMingFBVV95cUxPckpaTkdLMW9EU2xaczc4QTRxekxrOUlRODljNnBNUHNBUW9RRHRSMHNZQjlCejBWOVhoVl9IclVadUtJNDJDendhWTVHdGxsdXJUZmtuMi1ORzFqS2JjOV9GckJSVUtnU2IzUnRDY2lLanNDNUlWRzJnV05ZMHozbzU3djBzX3pHYnJhQm01UzN4bzQzLTBhVlczX2NrQQ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMirwFBVV95cUxPc3I3RFE3YkJiTnljUGlQRmNVcUptQlZ6V1Z0TFVWVC0zb0tSNXlKRzlvX2o0aGgzNUU3djNKbmRqd0xaemV6ME5JVzFBdHdKQ29HVlA3V25TRkVyYThQcUpVQXVTQnc5X0xWemI5ZVZsN0tDWWVGN2FKbmxLVF95bjE3THBwcjFZbURWVXpEV1BNVW40NXFLTlNVRms1QVdGTFlMdjRZWjd3aDRLeXhj?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMigAFBVV95cUxQcl9waE9ncnIybkQxQzBJejM4aUIxX1BfUjJnQTRPaFdkeWtQcTNmQmpCQUJXOWJZRkUtMDFGbnNGWUFwa0t2RFA5TnZJTi10amlYOTdxWTdqeW55QUR2QlJBUmlvNktEcjlZcjF3WkdkdmNhSWdOYjlDUG1wV3ppYQ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMi-...?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMilAFBVV95cUxOUE9iblBHanJBZ1J3OXZNNVkzV2IzbW52c1A3RERLcUdoRDNVdHZRalZyNGxqamhPNjYzWUhkOFFOSWZWQ2l6dENpcllrbUdWaGk0bVBsbUM3VTVTUHFZaFdiUFUySEJtYzRoeDJyalBSVFV0dkdUcG5vaWlKdG9LSlFqSnNtZk0tN0dpR0J3T3hBMF9m?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMilAFBVV95cUxORXh6WURWRnpsaUVvcWthRTdWVnhzb3V2YjloZVd2Ty0xUnVuX3RPdTh3OGVzdVBIMlJYT1J6NVBVVzQ3bmFKVzFSa2V0c0pSTGpaZWstOGlyZ2pjYUtvOVExM3V4TjJwOWtBNVlqWW1GV0JjWUNSR21fNlNPYjVVY3kybE0zaWFsY0Q3eS1nMHdZT3VN?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMirwFBVV95cUxPbVJNX1p3ZGhlT2pkU2tNTXptamJFaFV2ZUhNU083VjNxaE54RzdRbkRtM3hBNlZhUFBKOUV0TzVaNXhxZzVROHhCRlJNSGRPdVU3ZmVDcnlRa3ExZkhkUTNvZ2ZabnI4ZHhIQnRJY2pIT3hHQy1KX1JsYjNQakNOY1o5VXM4SlJsaXlWeTNCMU1SQkMtWWpCb09YejA3T3NjOXgwQW5tSGhVbXBVb1BJ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMid0FVX3lxTE5RYXI5ckZsdGt3S29zd3hXUHJvdS12QS1Ha1h5VTN3aXBYV1ZRY1dISXhUbXlKdThaczRuLUlhOHA2MzM5dTVOTE1hZjRiVExDYU5FU2Fmc1d5U2ZJczJiaHRzVm84Q2M4UlFmbnpkcXNZVTlsRXIw?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiekFVX3lxTE9Femt2U0hvVVMycENPLXcyOXJ2cTIzMEJtYnhENkV0VTRwc21hMEdUbEN1dnk0dms5R3poS1R1WTBMQ09pd0lKeTVUTjZqSXpLLTRRTHhlTFJ5a0M1VnZJblgwdGRnT0MwN3FjNGtma0cxS2doWkxkOFFB?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiogFBVV95cUxNREdUNzI2b2hzQmZhQkVzQWt5UXpMSk50eDdtbk5xX1BRaHZjWEN2VDhfYmNVanVPNGxseUktWmVzRmpkbzR5Y2dDa21jWWRLZE5iTlpkZXpNcHJPTXFncXR2WldIV3BMTTRnWjhpZmVQWWNZSzhqT3ViSVV1N0MwV1ZBUWhjaDV0eVp3SU5MZ1ZGcVlhZ1Q5ZGlYQTNiNGhXS3c?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiiwFBVV95cUxQV3d4d3Y2blhlWmw1UWktTFRQenlKQ2tibVBGZWhYQUZWYjF6cjVWXzNkelM3QUNrSlpLMXhNV0RjRnhaSTItdTlWLVlabHJiOEUwZzBWSWJZWW5MazJPNElwVlM5b2MxLVJ6bXhiNXgtV0FiZk9aVVNEU2J5MUdGNFNkTkhBbVJPb2N3?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiowFBVV95cUxPTkd0ZEN1dnBfQ0ZaNElPUnBZemF0dWpMRGFodkJtVVJfMGNqeVo2ckFqdWVVNmZBOHF2b1F6WGd4UmVKQk11NDBfbzVfdGl0NmVubE9OdmZUdE1jYUVSVUhDeTVDek52U1hHM0JNbkJNTzlVdGQ5bXpzNU4ySWE2bmFLLWc3U1lGbXpTYXQ3dGdyV0tyQ2JlY0tuN3h0NlBqbUxZ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMi_?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMirwFBVV95cUxNdDhoZmh5ZGxsbHY4cDdLTG5ULXRnd3N1V3hHdmVjLUh2QWhlbkstTGJQME5QVjVHcm1TeUJWWk84bGRxWmczSHVZRDVOTTV5MVJZVFpTN3VPdUFBVFdFRWxQRHZxV0dYMEJ6cE9BOXVwdlViaEdZblVrbWNWZ0gzcEJ2S3dGSzIwamxSTkxMRlZHMXBQVDM4TGg1UjNsUHZuSXpGOW1wejJUYVc4N21F?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMinwFBVV95cUxNY1lpVzZyZ3ZwbDMxYVNsd3BJX1lKbzR0NXlkeXcwMEt6Z2RvQVhWU3dQUlpIX0pRQzgzSktIeEN1V1VjZDJ4QzdZRHBLcEFZR2xaRm1PdDhFTUkxVnZmUnh2d2x1YmlFUmR1eUp5aVRsZUM1Ml9UeE9ndDlLQXhGbGJ4LVdwME5OVFZkN2VodjBEUVZNYmFlRkxGQXBjRW8?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMinAFBVV95cUxPX1cybk1VZ2RhLThZbUwwdmphamdKLTNrNGQwUW5ZbHY2VktPbkkyZC02ZnNiZ01hbHdVSGZDTEJmd3lfLS1Jc0hLd293MjRuX2xzdlhfVEdQMmxwdzZqcE1TeDhOd0xmNmhHY0lTc1ZOdWtXLTE2MlFIVjN2TFRRVjRhRTBWMnd4Y1NLWDlXQVQyNEtKVDducy1EVzA?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMijgFBVV95cUxPY2IyNkZMU3ViVlZzc25RX1RoemZKOXpiUVZsRFA2LWQzQjFLX2RYbkRiT3FFdl9WQmhYeDVmd3cyM1lleXR6WjNaQ21zZnpacDZERXZ0X2RpZUVTcU1iTEtsWmZGNEdaRlhJWTE1b1NYWjR1RjZOaU90SHdTVkU3V3RsMXJJbXZkU1MzN1hn?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiowFBVV95cUxPWG9Ka2pITVFhTVRRd2lFeEE1c1c1R29qRWhfQ2NWUmVOV0JHakIycWs0UDM2Z2EtUFhxbVZ4VWxfa1lGSlpxbW1DTEFwSFhUdXNIWnNIZmtnWWs3emM1bG1nRWJrQzRieTZIbzVOOU1yaXZzcFpsYUZ1am1PZkkzdWxldVhLZjgydXVtd001YnhaVkxNZFFWTkZPejN5RS1oM0VN?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMipwFBVV95cUxNWWxtNFY3QzVMeVZfZnVyNUlrWm5ab3RjUmZFOUZld3JZSDVpbFphN3RfZmNlSHE4ME5ZcVFndWI4YUlwc19YUWpwbXNlQ0h4RDljZjJJWlFBdHV6S2VLRzdzaFpNQ1psVmMyT3NYRUxORElrR0tEZUtnYlB0al9nTzlTUzYzenB0WDVFYkM3MWd6RmVkRVFwekI5ekZUTXpCeTZBVDAxSQ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMipAFBVV95cUxQUDNCdVBKVzNSRzJDTXdtaFRqMG9JdlBzRmstd2MyV1FZcm1PZU5mNEFVS0h4c3BYZGJVMm0ybENEcmNUZmdqcV9RSXY0ZWpOMV9TOFR0WnpaLUFjNjZ1OHhMWXo0NkJvVmFTSkU5Zm9BYmJBMkhENk50b1hhUGFRYzhUV2o0aFpYWVNhdF81dmNVNC1EQlM1bXdtWGxZaWFYbE0xSg?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMinwFBVV95cUxOSjU5ekNVTnBTajNpZTNMdy1oLWlWWUIzZk55ejhxLUxNaTVGS3F5dUZVVjZtMU55S1lIbktqakF1aGpfNGdxUFpkVWE2M2J4bHhDMEY3VE1uWW5lU3pwbjdfcWljUi1rR0dIZW1XR0htbnhMMjZnNkdab3RJcDFqM0FUZU5FMkV4UVRqcW5tNlZTajc3NHZXVkJQMUlxd3c?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiigFBVV95cUxQNTZ2ZzRoRXNDNTMzTFczZ2VHNExEUElEbHBEdFJvcVM4TW9yZVE1eFRRTXRCOXlpN1ZQQWNHVktTN0xKNGhqM0p6THp1VzRXZHJaUDFrdzliSWpRa0x0eGp6NkdSTFZtQUJKZmlfZmhoZURwLURBYlUyVjZhVEZ1bDV2SXBsS01PZHc?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMingFBVV95cUxNek1TV1JqY2JGTlEyTm1IYTUxVnRoRU0xOVRFZUFfSjlqUk9HSnJ3OHB6cmlyVnFZRzg4Z1J6ekF2bTRJUlB5YkRudEU5TDQzRjNTWHRSQXhZOEc2Q1g5MTZxcG9RY2RYbk5zZDUzTkVmOUltSm1ObHRZSDBIUnhVX0FKUjVDS0tBZU90Zkp2QTRBWFdsOUhHWFJKb3QwUQ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMioAFBVV95cUxNM3ZPMUNoRkJwRjUtcXp1ME9yNnlZX2dpRHhKMlpnLXRpSW14VkZsR2JPOHFqWFNCbmpkTmRWdHRYMkpiSEpIU1duZ3JRWTR5SXZBMFFrVURkdXVKVGVNeHBna3Npb2wzMS1wQjFxR1lKRVlRdHZfSXo5aXhqUmUzMkNQb1NQOU9KTEUxZi1uQWkyVkE1cFYyRXJrMHZIWGRw?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiQ0FVX3lxTFAyR1hSOWZzQWdYajJzSi1sejZyMXJwM3ZCczRXTjFFM1F5OG53ZHA3c0JIVUphSDZHWEg3MXBvdTdJcWvSAUJBVV95cUxPbDdscWF0bHpSREQxOGl4VFFlMU1qV29YMEZjOWVGTkV2LVFqR2FtTjVHd3pCWUFHelR5Rk9kZG5CYUE?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiqwFBVV95cUxQYnZ2ajNEZ2ZDTFJmTHJndE5nelJ1NFVYSDF4RmhIUnJ1WVI0RXVVSGtjYnlvbmxTUGdvc0RYMVZqZ3lOU2xZbkhjVHJaZDZzVDRxSTZBN1NKeURybkdQWWxmQjdROXRDWFlCc2w2VmZmRTBRR3JsQ2YtY2ZkNWI5MGZtcE0wem9MbnRPaklqZkw3U0I0RXo1UnNYOGYzcnV6aUZVeXpzblgzSE0?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://news.google.com/read/CBMiowFBVV95cUxPYTdQUGtSRHg4QUxLQnUzNGtGT3EtMVl6eEVDNkZIUk5ZRFM2Tk1HMHhxQmVuZ253bkU3M3QxQWp5bTU0VHRUdGlobER1bFBaRXRQeWZaNUJ4WTBpRGFVV2hEaG5tVTNMN0M0cWdXdlItZHF0VHctcnMzWUw5cDdnMWt2OE5DV2pxZWFRS1B1NlIzOTVKTHkwZmFGUHhDM0VZdUNN?hl=en-SG&gl=SG&ceid=SG%3Aen',
#  'https://www.ap7am.com/en/90890/cm-chandrababu-ensures-corruption-free-pension-distribution-in-andhra-pradesh&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIAhAC&usg=AOvVaw1_e5ohH2r7Wdo2GuJ9fRod',
#  'https://anambrastate.gov.ng/anambra-govt-in-collaboration-with-eurolac-reviews-anti-corruption-practices-in-the-state/&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQICRAC&usg=AOvVaw2gtO__ZQ1kQRENFIv2wXsJ',
#  'https://www.modernghana.com/news/1361354/mahama-defends-proposal-to-restructure-free-shs.html&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIARAC&usg=AOvVaw1PlayT8pm7obl93ACGNj0C',
#  'https://www.spectator.co.uk/article/the-corruption-scandal-gripping-xi-jinpings-army/&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIBBAC&usg=AOvVaw1AHmctArgStLUTUye5THRm',
#  'https://en.irna.ir/news/85675336/Iran-determined-to-actively-contribute-to-anti-corruption-efforts&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIBhAC&usg=AOvVaw2umTYL3QPYwg2EPweYZMGK',
#  'https://swisherpost.co.za/crime/license-examiner-held-for-bribing-anti-corruption-investigators/&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQICBAC&usg=AOvVaw1prhj8eYv9W-TYNKi5GKaR',
#  'https://www.etvbharat.com/en/!sports/south-africa-three-cricketers-lonwabo-tsotsobe-thami-tsolekile-ethy-mbhalati-arrested-for-match-fixing-enn24113002405&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIAxAC&usg=AOvVaw2KKEphqf15EH1ny8hzFcyH',
#  'https://www.nst.com.my/news/nation/2024/11/1141853/kedah-sees-rise-civil-servants-arrested-corruption&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIBxAC&usg=AOvVaw2LVVGmcvpJvTnNqRwt6ftn',
#  'https://en.tempo.co/read/1947200/kpk-tni-commander-to-discuss-corruption-handling-in-the-military&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIBRAC&usg=AOvVaw2K1pzQHL5wIEmz1I1qzzcX',
#  'https://www.nationthailand.com/news/general/40043749&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIABAC&usg=AOvVaw0p35fUZiFEbdwF8feKG44U']

# %% [markdown]
# Obtener resultados devolverá la lista, [{'Título': '...', 'Medios': '...', 'Fecha': '...', 'DateTime': '...', ' Desc ':' ... ',' enlace ':' ... ',' img ':' ... '}]

# %%
googlenews.results()
# Out:
# [{'title': 'China suspends military official Miao Hua in anti-corruption purge, denies Dong Jun probe',
#   'desc': None,
#   'date': 'Yesterday',
#   'datetime': datetime.datetime(2024, 11, 29, 12, 34, 55, 155210),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNTBSREJvUlhObWRrUkljR1oxVFJDMkFSaVVBaWdCTWdB=-w64-h64-p-df',
#   'media': 'The Online Citizen Asia',
#   'site': None,
#   'reporter': 'By Yee Loon'},
#  {'title': 'China defence minister placed under investigation for corruption, FT reports',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 155686),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXZTRnBxUVRGYWVFSXRkVlEzVFJDM0FSaVRBaWdCTWdhTmtwQVRzUVk=-w64-h64-p-df',
#   'media': 'The Straits Times',
#   'site': None,
#   'reporter': None},
#  {'title': 'China Defence Minister Dong Jun’s fate unclear as corruption probe sparks differing account',
#   'desc': None,
#   'date': '2 days ago',
#   'datetime': datetime.datetime(2024, 11, 28, 12, 34, 55, 156190),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNUxObGhyY2xObFYwdEJSRUp1VFJDaUFSaTJBaWdCTWdhUlVwUVVJUWc=-w64-h64-p-df',
#   'media': 'Reuters',
#   'site': None,
#   'reporter': 'By Trevor Hunnicutt, Laurie Chen and Idrees Ali'},
#  {'title': 'China dismisses report of corruption probe into Defence Minister Dong Jun',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 156662),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNUNla3BGYUd4NVZuVkVZVzFHVFJDcUFSaXBBaWdCTWdhWlZKYXRKUWc=-w64-h64-p-df',
#   'media': 'South China Morning Post',
#   'site': None,
#   'reporter': 'By Yuanyue Dang'},
#  {'title': 'China’s defence minister placed under investigation for corruption',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 157143),
#   'link': 'https://news.google.com/read/CBMicEFVX3lxTE5qYWpZMlllWS1nNVF6LUVHaWJpcmhBLTZfYV9KclotckJuOXo2YmJzM2o3NUR6MDdNNTR4X29KcG1kaEh1ZG9fNlNNel8zZUlORHdIVy1fd0xzRlF0a1pyX2tQMk9HMUdGalpScnYyTXU?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iL0NnNXRTalV3U25OeVYyZEJlVzVaVFJDb0FSaXJBaWdCTWdrSkZKaU9JV2l4NVFJ=-w64-h64-p-df',
#   'media': 'Financial Times',
#   'site': None,
#   'reporter': 'By Demetri Sevastopulo'},
#  {'title': 'China Defense Minister Investigated for Corruption, FT Says',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 157633),
#   'link': 'https://news.google.com/read/CBMirwFBVV95cUxPaGlQVXcxQWxQcDNMbHNodlhHcFFxSEpkczhWeHp3bWNUMlpidm9FOFRpSm5lamZIRFlEQm5kZVh4WlZqTXhIdzZPa1hNWm9YQVY5elNfRXNqWmNPQTZrbnFWMC1tcENNNG55WmxFLXE3UEpEOXF3RTFpRUlYTWE5RzlOYi1ZMnpJUHZUTjlTbmt5Z3hDcXExTEpaRWx0VmZjVGppTlo3b2pLQkhvMDA0?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNTJZMFpaYkc1cFRYTnBhM1U0VFJDM0FSaVRBaWdCTWdhbG9vek51UVU=-w64-h64-p-df',
#   'media': 'Bloomberg',
#   'site': None,
#   'reporter': None},
#  {'title': 'China investigates defence minister for corruption: Report',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 158106),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNUhaR3BTU0VZNFVHRlhWRjl5VFJDM0FSaVRBaWdCTWdZcFZaVE9LUWc=-w64-h64-p-df',
#   'media': 'The Star Online',
#   'site': None,
#   'reporter': None},
#  {'title': 'China launches corruption probe against Defence Minister Dong Jun: Report',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 158539),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNVpOVmN3YlVGTWJraDZaa3d6VFJEQ0FSaURBaWdCTWdZSmdKSzJMQWM=-w64-h64-p-df',
#   'media': 'Al Jazeera English',
#   'site': None,
#   'reporter': None},
#  {'title': 'China Investigates Defense Minister for Corruption: Report',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 158950),
#   'link': 'https://news.google.com/read/CBMinwFBVV95cUxQWmtEVEZQTUhkM08zcS1JclB1c3o1X2tsOERNZDlCSU44dlJCSjBjWDBsa2tMSXNKUklMRDYwemRQcF9BMjZ1cndwSl9NZ04yVXp6bE9iQkJqdDRpWFZ1MEhMcU50NTdlV0VRbVhVQW9iakxCb2hTOUd3RXhPMXdJNUFtWHl2VHVhVi1ja0k1N1c4cDJXaHBzTVlwWUcxVFE?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNDNaRGx4VEhSTWRuRnVVQzFpVFJDMkFSaVZBaWdCTWdB=-w64-h64-p-df',
#   'media': 'The Irrawaddy',
#   'site': None,
#   'reporter': None},
#  {'title': 'Can technology end corruption?',
#   'desc': None,
#   'date': '15 hours ago',
#   'datetime': datetime.datetime(2024, 11, 29, 21, 34, 55, 159386),
#   'link': 'https://news.google.com/read/CBMiigFBVV95cUxNcURiTTFIbENNM1ZLUUVlTG5GdS1xc1ZEazdWWU9vZENRTXdBMjNySmdPRG9yWTZpRDd6M3lIOWpPS2o0dG5IR3p6RTdpMVBIX0w0ZFpoMnhVSXJqU0VvMEgwcHNwRE9wUFpTa1ljcV9uU3pvMkZDeW1MV2RiUFR2aEszQjg0LURyZWc?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iL0NnNDRTRlpXWW01YWJHNDFVazQyVFJDM0FSaVRBaWdCTWdrQk1Jd0NILWsxeXdF=-w200-h112-p-df',
#   'media': 'Bangkok Post',
#   'site': None,
#   'reporter': None},
#  {'title': 'China probes top military official Miao Hua for corruption',
#   'desc': None,
#   'date': '2 days ago',
#   'datetime': datetime.datetime(2024, 11, 28, 12, 34, 55, 159824),
#   'link': 'https://news.google.com/read/CBMirwFBVV95cUxPQmVMbHJrWFkyaGgwUktPTjNLTjZLOThmQjkxck4tMnRZZEVDQmtySkRXZUkyQ1l0dkc3dDhRRXpWSmJsSVVHb21jcTZnWGhlZ2hHLVg5eGVYV1NGOEF2RTQ4TVhNN0xsZUk4M28xZ3l2R3l3NFRoeW5iSmdxLXRVODNOQ1ZkLUM3RXNXdGdUQ0FBVjA4dzc4YzA1aEFFWVd3WDgyR3Q2ajJDQzk4Qmo0?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXpkV1ZXVFd4aWIzVjVXRXhIVFJDb0FSaXJBaWdCTWdhQllJNk9wUVk=-w200-h112-p-df',
#   'media': 'CNA',
#   'site': None,
#   'reporter': None},
#  {'title': 'DSI summary on PTT-OR corruption case is fake news, agency says',
#   'desc': None,
#   'date': '3 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 9, 34, 55, 160513),
#   'link': 'https://news.google.com/read/CBMiYkFVX3lxTFA4RkMtWmlhdERITm5iS0pyUFhBM05XNGtndDZ2Tm90emFiVzNUV05xUTVhR2FrbmRaS3RMV2tFVVVSNjREMU5iZG51Zjdxck52NjAtWEI4TkZEMXdyeHB5UW13?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNUhSVTV5Y0VFNFFVaGtRbWRPVFJDb0FSaXNBaWdCTWdZWmc1SXFNUWM=-w200-h112-p-df',
#   'media': 'Nation Thailand',
#   'site': None,
#   'reporter': None},
#  {'title': 'Ex-Taipei city councilor found guilty of corruption',
#   'desc': None,
#   'date': 'Yesterday',
#   'datetime': datetime.datetime(2024, 11, 29, 12, 34, 55, 160987),
#   'link': 'https://news.google.com/read/CBMiVkFVX3lxTE15dWc5em9hLU1LYjNMbk9sTkJvcS0tZlFFdXFsN1JpMC1BbGQwSmg1dURoajdOcGQ1d1VjZnlSY0hyRU0wYjdnRnh1aUo2X3VIekgzdFFB?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNVhNRjlOVnkxcWFuVmlka2hVVFJDOEFSaUxBaWdCTWdB=-w200-h112-p-df',
#   'media': 'Focus Taiwan',
#   'site': None,
#   'reporter': None},
#  {'title': 'China investigates defense minister for corruption — report',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 161417),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXZjSEU1YmsxS1gwbE5VRGgxVFJEaEFSamhBU2dCTWdZQkpZU09FUXM=-w200-h112-p-df',
#   'media': 'DW (English)',
#   'site': None,
#   'reporter': None},
#  {'title': 'Former Taipei councilor and aide sentenced for corruption',
#   'desc': None,
#   'date': 'Yesterday',
#   'datetime': datetime.datetime(2024, 11, 29, 12, 34, 55, 161854),
#   'link': 'https://news.google.com/read/CBMiekFVX3lxTE5sWUVxM3VsUng0aFpFM3N5djJfWnBhMEJRTkpKZktkUFBYR3dXQkhDOEZ5VWZKNVlKWmJKQ3VmZjRwYnl3UXNlQTZjQ2hZN29wNEhZNnpSMVhrRDlZNDB1QjA4UG9VaDBScGhrSVNBOVVTUkRvVGhZLUdB?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNXlOVWhNVTBkd04zWlZUM2swVFJEQ0FSaURBaWdCTWdB=-w200-h112-p-df',
#   'media': '台北時報',
#   'site': None,
#   'reporter': 'By Lery Hiciano'},
#  {'title': 'The corruption scandal gripping Xi Jinping’s army',
#   'desc': None,
#   'date': '1 hour ago',
#   'datetime': datetime.datetime(2024, 11, 30, 11, 34, 55, 162283),
#   'link': 'https://news.google.com/read/CBMijgFBVV95cUxOdHBiWFk2RDhYaWs0WTFWNThGZzVhbFJSUkVNNWgzaDBKeThWaVEzZVBNMEh3WUtwTFRJdkFtZDN1RzBlQkp1aWtSak1BYjFqNUxIWW9NcVN1Tk9yN19MUE1qZ3VfZ19ETE5Tb1lXaEZhb0ZFa2tGTTNVOHZtcVFaYkdPSV9kWjlXSjlrZmF3?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iL0NnNVpRbmRwTUcxck1VaHpTVEJQVFJDM0FSaVVBaWdCTWdrRklJcUluQ1lsUlFN=-w200-h112-p-df',
#   'media': 'The Spectator',
#   'site': None,
#   'reporter': 'By Ian Williams'},
#  {'title': 'Kedah sees rise in civil servants arrested for corruption',
#   'desc': None,
#   'date': '2 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 10, 34, 55, 162731),
#   'link': 'https://news.google.com/read/CBMiowFBVV95cUxNeWFHVy1EbVptVXlsYWZtLXRCVFFKSEVXdU9ZUTVTY3BpNjlELWFucUlVek9kSnRySGY2aGZOQXBtazlOdThNWHB6LWtDOFdmRXJraEUtUkoyMFZaZ3hYel9OU3BRMjR1eGhkc19TRWFPaWJXVTdoOXZWTHpRSlNYYUdZeG1tbmpXTGZMVWdhNENBXzU4NENDZ3RqU2xWMkVKbEFZ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iL0NnNTRWR3BvVkhaMlNuVkhOVzB3VFJEQ0FSaURBaWdCTWdrQkVJZ21IZWhyOEFB=-w200-h112-p-df',
#   'media': 'New Straits Times',
#   'site': None,
#   'reporter': 'By Adie Zulkifli'},
#  {'title': 'Former Bank of China chairman sentenced to death on corruption charges',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 163166),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNVpXREpTU214eVNWbzFaazFDVFJDM0FSaVRBaWdCTWdZNW80Z3lQUVU=-w200-h112-p-df',
#   'media': 'Business Standard',
#   'site': None,
#   'reporter': None},
#  {'title': 'China announces top military official is under investigation',
#   'desc': None,
#   'date': 'Yesterday',
#   'datetime': datetime.datetime(2024, 11, 29, 12, 34, 55, 163581),
#   'link': 'https://news.google.com/read/CBMingFBVV95cUxPeGpEVm5oajZrYklRYzMyLWM3WjdEQlpZX3RNSGhJM0tfbzlyeE5GYURvczUxUFZpbXhJS0hnZmVhdGx2YXRnb2o2X0xGMnFHcmh6VGx5ODZvNnBKakhQUWJvNXNxaXQ3UHM2bDRreFRGWXlPWC11VDlOUWpySTNXaE5xR0t4SzR2WFBDS3JILTBqeVM1bm84R3VlVzdCdw?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNUdWazFGUWpSaFkzQnpjM2RCVFJDM0FSaVRBaWdCTWdZZEVwb0tFZ3M=-w200-h112-p-df',
#   'media': 'The Washington Post',
#   'site': None,
#   'reporter': 'By Katrina Northrop and Christian Shepherd'},
#  {'title': "China's defence minister Dong Jun under investigation for corruption: Report",
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 164030),
#   'link': 'https://news.google.com/read/CBMiqgFBVV95cUxOanZHd1l1bmtoY1QxMVUwdUVKck1DRlZ3S1U1TmpaY1hCbllSZkk3dEtsWTNHc0daaGRTVG5GM2tfa0FCNFdlM2xLdnpmNTkzQkVzUWtvNGRZbXJvM1pxdEZOaGFVd1pSVGdhSDRvWm5QVzJ6b2JnbmdfSHZmWFl3eE5tVE5GbUItQ1JZeHN6VU92Vk9WLVhJQ3pwMHQwYzl4SzRTa2NVYUVCZw?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNVhURVkwT1dGdmNtODJWVzk1VFJDb0FSaXJBaWdCTWdhTmtvd1VNUVk=-w200-h112-p-df',
#   'media': 'CNA',
#   'site': None,
#   'reporter': None},
#  {'title': 'Sabah corruption scandal ahead of 2025 state polls poses fresh challenge for Anwar',
#   'desc': None,
#   'date': '10 days ago',
#   'datetime': datetime.datetime(2024, 11, 20, 12, 34, 55, 164448),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXhXblJCYUdOMWJUbFZibGM0VFJDM0FSaVRBaWdCTWdZaFJZak5JUWs=-w200-h112-p-df',
#   'media': 'The Straits Times',
#   'site': None,
#   'reporter': None},
#  {'title': 'China says top military official suspended, placed under investigation',
#   'desc': None,
#   'date': '2 days ago',
#   'datetime': datetime.datetime(2024, 11, 28, 12, 34, 55, 164888),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNWlYMVZGY1hJMWQzRkRlRGhCVFJDb0FSaXNBaWdCTWdhZEFwWUxEZ3c=-w200-h112-p-df',
#   'media': 'Al Jazeera English',
#   'site': None,
#   'reporter': None},
#  {'title': 'China investigates head of Shanghai’s free-trade zone for corruption',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 165323),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXpPRmR6Tm14TE5GUlhWVUk0VFJDcUFSaXBBaWdCTWdZdEZZQ3VGUW8=-w200-h112-p-df',
#   'media': 'South China Morning Post',
#   'site': None,
#   'reporter': 'By Vanessa Cai'},
#  {'title': 'Slovakia’s central bank governor given reprieve in corruption case',
#   'desc': None,
#   'date': 'Yesterday',
#   'datetime': datetime.datetime(2024, 11, 29, 12, 34, 55, 165854),
#   'link': 'https://news.google.com/read/CBMicEFVX3lxTE9Cb043bFpXOC1YcXBKbW5xWlRqWmRkYk1yeE1OTDJoeTl5ZmdmajBvRUxXVlVGcXc3S2ZsdjBrUXpVcS1JVllLTUowTl82YmxrZkdkLWx6ODJwWlhFaFIzSDlxamRhZjFfcEJoS1pSYkQ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNW5Wa3QxZVRWWVoxTTRYM2QwVFJDb0FSaXJBaWdCTWdZcE5aYk5IUWs=-w200-h112-p-df',
#   'media': 'Financial Times',
#   'site': None,
#   'reporter': 'By Raphael Minder'},
#  {'title': 'High-level Corruption Probe Leads to Insults and Death Threats in the Philippines',
#   'desc': None,
#   'date': '5 days ago',
#   'datetime': datetime.datetime(2024, 11, 25, 12, 34, 55, 166311),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNDVYMmxvWVY4eVpXVTVibEl4VFJEREFSaURBaWdCTWdZZEpaVE5tUWs=-w200-h112-p-df',
#   'media': 'The Diplomat',
#   'site': None,
#   'reporter': 'By Mong Palatino'},
#  {'title': 'Corruption is like cancer cells eroding the nation - Sultan Nazrin',
#   'desc': None,
#   'date': '8 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 4, 34, 55, 166795),
#   'link': 'https://news.google.com/read/CBMiUkFVX3lxTE12QzZ6ZHVwSVpMQnZJTEcybEw4TlhNOVoxWldWM1RLY2ZKS3UyTS1FSXVVbHdxWFVYZFZHdko1S2FGdnhGYjJvVngtOW5pS3VaWmc?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNVBObVZEYkhoWFpqUm1VazFYVFJDdUFSaWlBaWdCTWdZcGhaRE50UVk=-w200-h112-p-df',
#   'media': 'Malaysiakini',
#   'site': None,
#   'reporter': None},
#  {'title': 'China’s Third Defense Minister Under Probe For Corruption? Is Xi Jinping’s “Personal Ambitions” Hurting PLA?',
#   'desc': None,
#   'date': 'Yesterday',
#   'datetime': datetime.datetime(2024, 11, 29, 12, 34, 55, 167273),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNWtSbGgzTVdOTFpVMWpWakl5VFJDZkFSaS1BaWdCTWdZQi1vUUVVd00=-w200-h112-p-df',
#   'media': 'EurAsian Times',
#   'site': None,
#   'reporter': 'By Shubhangi Palve'},
#  {'title': 'Chinese Defence Minister Dong Jun under investigation for corruption – report',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 167730),
#   'link': 'https://news.google.com/read/CBMirwFBVV95cUxPVzZqTXI4N0V6VkdsTGJibUdaZHM4SUNuLXl1cl8xOTRITV9DVVZvUG5UUmZXTEdkbnNxM2RrM1FCYnhSaXZoNGhPdVVwZ3VHOC1hNVVzanQyUEZRSWpVSV9RWktuN1BaMXRHdi1YZlF0X0V6UDV0SHJDUzB0UHhHVWo0VG4tWG5vZXA2MjRSOHFpWmlEd2dXemYtdXRsdURwUjhRZVNoelF6SDc1OUNv?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNHhUbGRQWjAxMFVEVTNRak54VFJDN0FSaU5BaWdCTWdB=-w200-h112-p-df',
#   'media': 'Hong Kong Free Press',
#   'site': None,
#   'reporter': 'By Oliver Hotham'},
#  {'title': 'Former Taipei councilor found guilty of corruption',
#   'desc': None,
#   'date': '5 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 7, 34, 55, 168152),
#   'link': 'https://news.google.com/read/CBMiWEFVX3lxTFBmX1FXaWdPTk51aER4RkEwdkRfYmtLeWllYUJLdzNNMmtGNlR6NUkwajlnTzcwUWlhLU14ODkteHRLN1pDOGhab2pXRTNmMnpVdmhYLTlwcl8?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNHhkbEJMVkdSbGRHOXdSbTluVFJDMUFSaVdBaWdCTWdZdE1JcXVIUWs=-w200-h112-p-df',
#   'media': 'Taiwan News',
#   'site': None,
#   'reporter': None},
#  {'title': 'Singapore gears up for biggest corruption trial in decades',
#   'desc': None,
#   'date': '23 Sept',
#   'datetime': datetime.datetime(2024, 9, 23, 0, 0),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iL0NnNXNhbXB0U1dsNlFtRTJPREprVFJDakFSaTJBaWdCTWdtVklwd1VsU3FpWndJ=-w200-h112-p-df',
#   'media': 'Al Jazeera English',
#   'site': None,
#   'reporter': 'By Nicholas Yong'},
#  {'title': "'Is the ICC Anti-Corruption Unit... ?' Ex-Pakistan batter expresses disgust",
#   'desc': None,
#   'date': '7 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 5, 34, 55, 169007),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iL0NnNU5WblIwZVVobFVGWkthQzFvVFJDb0FSaXNBaWdCTWdrRmNKU3dzT2FwQ3dJ=-w200-h112-p-df',
#   'media': 'The Times of India',
#   'site': None,
#   'reporter': None},
#  {'title': 'A Top Military Official in China Is Suspended Under Suspicion of Corruption',
#   'desc': None,
#   'date': '2 days ago',
#   'datetime': datetime.datetime(2024, 11, 28, 12, 34, 55, 169435),
#   'link': 'https://news.google.com/read/CBMingFBVV95cUxNNzhBMWZ2V01ZZzctSC1ReXZ0Tm1TVjJVdk5XM1dfQnRIcU1uUUZJblRobjVfMHMtY2FCVDRBVkV6dGREVm50WHl3WnlUMmNkR0NrM21fR3NjNHp0UTdmaV95bFZWYWpraU9JMXNZdkJjbWlBLUNFcUZsNjNsM0xYajdMYWl6d1pKTUJJUDRzWmJ6NXFEY2NDRUlVYWRQZw?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNUxUVVJsVW5oNVFWQkZSRmhTVFJDM0FSaVRBaWdCTWdZZEVwb0tFZ3M=-w200-h112-p-df',
#   'media': 'The New York Times',
#   'site': None,
#   'reporter': 'By Chris Buckley'},
#  {'title': 'China investigating defense minister for corruption, FT reports',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 169867),
#   'link': 'https://news.google.com/read/CBMimwFBVV95cUxNYkU1VG10cnlPWmMyU1ZudmdVZ0hEc3hGNnRCdUlkbTRsQ2hqcHlYZV9RYVN1OGJUT19EWnJhNGtPd3FPM1dkTGVIT04zR3lOSnl2VFZzMm1SV0FlRjJ4enMxS2JxQml6U1JtOVVZT3hwMDVBbjJaTUowbjJCQXhnellLVlRpRkJUYUZGNnd0dWd4a1JmMlFEODMwUQ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNUVjRlp4YzNKdlEzRldSakprVFJDb0FSaXNBaWdCTWdZRkdhREdFZ3M=-w200-h112-p-df',
#   'media': 'Nikkei Asia',
#   'site': None,
#   'reporter': None},
#  {'title': 'How the expansion of U.S. anti-corruption law affects Brazil',
#   'desc': None,
#   'date': '23 hours ago',
#   'datetime': datetime.datetime(2024, 11, 29, 13, 34, 55, 170262),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iJ0NnNU5TSEJxTWt0aUxTMVRORTVqVFJDM0FSaVRBaWdCTWdNQmdBZw=-w200-h112-p-df',
#   'media': 'The Brazilian Report',
#   'site': None,
#   'reporter': None},
#  {'title': 'Imran Khans wife Bushra Bibi dodges arrest in 190 million pound corruption case',
#   'desc': None,
#   'date': '4 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 8, 34, 55, 170655),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iL0NnNW9jSEZoV0hWUWNtSm9SMUZRVFJEQ0FSaUVBaWdCTWdrTlFaNm1ucWsxWndJ=-w200-h112-p-df',
#   'media': 'The Tribune India',
#   'site': None,
#   'reporter': None},
#  {'title': 'Corruption Casebook 2: Hidden Victims of Corruption',
#   'desc': None,
#   'date': '25 Jul',
#   'datetime': datetime.datetime(2024, 7, 25, 0, 0),
#   'link': 'https://news.google.com/read/CBMifkFVX3lxTFAwNkVGSXVxUUs3VmtVbVlsZWNXRmdhUl9ESHpsTDZOMnUxQWx0QnhGaVUxbHdUejZZN0JLSTBHeF9IRmtzSjlpdjdqRlZVV250WEhGXzQ0NDZzY0EzeF83TkJrLUpiRHFEakZxZWFsZVdIdVBFWDEyMEkwcHJSZw?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNDRRamR0Tlc5eFNHb3pNRk5CVFJDTEFoaTlBU2dCTWdhZEU1U3NGUXM=-w200-h112-p-df',
#   'media': 'Corrupt Practices Investigation Bureau',
#   'site': None,
#   'reporter': None},
#  {'title': 'Total Energies pauses investments into Adani Group on bribery charges',
#   'desc': None,
#   'date': '4 days ago',
#   'datetime': datetime.datetime(2024, 11, 26, 12, 34, 55, 172011),
#   'link': 'https://news.google.com/read/CBMitAFBVV95cUxPeXlZNVNhZC1sV3VjMVAwZjJRT2hoZVZ2cmltLUFzc3ZuLXJQWU5HS2RFQXlqUGx1UGVyNEpYb3ZkLWNvY3pGOG0yQjAzbDdKdTl0VkZCaHFIbGVmdVh3alFLRnRBNVhHVlIydTE4NlhzdjFoQjRZU0I4ODlTejFmRzhISlRHdlB1MDh5RXhHdjdUSGZXQVNSQk1jRE92djBVNmUyOFRHal94Y3ktMDFZXzloMl_SAboBQVVfeXFMUGZaNE5zNjlTY0psN0YxdHRkbFlLemw3NThydTRyWER3VFY2dlZaM0UwTHZvVThVbmVKTE50YWdFemJyT21HSFVNWnhEcVVfSFdicEJlUWktNUVjcC1QWUs2ek4tSU9XX0VtQjl3YVNQODJ4dDFUQ1EzT1l3d1BzVFlxWEpFX0VlSHRuT04zYUFwWDJ0U1N4MmVsRno1eGE5RW4tbS1CdHVhZHBDVXUyRHlUMnV1V3JVRWRR?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNUhWbnBsZURCdVdsVnhhbVEyVFJEQ0FSaURBaWdCTWdheFZKaXZwUWc=-w200-h112-p-df',
#   'media': 'Al Jazeera English',
#   'site': None,
#   'reporter': None},
#  {'title': 'FT: China defence minister placed under investigation for corruption',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 172428),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNWtYM2xuV2taWlEyYzFNRVJDVFJDM0FSaVRBaWdCTWdZcFZaVE9LUWc=-w200-h112-p-df',
#   'media': 'Malay Mail',
#   'site': None,
#   'reporter': None},
#  {'title': 'Constant Vigilance Vital To The Fight Against Corruption',
#   'desc': None,
#   'date': '30 Apr',
#   'datetime': datetime.datetime(2024, 4, 30, 0, 0),
#   'link': 'https://news.google.com/read/CBMiqwFBVV95cUxQY2pzLVE2UHZQSkpzZ0x3TFE1MzRXUG12Wkt2VldYT1JOQmVjcWFzQWp6Vnl1N3E3aE44Wm1kazJQS01rTnpMQm90Qk03a2w4Y1pHNU9iSVNYNHAwRDlEdFN0d2lQOWwtS0FVRFp6bVBNYVRtSmpxdWtxenViUTl5cHVRSEEzQm10OTN0cDBsTGFYaWpXb0RIWmRvQk5DOUk2TjlNVGw3TlpRWkU?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNUxZbXByU1UxdmRuQnBRMmRzVFJEQkFSaUZBaWdCTWdZTkE0aXJpUXc=-w200-h112-p-df',
#   'media': 'Corrupt Practices Investigation Bureau',
#   'site': None,
#   'reporter': None},
#  {'title': 'A Corruption Case That Spilled Across Latin America Is Coming Undone',
#   'desc': None,
#   'date': '4 days ago',
#   'datetime': datetime.datetime(2024, 11, 26, 12, 34, 55, 173349),
#   'link': 'https://news.google.com/read/CBMipgFBVV95cUxQSDZwd2NqTTlPX1FUa1pDV1RPdkloNmV6NHFmWnlPeGk2aDRoQ25aSFk0RzZ5UnQ0MU9zdzI0enJieExMX2s0T1JKMW9rUGFUV1JCZEpzc1ljSWU1dklNaHZrNGhmRms4NENteHNWNHNYRDVKbFdfQWY4TVJDall5U3doMG53bXZ4X2ZCMEpZc2xMaC04N2lMbU9xTzRmSXVjMnBrXzJn?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNUxaVlJJZGxGdFJIRkxkRTlqVFJDM0FSaVRBaWdCTWdZSk1vUUlHZ28=-w200-h112-p-df',
#   'media': 'The New York Times',
#   'site': None,
#   'reporter': 'By Jack Nicas and Ana Ionova'},
#  {'title': 'KPK, TNI Commander to Discuss Corruption Handling in the Military',
#   'desc': None,
#   'date': '3 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 9, 34, 55, 173791),
#   'link': 'https://news.google.com/read/CBMingFBVV95cUxPckpaTkdLMW9EU2xaczc4QTRxekxrOUlRODljNnBNUHNBUW9RRHRSMHNZQjlCejBWOVhoVl9IclVadUtJNDJDendhWTVHdGxsdXJUZmtuMi1ORzFqS2JjOV9GckJSVUtnU2IzUnRDY2lLanNDNUlWRzJnV05ZMHozbzU3djBzX3pHYnJhQm01UzN4bzQzLTBhVlczX2NrQQ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNVZTblpYVVc4NUxYaEZOMDAyVFJDb0FSaXNBaWdCTWdhQlZZUUxOZ1E=-w200-h112-p-df',
#   'media': 'Tempo.co English',
#   'site': None,
#   'reporter': None},
#  {'title': 'Chinese defense minister under investigation for alleged corruption',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 174229),
#   'link': 'https://news.google.com/read/CBMirwFBVV95cUxPc3I3RFE3YkJiTnljUGlQRmNVcUptQlZ6V1Z0TFVWVC0zb0tSNXlKRzlvX2o0aGgzNUU3djNKbmRqd0xaemV6ME5JVzFBdHdKQ29HVlA3V25TRkVyYThQcUpVQXVTQnc5X0xWemI5ZVZsN0tDWWVGN2FKbmxLVF95bjE3THBwcjFZbURWVXpEV1BNVW40NXFLTlNVRms1QVdGTFlMdjRZWjd3aDRLeXhj?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNTBUVk5xU2xac2JYaG1jVXRtVFJDM0FSaVRBaWdCTWdZcFZaVE9LUWc=-w200-h112-p-df',
#   'media': 'Semafor',
#   'site': None,
#   'reporter': None},
#  {'title': 'STOLEN FUTURES: The impact of corruption on children in Africa.',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 174653),
#   'link': 'https://news.google.com/read/CBMigAFBVV95cUxQcl9waE9ncnIybkQxQzBJejM4aUIxX1BfUjJnQTRPaFdkeWtQcTNmQmpCQUJXOWJZRkUtMDFGbnNGWUFwa0t2RFA5TnZJTi10amlYOTdxWTdqeW55QUR2QlJBUmlvNktEcjlZcjF3WkdkdmNhSWdOYjlDUG1wV3ppYQ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': None,
#   'media': 'African Union',
#   'site': None,
#   'reporter': None},
#  {'title': 'Corruption in Chinese army continues to haunt Xi Jinping; PLA purge expands',
#   'desc': None,
#   'date': '23 hours ago',
#   'datetime': datetime.datetime(2024, 11, 29, 13, 34, 55, 175095),
#   'link': 'https://news.google.com/read/CBMi-...?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNVRlRFZ4ZUZsVFIyOWtZMFpwVFJDM0FSaVRBaWdCTWdZWkFxUUxEZ3c=-w200-h112-p-df',
#   'media': 'Business Standard',
#   'site': None,
#   'reporter': 'By Bhaswar Kumar'},
#  {'title': 'Benjamin Bestgen: Corruption, I presume? A useful lesson from Singapore',
#   'desc': None,
#   'date': 'Yesterday',
#   'datetime': datetime.datetime(2024, 11, 29, 12, 34, 55, 175498),
#   'link': 'https://news.google.com/read/CBMilAFBVV95cUxOUE9iblBHanJBZ1J3OXZNNVkzV2IzbW52c1A3RERLcUdoRDNVdHZRalZyNGxqamhPNjYzWUhkOFFOSWZWQ2l6dENpcllrbUdWaGk0bVBsbUM3VTVTUHFZaFdiUFUySEJtYzRoeDJyalBSVFV0dkdUcG5vaWlKdG9LSlFqSnNtZk0tN0dpR0J3T3hBMF9m?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNTRjSEZXTUdjNFR6aHlaWFk0VFJESUFSaklBU2dCTWdZaFpZNnNMUWM=-w200-h112-p-df',
#   'media': 'Scottish Legal News',
#   'site': None,
#   'reporter': None},
#  {'title': 'China suspends top military official Miao Hua amid corruption probe',
#   'desc': None,
#   'date': '2 days ago',
#   'datetime': datetime.datetime(2024, 11, 28, 12, 34, 55, 175906),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXhUbk5NVVRaalUySkRRbkJ4VFJDb0FSaXNBaWdCTWdZZEFwWUxFZ3M=-w200-h112-p-df',
#   'media': 'The Times of India',
#   'site': None,
#   'reporter': None},
#  {'title': "Iswaran corruption charges amended as ex-minister, Ong Beng Seng would have 'interest in denying' corruption: AGC",
#   'desc': None,
#   'date': '24 Sept',
#   'datetime': datetime.datetime(2024, 9, 24, 0, 0),
#   'link': 'https://news.google.com/read/CBMilAFBVV95cUxORXh6WURWRnpsaUVvcWthRTdWVnhzb3V2YjloZVd2Ty0xUnVuX3RPdTh3OGVzdVBIMlJYT1J6NVBVVzQ3bmFKVzFSa2V0c0pSTGpaZWstOGlyZ2pjYUtvOVExM3V4TjJwOWtBNVlqWW1GV0JjWUNSR21fNlNPYjVVY3kybE0zaWFsY0Q3eS1nMHdZT3VN?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iL0NnNTZkRlZGUldwWWVsbE9NbVUyVFJDb0FSaXJBaWdCTWdrSlFaRFZLS2VwQ0FJ=-w200-h112-p-df',
#   'media': 'CNA',
#   'site': None,
#   'reporter': 'By Rachel Chan Chin Wai'},
#  {'title': 'First cryptocurrency corruption case in China is former central bank official',
#   'desc': None,
#   'date': '9 days ago',
#   'datetime': datetime.datetime(2024, 11, 21, 12, 34, 55, 176888),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iJ0NnNVhOeTE0YlZoUk1sUTNjbEZ4VFJDcUFSaXBBaWdCTWdPTkZnSQ=-w200-h112-p-df',
#   'media': 'South China Morning Post',
#   'site': None,
#   'reporter': 'By Sylvie Zhuang'},
#  {'title': 'Escaping Trump’s tariffs has required navigating a ‘broken’ system vulnerable to corruption, businesses and academics say',
#   'desc': None,
#   'date': '4 days ago',
#   'datetime': datetime.datetime(2024, 11, 26, 12, 34, 55, 177382),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNDFkMmxTY2t0RWJtSnZSelYzVFJDb0FSaXJBaWdCTWdZQllJQnB4Z1U=-w200-h112-p-df',
#   'media': 'CNN',
#   'site': None,
#   'reporter': 'By Matt Egan'},
#  {'title': 'China defense minister being investigated for corruption, report says',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 177876),
#   'link': 'https://news.google.com/read/CBMirwFBVV95cUxPbVJNX1p3ZGhlT2pkU2tNTXptamJFaFV2ZUhNU083VjNxaE54RzdRbkRtM3hBNlZhUFBKOUV0TzVaNXhxZzVROHhCRlJNSGRPdVU3ZmVDcnlRa3ExZkhkUTNvZ2ZabnI4ZHhIQnRJY2pIT3hHQy1KX1JsYjNQakNOY1o5VXM4SlJsaXlWeTNCMU1SQkMtWWpCb09YejA3T3NjOXgwQW5tSGhVbXBVb1BJ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNU1OazR0WDBWbFVqZFpXRFpUVFJDMkFSaVZBaWdCTWdZQmNKYk5xUWM=-w200-h112-p-df',
#   'media': 'The Japan Times',
#   'site': None,
#   'reporter': 'By Jesse Johnson'},
#  {'title': 'Sri Lanka votes for change',
#   'desc': None,
#   'date': '2 days ago',
#   'datetime': datetime.datetime(2024, 11, 28, 12, 34, 55, 178294),
#   'link': 'https://news.google.com/read/CBMid0FVX3lxTE5RYXI5ckZsdGt3S29zd3hXUHJvdS12QS1Ha1h5VTN3aXBYV1ZRY1dISXhUbXlKdThaczRuLUlhOHA2MzM5dTVOTE1hZjRiVExDYU5FU2Fmc1d5U2ZJczJiaHRzVm84Q2M4UlFmbnpkcXNZVTlsRXIw?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXVUMVZZVDBwNllWVmtWa2d3VFJDOEFSaUxBaWdCTWdZQkVJSUdVUUk=-w200-h112-p-df',
#   'media': 'The Interpreter',
#   'site': None,
#   'reporter': 'By Gordon Weiss'},
#  {'title': 'Understanding corruption and its relationship with AML',
#   'desc': None,
#   'date': '30 Oct',
#   'datetime': datetime.datetime(2024, 10, 30, 0, 0),
#   'link': 'https://news.google.com/read/CBMiekFVX3lxTE9Femt2U0hvVVMycENPLXcyOXJ2cTIzMEJtYnhENkV0VTRwc21hMEdUbEN1dnk0dms5R3poS1R1WTBMQ09pd0lKeTVUTjZqSXpLLTRRTHhlTFJ5a0M1VnZJblgwdGRnT0MwN3FjNGtma0cxS2doWkxkOFFB?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXFRMWxoU1hBM2NEQlpVRmxpVFJESEFSajlBU2dCTWdZQmtaS3NQUWM=-w200-h112-p-df',
#   'media': 'ComplyAdvantage',
#   'site': None,
#   'reporter': None},
#  {'title': '2024/42 "Corruption Eradication in Indonesia: One Step Forward, Two Steps Back" by Astrid Meilasari-Sugiana, Gunardi Endro, Siwage Dharma Negara',
#   'desc': None,
#   'date': '10 Jun',
#   'datetime': datetime.datetime(2024, 6, 10, 0, 0),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNUZiVU5KVFhnekxURlpWbFJMVFJDM0FSaVRBaWdCTWdheGs0Snd3UVE=-w200-h112-p-df',
#   'media': 'ISEAS-Yusof Ishak Institute',
#   'site': None,
#   'reporter': None},
#  {'title': 'Singapore ex-Transport Minister Iswaran pleads guilty in graft trial',
#   'desc': None,
#   'date': '24 Sept',
#   'datetime': datetime.datetime(2024, 9, 24, 0, 0),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNHpZMUJNU1dScGMyRjNUMnRVVFJDb0FSaXNBaWdCTWdZOVU1UXlwUWc=-w200-h112-p-df',
#   'media': 'Al Jazeera English',
#   'site': None,
#   'reporter': None},
#  {'title': "Explainer: 'The Corrupt Solar Project': Adani embroiled in US findings of bribery scheme",
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 179992),
#   'link': 'https://news.google.com/read/CBMiogFBVV95cUxNREdUNzI2b2hzQmZhQkVzQWt5UXpMSk50eDdtbk5xX1BRaHZjWEN2VDhfYmNVanVPNGxseUktWmVzRmpkbzR5Y2dDa21jWWRLZE5iTlpkZXpNcHJPTXFncXR2WldIV3BMTTRnWjhpZmVQWWNZSzhqT3ViSVV1N0MwV1ZBUWhjaDV0eVp3SU5MZ1ZGcVlhZ1Q5ZGlYQTNiNGhXS3c?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNDFWRWx1VTJoUFQzbFRaMW96VFJDMkFSaVZBaWdCTWdhbGhZN05OUVk=-w200-h112-p-df',
#   'media': 'Reuters',
#   'site': None,
#   'reporter': 'By Aditya Kalra and Aditi Shah'},
#  {'title': 'Horizontal Review of Gatekeepers’ Technical Compliance Related to Corruption',
#   'desc': None,
#   'date': '9 Jul',
#   'datetime': datetime.datetime(2024, 7, 9, 0, 0),
#   'link': 'https://news.google.com/read/CBMiiwFBVV95cUxQV3d4d3Y2blhlWmw1UWktTFRQenlKQ2tibVBGZWhYQUZWYjF6cjVWXzNkelM3QUNrSlpLMXhNV0RjRnhaSTItdTlWLVlabHJiOEUwZzBWSWJZWW5MazJPNElwVlM5b2MxLVJ6bXhiNXgtV0FiZk9aVVNEU2J5MUdGNFNkTkhBbVJPb2N3?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXlkbFZtUmpCSk1sbDRObEo1VFJDTEFoaTlBU2dCTWdZTkVaQXVKUWc=-w200-h112-p-df',
#   'media': 'Documents - Financial Action Task Force (FATF)',
#   'site': None,
#   'reporter': None},
#  {'title': 'Chinese defence minister placed under investigation for corruption.',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 180919),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNHRRMkpxVURFeFpuQk1hbXBmVFJDcEFSaXBBaWdCTWdZeFZJaHdxUVk=-w200-h112-p-df',
#   'media': 'ForexLive',
#   'site': None,
#   'reporter': 'By Eamonn Sheridan'},
#  {'title': 'Lost nearly $55 billion since U.S. corruption charges: Adani Group',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 181403),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNDVUSHBJVlUxM09UbHFkMGszVFJDb0FSaXNBaWdCTWdZTmtZd29QUVk=-w200-h112-p-df',
#   'media': 'The Hindu',
#   'site': None,
#   'reporter': None},
#  {'title': 'Sarawak Metro invites MACC, ombudsman to audit as part of zero-tolerance policy on corruption',
#   'desc': None,
#   'date': '2 days ago',
#   'datetime': datetime.datetime(2024, 11, 28, 12, 34, 55, 181922),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNVhTVnBmTTFaVVowOTFUa2xYVFJDOUFSaUxBaWdCTWdhbFpKRE9LUVk=-w200-h112-p-df',
#   'media': 'Malay Mail',
#   'site': None,
#   'reporter': None},
#  {'title': 'Dossier no. 82: How Neoliberalism Has Wielded ‘Corruption’ to Privatise Life in Africa',
#   'desc': None,
#   'date': '22 hours ago',
#   'datetime': datetime.datetime(2024, 11, 29, 14, 34, 55, 182374),
#   'link': 'https://news.google.com/read/CBMiowFBVV95cUxPTkd0ZEN1dnBfQ0ZaNElPUnBZemF0dWpMRGFodkJtVVJfMGNqeVo2ckFqdWVVNmZBOHF2b1F6WGd4UmVKQk11NDBfbzVfdGl0NmVubE9OdmZUdE1jYUVSVUhDeTVDek52U1hHM0JNbkJNTzlVdGQ5bXpzNU4ySWE2bmFLLWc3U1lGbXpTYXQ3dGdyV0tyQ2JlY0tuN3h0NlBqbUxZ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNDNlRXh5ZG1abldHVnBkVWhyVFJDX0FSaUhBaWdCTWdhWlVwUnBKUWs=-w200-h112-p-df',
#   'media': 'MR Online',
#   'site': None,
#   'reporter': None},
#  {'title': 'Singapore’s ex-transport minister jailed for 12 months in landmark ruling',
#   'desc': None,
#   'date': '3 Oct',
#   'datetime': datetime.datetime(2024, 10, 3, 0, 0),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXRVazlzVUdadWExSmpNa0pDVFJDakFSaTJBaWdCTWdZQlFKaW9xUWc=-w200-h112-p-df',
#   'media': 'Al Jazeera English',
#   'site': None,
#   'reporter': None},
#  {'title': 'Singapore’s ex-transport minister hit with 8 new charges in corruption case',
#   'desc': None,
#   'date': '25 Mar',
#   'datetime': datetime.datetime(2024, 3, 25, 0, 0),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNW5VbFprTFhRNFpHdHlaVkZTVFJEQ0FSaURBaWdCTWdZbFJZck9vUWM=-w200-h112-p-df',
#   'media': 'Al Jazeera English',
#   'site': None,
#   'reporter': None},
#  {'title': '2024/44 "Anti-Corruption Politics and Shifts in Central-Local Relations in Vietnam" by Nguyen Khac Giang',
#   'desc': None,
#   'date': '13 Jun',
#   'datetime': datetime.datetime(2024, 6, 13, 0, 0),
#   'link': 'https://news.google.com/read/CBMi_?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iL0NnNXFiR1ZoY1RoNlVIZHZjMkoxVFJDM0FSaVRBaWdCTWdrTlFveW5tbVUxcndF=-w200-h112-p-df',
#   'media': 'ISEAS-Yusof Ishak Institute',
#   'site': None,
#   'reporter': None},
#  {'title': 'Indian Billionaire Gautam Adani’s Company Says He Hasn’t Been Charged For Violating U.S. Corruption Law',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 184031),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNURNMUpYY0ZWWFVHVldSbWRFVFJDM0FSaVRBaWdCTWdZWk41aEpuZ2c=-w200-h112-p-df',
#   'media': 'Forbes',
#   'site': None,
#   'reporter': 'By Jonathan Burgos'},
#  {'title': 'Why China is purging its senior military officials',
#   'desc': None,
#   'date': '22 hours ago',
#   'datetime': datetime.datetime(2024, 11, 29, 14, 34, 55, 184457),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNWlWV3hYVmxKV2VHRlJaRWRoVFJDb0FSaXNBaWdCTWdB=-w200-h112-p-df',
#   'media': 'The Times of India',
#   'site': None,
#   'reporter': None},
#  {'title': 'Explainer: How corruption facilitates organized crime',
#   'desc': None,
#   'date': '25 days ago',
#   'datetime': datetime.datetime(2024, 11, 5, 12, 34, 55, 184876),
#   'link': 'https://news.google.com/read/CBMirwFBVV95cUxNdDhoZmh5ZGxsbHY4cDdLTG5ULXRnd3N1V3hHdmVjLUh2QWhlbkstTGJQME5QVjVHcm1TeUJWWk84bGRxWmczSHVZRDVOTTV5MVJZVFpTN3VPdUFBVFdFRWxQRHZxV0dYMEJ6cE9BOXVwdlViaEdZblVrbWNWZ0gzcEJ2S3dGSzIwamxSTkxMRlZHMXBQVDM4TGg1UjNsUHZuSXpGOW1wejJUYVc4N21F?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iMkNnNHRaM0YwY3pCdlRYVkZNbXN0VFJDVEFSalhBaWdCTWd1QkVvaGlLYWE0MUZpdXVR=-w200-h112-p-df',
#   'media': 'UNODC',
#   'site': None,
#   'reporter': None},
#  {'title': "Turmoil In Ranks: China's PLA Grapples With Corruption Scandals As Senior Officers Face Scrutiny",
#   'desc': None,
#   'date': 'Yesterday',
#   'datetime': datetime.datetime(2024, 11, 29, 12, 34, 55, 185277),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXZkbUZOUWpoTlkxUnhObWxSVFJDOUFSaUxBaWdCTWdhSlFwS3RxUVk=-w200-h112-p-df',
#   'media': 'BW Businessworld',
#   'site': None,
#   'reporter': None},
#  {'title': 'Iran determined to actively contribute to anti-corruption efforts: Official',
#   'desc': None,
#   'date': '1 hour ago',
#   'datetime': datetime.datetime(2024, 11, 30, 11, 34, 55, 185681),
#   'link': 'https://news.google.com/read/CBMinwFBVV95cUxNY1lpVzZyZ3ZwbDMxYVNsd3BJX1lKbzR0NXlkeXcwMEt6Z2RvQVhWU3dQUlpIX0pRQzgzSktIeEN1V1VjZDJ4QzdZRHBLcEFZR2xaRm1PdDhFTUkxVnZmUnh2d2x1YmlFUmR1eUp5aVRsZUM1Ml9UeE9ndDlLQXhGbGJ4LVdwME5OVFZkN2VodjBEUVZNYmFlRkxGQXBjRW8?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNUNNbGt4YW1wc1QxRnlRa2xHVFJEQ0FSaURBaWdCTWdB=-w200-h112-p-df',
#   'media': 'ایرنا',
#   'site': None,
#   'reporter': None},
#  {'title': "Corruption, leakages and abuse of power are akin to cancerous cells in nation's anatomy, says Sultan Nazrin",
#   'desc': None,
#   'date': '8 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 4, 34, 55, 186091),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNUdYMUJJUkV4TFVXdE5hbnB3VFJDM0FSaVRBaWdCTWdB=-w200-h112-p-df',
#   'media': 'The Star Online',
#   'site': None,
#   'reporter': None},
#  {'title': 'Practical Law: Note for the Board on Anti-Corruption - Singapore',
#   'desc': None,
#   'date': '26 Aug',
#   'datetime': datetime.datetime(2024, 8, 26, 0, 0),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNTVYMUZtVVdsT1IzQTJNVkpZVFJEQ0FSaURBaWdCTWdZQlFJalVTQVE=-w200-h112-p-df',
#   'media': 'Allen & Gledhill',
#   'site': None,
#   'reporter': None},
#  {'title': "Chinese military official Miao Hua under investigation amid ongoing corruption crackdown in China's army ranks",
#   'desc': None,
#   'date': 'Yesterday',
#   'datetime': datetime.datetime(2024, 11, 29, 12, 34, 55, 187074),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXhVVzR4Um1SeE1YQXpRV2N5VFJDb0FSaXJBaWdCTWdZZEFwWUxFZ3M=-w200-h112-p-df',
#   'media': 'ABC News',
#   'site': None,
#   'reporter': 'By Patrick Martin'},
#  {'title': 'Tsotsobe, Tsolekile and Mbhalati arrested and charged with corruption',
#   'desc': None,
#   'date': '18 hours ago',
#   'datetime': datetime.datetime(2024, 11, 29, 18, 34, 55, 187557),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNVNZa1J3VDNoclRXUlpOMEpEVFJDb0FSaXNBaWdCTWdB=-w200-h112-p-df',
#   'media': 'ESPNcricinfo',
#   'site': None,
#   'reporter': 'By Firdose Moonda'},
#  {'title': 'China probes top military official for corruption',
#   'desc': None,
#   'date': '2 days ago',
#   'datetime': datetime.datetime(2024, 11, 28, 12, 34, 55, 188016),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNTZiamMyTVdRM01VZFljbmxLVFJDb0FSaXNBaWdCTWdhQk1KSnVtUWM=-w200-h112-p-df',
#   'media': 'RFI English',
#   'site': None,
#   'reporter': None},
#  {'title': 'Special House Committee formed to probe corruption in Visakha Dairy, says Andhra Pradesh Assembly Speaker',
#   'desc': None,
#   'date': '20 hours ago',
#   'datetime': datetime.datetime(2024, 11, 29, 16, 34, 55, 188432),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNUxjMll5TjBOVFpUQjRNSEZ4VFJEaEFSamhBU2dCTWdhTmtwQXBPUVk=-w200-h112-p-df',
#   'media': 'The Hindu',
#   'site': None,
#   'reporter': None},
#  {'title': 'What makes China’s Guangdong and its ‘sin city’ magnets for corruption probes?',
#   'desc': None,
#   'date': '7 days ago',
#   'datetime': datetime.datetime(2024, 11, 23, 12, 34, 55, 188875),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iJ0NnNXFOVWRrWlY4elpGVjNiVGxRVFJDcUFSaXBBaWdCTWdNQkVBZw=-w200-h112-p-df',
#   'media': 'South China Morning Post',
#   'site': None,
#   'reporter': 'By William Zheng'},
#  {'title': 'Disgraced ex-minister gets jail time in rare corruption case for squeaky clean Singapore',
#   'desc': None,
#   'date': '3 Oct',
#   'datetime': datetime.datetime(2024, 10, 3, 0, 0),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNVVaSFF5TFZVNVMyaEljbmhGVFJDb0FSaXJBaWdCTWdhQlFKcW9KUWs=-w200-h112-p-df',
#   'media': 'CNN',
#   'site': None,
#   'reporter': None},
#  {'title': 'Karnataka cabinet orders reopening of corruption and money laundering cases against BS Yediyurappa and Family',
#   'desc': None,
#   'date': 'Yesterday',
#   'datetime': datetime.datetime(2024, 11, 29, 12, 34, 55, 189673),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNW9PVWxCUjFCNFgwTlJPWHAxVFJDb0FSaXNBaWdCTWdhZGRZb0xzZ1U=-w200-h112-p-df',
#   'media': 'Hindustan Times',
#   'site': None,
#   'reporter': None},
#  {'title': 'SC stays revival of corruption case against former TN CM Panneerselvam',
#   'desc': None,
#   'date': 'Yesterday',
#   'datetime': datetime.datetime(2024, 11, 29, 12, 34, 55, 190068),
# ...
#   'media': 'The Diplomat',
#   'site': None,
#   'reporter': 'By Mohammad Qadam Shah and Qadam Shah'},
#  {'title': 'Combatting High-level Corruption in Eastern Europe',
#   'desc': None,
#   'date': '12 Sept',
#   'datetime': datetime.datetime(2024, 9, 12, 0, 0),
#   'link': 'https://news.google.com/read/CBMipwFBVV95cUxNWWxtNFY3QzVMeVZfZnVyNUlrWm5ab3RjUmZFOUZld3JZSDVpbFphN3RfZmNlSHE4ME5ZcVFndWI4YUlwc19YUWpwbXNlQ0h4RDljZjJJWlFBdHV6S2VLRzdzaFpNQ1psVmMyT3NYRUxORElrR0tEZUtnYlB0al9nTzlTUzYzenB0WDVFYkM3MWd6RmVkRVFwekI5ekZUTXpCeTZBVDAxSQ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNWxhSEJLWWxGeFVGWXllSFpzVFJDOUFSaUtBaWdCTWdhQklaQk5wUVk=-w200-h112-p-df',
#   'media': 'OECD',
#   'site': None,
#   'reporter': None},
#  {'title': 'Ecuador judge convicts 20 in judiciary corruption case',
#   'desc': None,
#   'date': '4 days ago',
#   'datetime': datetime.datetime(2024, 11, 26, 12, 34, 55, 192481),
#   'link': 'https://news.google.com/read/CBMipAFBVV95cUxQUDNCdVBKVzNSRzJDTXdtaFRqMG9JdlBzRmstd2MyV1FZcm1PZU5mNEFVS0h4c3BYZGJVMm0ybENEcmNUZmdqcV9RSXY0ZWpOMV9TOFR0WnpaLUFjNjZ1OHhMWXo0NkJvVmFTSkU5Zm9BYmJBMkhENk50b1hhUGFRYzhUV2o0aFpYWVNhdF81dmNVNC1EQlM1bXdtWGxZaWFYbE0xSg?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNW9UVmMwYWsxUGVuRXhUbFp4VFJDNEFSaVNBaWdCTWdB=-w200-h112-p-df',
#   'media': 'Reuters Canada',
#   'site': None,
#   'reporter': 'By Alexandra Valencia and Kylie Madry'},
#  {'title': 'RG Kar corruption case: CBI files chargesheet, not accepted by court',
#   'desc': None,
#   'date': '18 hours ago',
#   'datetime': datetime.datetime(2024, 11, 29, 18, 34, 55, 192897),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNXVUV0poVFRBMWJUZFFibXhoVFJDb0FSaXJBaWdCTWdB=-w200-h112-p-df',
#   'media': 'India Today',
#   'site': None,
#   'reporter': 'By Rajesh Saha'},
#  {'title': 'Saudi citizen wanted for corruption crimes extradited from Russia',
#   'desc': None,
#   'date': '22 hours ago',
#   'datetime': datetime.datetime(2024, 11, 29, 14, 34, 55, 193290),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNHhlbWhZYkVkMWRHdGxkRGMyVFJDbkFSaXVBaWdCTWdB=-w200-h112-p-df',
#   'media': 'Saudi Gazette',
#   'site': None,
#   'reporter': None},
#  {'title': 'Sabah PKR gathering evidence to dispel corruption allegations against PM',
#   'desc': None,
#   'date': '6 days ago',
#   'datetime': datetime.datetime(2024, 11, 24, 12, 34, 55, 193671),
#   'link': 'https://news.google.?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNHphVmRPYlhSWVJXcEdiMHhKVFJDdkFSaWdBaWdCTWdZQmNvNXdKUWc=-w200-h112-p-df',
#   'media': 'The Star Online',
#   'site': None,
#   'reporter': None},
#  {'title': 'RG Kar Corruption Case: CBI Files Chargesheet, Not Accepted By Court',
#   'desc': None,
#   'date': '14 hours ago',
#   'datetime': datetime.datetime(2024, 11, 29, 22, 34, 55, 194073),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNVBRVEZmT1hkb1YycHlNMEZGVFJDd0FSaWVBaWdCTWdhbFJZN3NJUWc=-w200-h112-p-df',
#   'media': 'NDTV',
#   'site': None,
#   'reporter': None},
#  {'title': 'South Korean PM offers to Resign in his own Fight Against Corruption',
#   'desc': None,
#   'date': '22 Aug',
#   'datetime': datetime.datetime(2024, 8, 22, 0, 0),
#   'link': 'https://news.google.com/read/CBMinwFBVV95cUxOSjU5ekNVTnBTajNpZTNMdy1oLWlWWUIzZk55ejhxLUxNaTVGS3F5dUZVVjZtMU55S1lIbktqakF1aGpfNGdxUFpkVWE2M2J4bHhDMEY3VE1uWW5lU3pwbjdfcWljUi1rR0dIZW1XR0htbnhMMjZnNkdab3RJcDFqM0FUZU5FMkV4UVRqcW5tNlZTajc3NHZXVkJQMUlxd3c?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXNOemxFUnpJd1FUYzNTbGhHVFJDMkFSaVVBaWdCTWdZQlFKYWpJQWs=-w200-h112-p-df',
#   'media': 'OCCRP',
#   'site': None,
#   'reporter': None},
#  {'title': 'How to strengthen anti-corruption frameworks: 4 actionable insights',
#   'desc': None,
#   'date': '20 Sept',
#   'datetime': datetime.datetime(2024, 9, 20, 0, 0),
#   'link': 'https://news.google.com/read/CBMiigFBVV95cUxQNTZ2ZzRoRXNDNTMzTFczZ2VHNExEUElEbHBEdFJvcVM4TW9yZVE1eFRRTXRCOXlpN1ZQQWNHVktTN0xKNGhqM0p6THp1VzRXZHJaUDFrdzliSWpRa0x0eGp6NkdSTFZtQUJKZmlfZmhoZURwLURBYlUyVjZhVEZ1bDV2SXBsS01PZHc?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNW5iWE55VDB4elJGWmhkRWN0VFJDeEFSaWRBaWdCTWdhWklwSXl0UWM=-w200-h112-p-df',
#   'media': 'ComplyAdvantage',
#   'site': None,
#   'reporter': None},
#  {'title': 'Defence firm Thales faces bribery and corruption investigation',
#   'desc': None,
#   'date': '9 days ago',
#   'datetime': datetime.datetime(2024, 11, 21, 12, 34, 55, 195297),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNHplazF4Y3pCV2JHNHRWWFZCVFJDakFSaTJBaWdCTWdZQmtZQzM1QUU=-w200-h112-p-df',
#   'media': 'The Guardian',
#   'site': None,
#   'reporter': 'By Simon Goodley'},
#  {'title': 'Anti-Corruption Network for Eastern Europe and Central Asia',
#   'desc': None,
#   'date': '3 Jul',
#   'datetime': datetime.datetime(2024, 7, 3, 0, 0),
#   'link': 'https://news.google.com/read/CBMingFBVV95cUxNek1TV1JqY2JGTlEyTm1IYTUxVnRoRU0xOVRFZUFfSjlqUk9HSnJ3OHB6cmlyVnFZRzg4Z1J6ekF2bTRJUlB5YkRudEU5TDQzRjNTWHRSQXhZOEc2Q1g5MTZxcG9RY2RYbk5zZDUzTkVmOUltSm1ObHRZSDBIUnhVX0FKUjVDS0tBZU90Zkp2QTRBWFdsOUhHWFJKb3QwUQ?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNXFhaTExWVd0SU1UVndiVWRQVFJDM0FSaVRBaWdCTWdZQjRJam1UQVE=-w200-h112-p-df',
#   'media': 'OECD',
#   'site': None,
#   'reporter': None},
#  {'title': 'Civic body chief, JE, contractor booked on corruption charges',
#   'desc': None,
#   'date': '13 hours ago',
#   'datetime': datetime.datetime(2024, 11, 29, 23, 34, 55, 196142),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iL0NnNVlSMjFUWW5kd1F6RnhhMVEzVFJDM0FSaVRBaWdCTWdtTmNZclV3T1NoNndF=-w200-h112-p-df',
#   'media': 'The Tribune India',
#   'site': None,
#   'reporter': None},
#  {'title': 'Corruption in the Extractive Value Chain',
#   'desc': None,
#   'date': '8 Jul',
#   'datetime': datetime.datetime(2024, 7, 8, 0, 0),
#   'link': 'https://news.google.com/read/CBMioAFBVV95cUxNM3ZPMUNoRkJwRjUtcXp1ME9yNnlZX2dpRHhKMlpnLXRpSW14VkZsR2JPOHFqWFNCbmpkTmRWdHRYMkpiSEpIU1duZ3JRWTR5SXZBMFFrVURkdXVKVGVNeHBna3Npb2wzMS1wQjFxR1lKRVlRdHZfSXo5aXhqUmUzMkNQb1NQOU9KTEUxZi1uQWkyVkE1cFYyRXJrMHZIWGRw?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': None,
#   'media': 'OECD',
#   'site': None,
#   'reporter': None},
#  {'title': 'Tom Lembong Sugar Corruption Case, AGO Examines Former Ministry Of SOEs Officials',
#   'desc': None,
#   'date': '10 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 2, 34, 55, 196937),
#   'link': 'https://news.google.com/read/CBMiQ0FVX3lxTFAyR1hSOWZzQWdYajJzSi1sejZyMXJwM3ZCczRXTjFFM1F5OG53ZHA3c0JIVUphSDZHWEg3MXBvdTdJcWvSAUJBVV95cUxPbDdscWF0bHpSREQxOGl4VFFlMU1qV29YMEZjOWVGTkV2LVFqR2FtTjVHd3pCWUFHelR5Rk9kZG5CYUE?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNTVlak5zWW1WVlFqWlJRV3BWVFJDM0FSaVRBaWdCTWdZQndJUnZ3UVU=-w200-h112-p-df',
#   'media': 'VOI English',
#   'site': None,
#   'reporter': None},
#  {'title': "South Africa's Tsotsobe, Tsolekile and Mbhalati arrested, charged with corruption",
#   'desc': None,
#   'date': '10 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 2, 34, 55, 197511),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNXROSHBLZERaWGIyc3RkR3hsVFJDb0FSaXNBaWdCTWdB=-w200-h112-p-df',
#   'media': 'India Today',
#   'site': None,
#   'reporter': None},
#  {'title': "Xi Jinping can't seem to find the right man to be the face of China's military",
#   'desc': None,
#   'date': '2 days ago',
#   'datetime': datetime.datetime(2024, 11, 28, 12, 34, 55, 197965),
#   'link': 'https://news.google.com/read/CBMiqwFBVV95cUxQYnZ2ajNEZ2ZDTFJmTHJndE5nelJ1NFVYSDF4RmhIUnJ1WVI0RXVVSGtjYnlvbmxTUGdvc0RYMVZqZ3lOU2xZbkhjVHJaZDZzVDRxSTZBN1NKeURybkdQWWxmQjdROXRDWFlCc2w2VmZmRTBRR3JsQ2YtY2ZkNWI5MGZtcE0wem9MbnRPaklqZkw3U0I0RXo1UnNYOGYzcnV6aUZVeXpzblgzSE0?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iI0NnNTVOVVptYVRoWFpIcG5RMlZvVFJDM0FSaVRBaWdCTWdB=-w200-h112-p-df',
#   'media': 'Business Insider',
#   'site': None,
#   'reporter': 'By Matthew Loh'},
#  {'title': 'Gautam Adani not charged with FCPA, only securities violations involving penalties: Adani Green',
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 198384),
#   'link': 'https://news.google....?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNWxWMlUxTmpGeFkyWjNhbXRIVFJDb0FSaXNBaWdCTWdhbE5Kak5vUWc=-w200-h112-p-df',
#   'media': 'The Hindu',
#   'site': None,
#   'reporter': None},
#  {'title': "China's Defense Minister Under Investigation as Corruption Crisis Deepens",
#   'desc': None,
#   'date': '3 days ago',
#   'datetime': datetime.datetime(2024, 11, 27, 12, 34, 55, 198886),
#   'link': 'https://news.google.com/read/CBMiowFBVV95cUxPYTdQUGtSRHg4QUxLQnUzNGtGT3EtMVl6eEVDNkZIUk5ZRFM2Tk1HMHhxQmVuZ253bkU3M3QxQWp5bTU0VHRUdGlobER1bFBaRXRQeWZaNUJ4WTBpRGFVV2hEaG5tVTNMN0M0cWdXdlItZHF0VHctcnMzWUw5cDdnMWt2OE5DV2pxZWFRS1B1NlIzOTVKTHkwZmFGUHhDM0VZdUNN?hl=en-SG&gl=SG&ceid=SG%3Aen',
#   'img': 'https://news.google.com/api/attachments/CC8iK0NnNHdTRE16WkRKYVdrOTJTalp2VFJDM0FSaVRBaWdCTWdhZGM1RHJMUWM=-w200-h112-p-df',
#   'media': 'Newsweek',
#   'site': None,
#   'reporter': 'By Micah Mccartney'},
#  {'title': 'CM Chandrababu Ensures Corruption-Free Pension Distribution in Andhra Pradesh',
#   'media': 'AP7AM',
#   'date': '0 minutes ago',
#   'datetime': datetime.datetime(2024, 11, 30, 12, 34, 55, 599795),
#   'desc': 'In Andhra Pradesh, social pensions were distributed a day earlier than scheduled. As December 1 falls on a Sunday, pensions..',
#   'link': 'https://www.ap7am.com/en/90890/cm-chandrababu-ensures-corruption-free-pension-distribution-in-andhra-pradesh&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIAhAC&usg=AOvVaw1_e5ohH2r7Wdo2GuJ9fRod',
#   'img': '...'},
#  {'title': 'ANAMBRA GOVT IN COLLABORATION WITH EUROLAC REVIEWS ANTI- CORRUPTION PRACTICES IN THE STATE',
#   'media': 'Anambra State Government',
#   'date': '5 minutes ago',
#   'datetime': datetime.datetime(2024, 11, 30, 12, 29, 55, 603319),
#   'desc': 'By MaryAnn Chukwuma : The Anambra State Government in collaboration with the European Union Rule of Law and Anti-Corruption (RoLAC) programme has organised...',
#   'link': 'https://anambrastate.gov.ng/anambra-govt-in-collaboration-with-eurolac-reviews-anti-corruption-practices-in-the-state/&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQICRAC&usg=AOvVaw2gtO__ZQ1kQRENFIv2wXsJ',
#   'img': '...'},
#  {'title': 'Mahama defends proposal to restructure Free SHS Secretariat over corruption',
#   'media': 'Modern Ghana',
#   'date': '1 hour ago',
#   'datetime': datetime.datetime(2024, 11, 30, 11, 34, 57, 802957),
#   'desc': 'Flagbearer of the opposition National Democratic Congress (NDC), John Dramani Mahama, has defended his proposal to abolish the Free Senior High School (Free...',
#   'link': 'https://www.modernghana.com/news/1361354/mahama-defends-proposal-to-restructure-free-shs.html&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIARAC&usg=AOvVaw1PlayT8pm7obl93ACGNj0C',
#   'img': '...'},
#  {'title': 'The corruption scandal gripping Xi Jinping’s army',
#   'media': 'The Spectator',
#   'date': '1 hour ago',
#   'datetime': datetime.datetime(2024, 11, 30, 11, 34, 57, 814730),
#   'desc': "In recent months, a purge of top generals has shaken China's Rocket Force, the most secretive and sensitive branch of China's military.",
#   'link': 'https://www.spectator.co.uk/article/the-corruption-scandal-gripping-xi-jinpings-army/&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIBBAC&usg=AOvVaw1AHmctArgStLUTUye5THRm',
#   'img': '...'},
#  {'title': 'Iran determined to actively contribute to anti-corruption efforts: Official',
#   'media': 'IRNA English',
#   'date': '2 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 10, 34, 57, 824873),
#   'desc': 'Kazemi participated in the Second Ministerial Meeting of Anti-Corruption Law Enforcement Authorities in the member states of the Organization of Islamic...',
#   'link': 'https://en.irna.ir/news/85675336/Iran-determined-to-actively-contribute-to-anti-corruption-efforts&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIBhAC&usg=AOvVaw2umTYL3QPYwg2EPweYZMGK',
#   'img': '...'},
#  {'title': 'License examiner held for bribing anti-corruption investigators',
#   'media': 'Swisher Post',
#   'date': '2 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 10, 34, 57, 834042),
#   'desc': "The official was under investigation by the Road Traffic Management Corporation's national traffic anti-corruption unit and the Hawks - following...",
#   'link': 'https://swisherpost.co.za/crime/license-examiner-held-for-bribing-anti-corruption-investigators/&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQICBAC&usg=AOvVaw1prhj8eYv9W-TYNKi5GKaR',
#   'img': '...'},
#  {'title': "South Africa's Tsotsobe, Tsolekile And Mbhalati Arrested, Charged With Corruption",
#   'media': 'ETV Bharat',
#   'date': '3 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 9, 34, 57, 842932),
#   'desc': 'Former South African cricketers Lonwabo Tsotsobe, Thami Tsolekile, and Ethy Mbhalati have been arrested on corruption charges related to T20 match-fixing...',
#   'link': 'https://www.etvbharat.com/en/!sports/south-africa-three-cricketers-lonwabo-tsotsobe-thami-tsolekile-ethy-mbhalati-arrested-for-match-fixing-enn24113002405&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIAxAC&usg=AOvVaw2KKEphqf15EH1ny8hzFcyH',
#   'img': '...'},
#  {'title': 'Kedah sees rise in civil servants arrested for corruption',
#   'media': 'NST Online',
#   'date': '3 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 9, 34, 57, 851891),
#   'desc': 'SINTOK: The number of civil servants arrested on suspicion of corruption in Kedah has increased by nine cases this year compared to last year,...',
#   'link': 'https://www.nst.com.my/news/nation/2024/11/1141853/kedah-sees-rise-civil-servants-arrested-corruption&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIBxAC&usg=AOvVaw2LVVGmcvpJvTnNqRwt6ftn',
#   'img': '...'},
#  {'title': 'KPK, TNI Commander to Discuss Corruption Handling in the Military',
#   'media': 'Tempo.co English',
#   'date': '4 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 8, 34, 57, 860897),
#   'desc': 'The Corruption Eradication Commission or KPK now has the authority to handle corruption cases involving TNI members.',
#   'link': 'https://en.tempo.co/read/1947200/kpk-tni-commander-to-discuss-corruption-handling-in-the-military&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIBRAC&usg=AOvVaw2K1pzQHL5wIEmz1I1qzzcX',
#   'img': '...'},
#  {'title': 'DSI summary on PTT-OR corruption case is fake news, agency says',
#   'media': 'Nation Thailand',
#   'date': '4 hours ago',
#   'datetime': datetime.datetime(2024, 11, 30, 8, 34, 57, 869909),
#   'desc': 'The Department of Special Investigation (DSI) announced on Saturday that a summary of the investigation on a corruption case involving national oil and gas...',
#   'link': 'https://www.nationthailand.com/news/general/40043749&ved=2ahUKEwim_bnXiISKAxVJXWwGHdO6CosQxfQBegQIABAC&usg=AOvVaw0p35fUZiFEbdwF8feKG44U',
#   'img': '...'}]

# %% [markdown]
# ##Construccion del Dataframe con las noticias
# ###Como los datos estan ordenados por links en la busqueda
# ###a traves de las dos palabras claves se crean 2 ###dataFrames, "bribery", "overlap", luego se concatenan en ##un solo conjunto de datos,una columna de description_text ###y su link hacia el sitio GoogleNews

# %% [markdown]
# 1-se crean tres  objetos donde se alojan las busquedas:
# # ***result_0 = googlenews.page_at(1)***
#
# # ***desc_1 = googlenews.get_texts()***
# # ***link_1 = googlenews.get_links()***

# %% [markdown]
# 2- Se asignan en un bucle for los resultados de la busqueda a los objetos:
#
# # ***for i in list(range(2, 10)):***
#
#     result = googlenews.page_at(i)
#     desc = googlenews.get_texts()
#     link = googlenews.get_links()
#
#     desc_1 = desc_1 + desc
#     link_1 = link_1 + link

# %% [markdown]
# 3- se construyen los dataframe con los resutados de la busqueda:
# import pandas as pd
#
# column_names = ["description_text", 'link']
# df = pd.DataFrame(columns = column_names)
#
# df['description_text'] = desc_1
# df['link'] = link_1
# display(df)
#
# df.to_csv('google_news.csv', index = False)
#
# df = df.reset_index()
#
# bribery = df[df["description_text"].str.contains("bribery", na=False)]
# overlap = df[df["description_text"].str.contains("overlap", na=False)]
# robbery = df[df["description_text"].str.contains("robbery", na=False)]
# bribery = pd.concat([bribery, overlap,robbery])
# bribery['bribery'] = 'Yes'
# bribery = bribery.reset_index(drop=True)
#
# # -Se unen los dataFrame:
#
# df = pd.merge(df,bribery,on='index',how='left')
# df = df[['description_text_x','bribery']]
#
# df.bribery = df.bribery.replace(np.NaN, 'No')
# df

# %%
result_0 = googlenews.page_at(1)

desc_1 = googlenews.get_texts()
link_1 = googlenews.get_links()

for i in list(range(2, 10)):

    result = googlenews.page_at(i)
    desc = googlenews.get_texts()
    link = googlenews.get_links()

    desc_1 = desc_1 + desc
    link_1 = link_1 + link

import pandas as pd

column_names = ["description_text", 'link']
df = pd.DataFrame(columns = column_names)

df['description_text'] = desc_1
df['link'] = link_1
display(df)

df.to_csv('google_news.csv', index = False)

df = df.reset_index()

bribery = df[df["description_text"].str.contains("bribery", na=False)]
overlap = df[df["description_text"].str.contains("overlap", na=False)]
robbery = df[df["description_text"].str.contains("robbery", na=False)]
bribery = pd.concat([bribery, overlap,robbery])
bribery['bribery'] = 'Yes'
bribery = bribery.reset_index(drop=True)

df = pd.merge(df,bribery,on='index',how='left')
df = df[['description_text_x','bribery']]

df.bribery = df.bribery.replace(np.NaN, 'No')
df
# Out:
#                                        description_text  \
# 0     China suspends military official Miao Hua in a...
# 1     China defence minister placed under investigat...
# 2     China Defence Minister Dong Jun’s fate unclear...
# 3     China dismisses report of corruption probe int...
# 4     China’s defence minister placed under investig...
# ...                                                 ...
# 1436  Pakistani Authorities Intensify Search for Bus...
# 1437  National Audit to review Sarawak Metro in mid-...
# 1438  Assistant Teacher convicted in vigilance corru...
# 1439  Probe Kwara officials for N14.2b misappropriat...
# 1440  Crisis in China's PLA? Senior military officia...
#
#                                                    link
# 0     https://news.google.com/read/CBMizgFBVV95cUxQN...
# 1     https://news.google.com/read/CBMiuwFBVV95cUxQM...
# 2     https://news.google.com/read/CBMiuwFBVV95cUxNS...
# 3     https://news.google.com/read/CBMi0gFBVV95cUxON...
# 4     https://news.google.com/read/CBMicEFVX3lxTE5qY...
# ...                                                 ...
# 1436  https://www.devdiscourse.com/article/law-order...
# 1437  https://dayakdaily.com/national-audit-to-revie...
# 1438  https://kalingatv.com/odisha/assistant-teacher...
# 1439  https://guardian.ng/news/nigeria/metro/probe-k...
# 1440  https://www.msn.com/en-in/news/world/crisis-in...
#
# [1441 rows x 2 columns]
#                                      description_text_x bribery
# 0     China suspends military official Miao Hua in a...      No
# 1     China defence minister placed under investigat...      No
# 2     China Defence Minister Dong Jun’s fate unclear...      No
# 3     China dismisses report of corruption probe int...      No
# 4     China’s defence minister placed under investig...      No
# ...                                                 ...     ...
# 1436  Pakistani Authorities Intensify Search for Bus...      No
# 1437  National Audit to review Sarawak Metro in mid-...      No
# 1438  Assistant Teacher convicted in vigilance corru...      No
# 1439  Probe Kwara officials for N14.2b misappropriat...      No
# 1440  Crisis in China's PLA? Senior military officia...      No
#
# [1441 rows x 2 columns]

# %% [markdown]
# Determino tamaño del dataframe

# %%
df.shape
# Out:
# (1441, 2)

# %% [markdown]
# # ***-Biblioteca adicional ...***

# %% [markdown]
# -Libreria skimpy: https://pypi.org/project/skimpy/
# skimpy es una herramienta liviana que proporciona estadísticas resumidas sobre variables en marcos de datos pandas o polares dentro de la consola o su ventana interactiva de Python

# %%
# !pip install skimpy
# Out:
# Requirement already satisfied: skimpy in /usr/local/lib/python3.10/dist-packages (0.0.15)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from skimpy) (2.18.0)
# Requirement already satisfied: click<9.0.0,>=8.1.6 in /usr/local/lib/python3.10/dist-packages (from skimpy) (8.1.7)
# Requirement already satisfied: ipykernel<7.0.0,>=6.7.0 in /usr/local/lib/python3.10/dist-packages (from skimpy) (6.29.5)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from skimpy) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from skimpy) (2.2.2)
# Requirement already satisfied: polars<0.21,>=0.19 in /usr/local/lib/python3.10/dist-packages (from skimpy) (0.20.31)
# Requirement already satisfied: pyarrow<17,>=13 in /usr/local/lib/python3.10/dist-packages (from skimpy) (16.1.0)
# Requirement already satisfied: rich<14.0,>=10.9 in /usr/local/lib/python3.10/dist-packages (from skimpy) (13.9.4)
# Requirement already satisfied: typeguard==4.2.1 in /usr/local/lib/python3.10/dist-packages (from skimpy) (4.2.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from typeguard==4.2.1->skimpy) (4.12.2)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.1.12)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.9.5)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=10.9->skimpy) (3.0.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.48)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.7.0->skimpy) (4.3.6)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=10.9->skimpy) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.3->skimpy) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.13)

# %%
from skimpy import skim

skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 1441   │ │ string      │ 2     │                                                          │
# │ │ Number of columns │ 2      │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                        ┃ NA     ┃ NA %      ┃ words per row             ┃ total words          ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ description_text_x                 │      0 │         0 │                        10 │                14716 │  │
# │ │ bribery                            │      0 │         0 │                         1 │                 1441 │  │
# │ └────────────────────────────────────┴────────┴───────────┴───────────────────────────┴──────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# -Script sugerido para conjunto de datos numerico :
# # ***from skimpy import skim, generate_test_data***
#
# # ***df = generate_test_data()***
# # ***skim(df)***

# %% [markdown]
# ...........................................

# %% [markdown]
# ## Para crear el dataFrame de Corruption, se buscan dos palabras clave para la construccion del dataframe producido a traves  la busqueda de noticias "bribery"-soborno-"overlap" -sobreprecio, en el sitio de googlenews

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1441 entries, 0 to 1440
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   description_text_x  1441 non-null   object
#  1   bribery             1441 non-null   object
# dtypes: object(2)
# memory usage: 22.6+ KB

# %% [markdown]
# Ahora generamos el análisis de datos exploratorios (EDA)  a traves de la utilizacion de pandas profiling

# %%
# Generate the Profiling Report
profile = ProfileReport(
    df, title="Coruption", html={"style": {"full_width": True}}, sort=None
)

# %% [markdown]
# # ***Reporte EDA***

# %% [markdown]
# La utilidad de la descirpcion de las variables en la busqueda de palabras, la nube de palabras le da alguna pista u orientacion de busqueda.

# %%
df.profile_report()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-11-30 12:35:04.920934&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %% [markdown]
# ## El profile en version wiget horizontal

# %%
# The Notebook Widgets Interface
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
profile
# Out:
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-11-30 12:35:06.751102&quot;&gt;&lt;title&gt;Coruption&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %% [markdown]
# # ***-Establecemos dummies en el dataset de noticias***

# %%
df
# Out:
#                                      description_text_x bribery
# 0     China suspends military official Miao Hua in a...      No
# 1     China defence minister placed under investigat...      No
# 2     China Defence Minister Dong Jun’s fate unclear...      No
# 3     China dismisses report of corruption probe int...      No
# 4     China’s defence minister placed under investig...      No
# ...                                                 ...     ...
# 1436  Pakistani Authorities Intensify Search for Bus...      No
# 1437  National Audit to review Sarawak Metro in mid-...      No
# 1438  Assistant Teacher convicted in vigilance corru...      No
# 1439  Probe Kwara officials for N14.2b misappropriat...      No
# 1440  Crisis in China's PLA? Senior military officia...      No
#
# [1441 rows x 2 columns]

# %% [markdown]
# ***-Es logico  aplicar dummies en la columna principal -description_text_x en el dataFrame, que obtengo?***

# %%
df = pd.get_dummies(df,columns=['description_text_x'], drop_first=True)### drop_first= True-elimina la primera de las columnas generadas, description_text_x.
display(df.head())
display(df.tail())
# Out:
#   bribery  \
# 0      No
# 1      No
# 2      No
# 3      No
# 4      No
#
#    description_text_x_2024/42 "Corruption Eradication in Indonesia: One Step Forward, Two Steps Back" by Astrid Meilasari-Sugiana, Gunardi Endro, Siwage Dharma Negara  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_2024/44 "Anti-Corruption Politics and Shifts in Central-Local Relations in Vietnam" by Nguyen Khac Giang  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_A Corruption Case That Spilled Across Latin America Is Coming Undone  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_A Top Military Official in China Is Suspended Under Suspicion of Corruption  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_AHMED SADIK: Why Abdi Mohamud's nomination as EACC CEO is praiseworthy  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_ANAMBRA GOVT IN COLLABORATION WITH EUROLAC REVIEWS ANTI- CORRUPTION PRACTICES IN THE STATE  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_Alleged Diversion Of Palliatives: Kano Anti-Corruption Agency Halts Investigation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_Anti-Corruption Network for Eastern Europe and Central Asia  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_Assistant Teacher convicted in vigilance corruption case and sent to jail  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    description_text_x_Tsotsobe, Tsolekile and Mbhalati arrested and charged with corruption  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_Turmoil In Ranks: China's PLA Grapples With Corruption Scandals As Senior Officers Face Scrutiny  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_Two cops arrested for meth peddling; two more on radar  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_Unbroken Chains: The Continuity of Systemic Corruption in Afghanistan  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_Understanding corruption and its relationship with AML  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_Wavinya Ndeti warns Machakos officials against corruption, vows strict action  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_What makes China’s Guangdong and its ‘sin city’ magnets for corruption probes?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_Why China is purging its senior military officials  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_Why Xi Jinping Is Targeting Senior Chinese Military Officials In Ongoing Anti-Corruption Crackdown  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    description_text_x_Xi Jinping can't seem to find the right man to be the face of China's military
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 163 columns]
#      bribery  \
# 1436      No
# 1437      No
# 1438      No
# 1439      No
# 1440      No
#
#       description_text_x_2024/42 "Corruption Eradication in Indonesia: One Step Forward, Two Steps Back" by Astrid Meilasari-Sugiana, Gunardi Endro, Siwage Dharma Negara  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_2024/44 "Anti-Corruption Politics and Shifts in Central-Local Relations in Vietnam" by Nguyen Khac Giang  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_A Corruption Case That Spilled Across Latin America Is Coming Undone  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_A Top Military Official in China Is Suspended Under Suspicion of Corruption  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_AHMED SADIK: Why Abdi Mohamud's nomination as EACC CEO is praiseworthy  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_ANAMBRA GOVT IN COLLABORATION WITH EUROLAC REVIEWS ANTI- CORRUPTION PRACTICES IN THE STATE  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_Alleged Diversion Of Palliatives: Kano Anti-Corruption Agency Halts Investigation  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_Anti-Corruption Network for Eastern Europe and Central Asia  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_Assistant Teacher convicted in vigilance corruption case and sent to jail  \
# 1436                                              False
# 1437                                              False
# 1438                                               True
# 1439                                              False
# 1440                                              False
#
#       ...  \
# 1436  ...
# 1437  ...
# 1438  ...
# 1439  ...
# 1440  ...
#
#       description_text_x_Tsotsobe, Tsolekile and Mbhalati arrested and charged with corruption  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_Turmoil In Ranks: China's PLA Grapples With Corruption Scandals As Senior Officers Face Scrutiny  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_Two cops arrested for meth peddling; two more on radar  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_Unbroken Chains: The Continuity of Systemic Corruption in Afghanistan  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_Understanding corruption and its relationship with AML  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_Wavinya Ndeti warns Machakos officials against corruption, vows strict action  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_What makes China’s Guangdong and its ‘sin city’ magnets for corruption probes?  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_Why China is purging its senior military officials  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_Why Xi Jinping Is Targeting Senior Chinese Military Officials In Ongoing Anti-Corruption Crackdown  \
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
#       description_text_x_Xi Jinping can't seem to find the right man to be the face of China's military
# 1436                                              False
# 1437                                              False
# 1438                                              False
# 1439                                              False
# 1440                                              False
#
# [5 rows x 163 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1441 entries, 0 to 1440
# Columns: 163 entries, bribery to description_text_x_Xi Jinping can't seem to find the right man to be the face of China's military
# dtypes: bool(162), object(1)
# memory usage: 239.4+ KB

# %% [markdown]
# # ***-Es logico el DataFrame que obtuve.??..es texto..tiene tratamiento diferente.***
